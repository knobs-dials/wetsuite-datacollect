# %% [markdown]
# <a href="https://colab.research.google.com/github/knobs-dials/wetsuite-datacollect/blob/main/kansspelautoriteit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Purpose of this notebook
#
# Collect data from contents PDFs under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/
#
# We are not aware of any API, so are currently collecting information based on scraping web pages.

# %% [markdown]
# NOTE: This is how a dataset was created.
# In the process we will give an example of extracting data from a website, reorganizing that data and, as it turns out, of applying OCR out of necessity.
#
# If you only care about how to _use_ that dataset, see [using_dataset_kansspelautoriteit.ipynb](../using_dataset_kansspelautoriteit.ipynb) instead.
#
# If you _do_ want to read this code, e.g. to get a start at doing your own OCR processing, read on...
# (note also that this code relies on poppler (for PDF parsing) and easyOCR (for OCR), neither of which are quite trivial installs)

# %% [markdown]
# ### Preparation
# imports we will use, and some helper functions.

# %%
#imports and helpers we'll use later

import hashlib, urllib, json, json, pprint, textwrap, re, pprint, random

import bs4, numpy

import wetsuite.helpers.localdata
import wetsuite.helpers.meta
import wetsuite.helpers.net
import wetsuite.helpers.format
import wetsuite.helpers.notebook
import wetsuite.helpers.strings
import wetsuite.helpers.date
import wetsuite.extras.pdf
import wetsuite.extras.ocr



def hash(data: bytes):
    ' calculate SHA1 hash of some data. '
    s1h = hashlib.sha1()
    s1h.update( data )
    return s1h.hexdigest()


def find_eur_money(s:str, minimum=0):
    ''' Given a string, returns a list of substrings that look like money amounts, e.g.
            find_eur_money('   EUR 10,-  ')       == ['10']
            find_eur_money('   EUR 10.    ')      == ['10']
            find_eur_money('   EUR100.000,-')     == ['100000']
            find_eur_money('   EUR100000  ')      == ['100000']
            find_eur_money('   \u20ac100.000')    == ['100000']   # but not commas, because Dutch uses that as a digit.  That should probably be configurable
            find_eur_money('   \u20ac 100000')    == ['100000']
            find_eur_money('   \u20ac 100000  ')  == ['100000']
        (where \u20ac is the euro symbol's unicode codepoint, expressed how python takes it)
    '''
    ret = []
    # the with-text-context was partially for debug, but might actually be useful to return
    for before, match_str, match_object, after in wetsuite.helpers.strings.findall_with_context(r"(?:EUR|\u20ac)\s*([0-9.]+)\b", s, 20):
        cap = match_object.groups()[0].replace('.','')
        try:
            if int(cap) < minimum:
                continue
        except ValueError as ve: # not parseable as number? Remove
            pass
        #print( '[%s]%s[%s] -> %r'%(before, match_str, after, cap) )
        ret.append(cap)
    return ret

# %% [markdown]
# ### Fetching the data

# %%
# Use a local store so that we only need to fetch the PDFs once, only render PDF pages once 
import wetsuite.helpers.localdata
pdfstore   = wetsuite.helpers.localdata.LocalKV('kansspel_pdfstore.db', key_type=str, value_type=bytes )     # URL -> PDF file bytestring
ocrstore   = wetsuite.helpers.localdata.LocalKV('kansspel_ocrstore.db', key_type=str, value_type=bytes )     # page-specific key -> json as bytes

# %% [markdown]
# #### Fetching case summaries
#
# What we have is a website we can look at.
# What we want is metadata and text per case.
#
# Let's first scrape the webpage to figure out all cases, all documents that relate to each case
#
# These fetches aren't cached, because the amount of cases will change, and case details can change as they progress.

# %%
# You're not expected to grasp all the following nested code- 
#   the main reason it is hard to read is that we spend a lot of code 
#   tring to get structured information from a not-so-structured HTML page.


# The purpose of this section is to fill the following variable:
extracted_cases = []  # list of (casename, [list of document dicts], [same-sized list of ocr results])

maxpage  = 9999999  # will be set to the actual number of pages by the first (well, every) page we fetch
cur_page = 0        # zero-based counting in the pagination

print( "FETCHING CASE SUMMARIES" )
while cur_page <= maxpage:
    page_url = 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=%d'%cur_page
    print( page_url )
                
    page_data = wetsuite.helpers.net.download(page_url)
    soup = bs4.BeautifulSoup( page_data, 'lxml' )

    # get the amount of pages, from the pagination links
    pagelinks = soup.select('a[class~="pager_step"][class~="pagina"]')   # CSS selector looking for both of those classes set in a whitespace-token list
    maxpage = int( pagelinks[-1].get('data-page') )                      # -1: last of those we see on the page.  Actually wrong on the last page?

    print( "page %d of %d"%( cur_page+1, maxpage+1 ) ) # numbering is zero-based,  print out one-based for humans

    # fetch all links to specific case detail pages
    for detail_page_a in soup.select('#results a[class~="siteLink"]'): # pick out the links (URLs) of the detail page of each case
        detail_page_url = detail_page_a.get('href') # these are already absolute  (otherwise we'd have to urljoin them)
        case_name = detail_page_a.text.replace('/','_')
        case_dict = {
            'name':case_name,
            'date_range':[],
            'money':[],
            'ecli':[],
            'case_detail_url':detail_page_url,
        }

        print( f'  Case: {repr(case_name):40s}', end='' )

        # Note: the date shown here and on the detail page may be the start date?   It may still useful to distinguish cases for repeat offenders


        ### fetch that case's detail page, and find all PDF links on it ##########################################################
        detail_page_data = wetsuite.helpers.net.download( detail_page_url )
        detail_soup = bs4.BeautifulSoup( detail_page_data, 'lxml' )

        # This section used to be three lines long, 
        #   until we decided that hey, maybe that status would be nice to have.
        #   then we discovered this is a free-form mess
        #   and this is the hand-crafted combination of of exception cases that will probably break in the future.


        #print( detail_page_url )
        
        ## Construct a list of dicts, one for each document,  with keys 'title', 'status', and 'pdf_url'
        doc_dicts = [] #  will be that list of dicts
        cur       = {} # 'currently collecting into this' dict 

        def check_add_clear():
            global doc_dicts, cur
            ''' if there's sensible content, we add it to our list of docs.
                clears cur for next document
            '''
            # if effectively empty, do nothing at all
            if len(cur.keys())==1  and  'title' in cur  and  cur['title']=='': # effectively empty. Also one of a handful of exception cases
                pass
            elif len(cur)>0: # effectively empty
                # fail if it's incomplete, so that I fix it   (or accept it as an edge case)
                if 'title' not in cur:
                    print('SKIP: scraping code is missing title, cur=%r'%cur)
                
                # temporarily removed, the case that triggers this is fixable
                elif 'pdf_url' not in cur:
                    print( 'SKIP: scraping code is missing pdf_url, cur=%r'%cur)
                
                #if 'status' not in cur:
                #    raise ValueError('scraping code is missing status, cur=%r'%cur) that happens, see e.g. https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/n1-interactive/ or https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                
                #print("ADD %r"%cur)
                else:
                    doc_dicts.append(cur)
            cur = {}


        # this whole part used to be short, and readable(ish), but the pages are a bit messy so it ended up with a lot of exception cases.
        pdflinks = list( detail_soup.select('a[class~="importLink"][class~="pdf"]') )   # (now) used only to find the content block that contains these

        # (and things like select('div[class~="grid-blok"] div[class~="grid-element"] div[class~="grid-inside"] div[class~="iprox-content"]') is not specific enough, that's a general template
        if len(pdflinks)==0:
            print("WARNING - no content?")
        else:
            # We expect a sequence of one or more of: 
            # - h2              (title)
            # - p with a inside (link)
            # - h2-or-h3        (the header saubg "status")
            # - p               (the actual status text)            

            # ...but I've seen an initial paragraph in front of it. 
            # ...and a header and a paragraph in front of it.
            child = pdflinks[0].parent.previous_element # try to position on the first document's title header. Parent would be the p
            while child.name is None and child.previous_sibling is not None: # find previous non-text node.   ...there must be a better way of doing this.
                child = child.previous_sibling
            #print( 'Chosen starting spot: ', child )

            while child is not None:
                #print( child )
                if child.name: # filter out text nodes (iirc)
                    pdflinks = list( child.select('a[class~="importLink"][class~="pdf"]') )
                    has_pdflinks = len(pdflinks) > 0
                    alltext = (''.join(child.findAll(text=True))).strip().lower().strip(':')

                    # augmenting some things we find
                    case_dict['money'].extend( find_eur_money(alltext, minimum=5001) )
                    case_dict['ecli'].extend( wetsuite.helpers.meta.findall_ecli(alltext, rstrip_dot=True) )

                    #print( "LOOKING AT %r"% str(child).strip() )
                    if child.name in ('h2','h3'):
                        if has_pdflinks: # weird case in https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/vriendenloterij/
                            cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            if 'title' not in cur: # would be overwritten in almost all cases
                                cur['title'] = alltext # but helps deal with https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/1x-corp-exinvest/
                        else:
                            if alltext == 'status': # header that just says 'status'
                                #print('HEADER - "status"')
                                pass 
                            else: # probably a title
                                #print('HEADER - title?')
                                check_add_clear() # starts a new one, so:
                                cur['title'] = child.text
                    elif child.name == 'p':
                        if len(cur)==0: # dict empty?
                            pass # probably an initial paragraph
                        else:
                            if has_pdflinks: #elif 'pdf_url' not in cur:
                                #print('FIRST P - PDF URL')
                                cur['pdf_url'] = urllib.parse.urljoin( detail_page_url, pdflinks[0].get('href') )   # make relative URLs absolute
                            else: #elif 'pdf_url' in cur: # status text
                                #print('SECOND P - STATUS TEXT')
                                cur['status'] = child.text
                child = child.next_sibling
            check_add_clear()

            #pprint.pprint( doc_dicts )
            print( '    # documents: %d'%len(doc_dicts) )


        extracted_cases.append( (case_dict, doc_dicts, []) )
        #break  #  during debug: stop after first case on page

    cur_page += 1
    #break  #  during debug: stop after first page
# Out:
# FETCHING CASE SUMMARIES
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=0
# page 1 of 7
#   Case: 'Gammix Limited'                        SKIP: scraping code is missing pdf_url, cur={'title': 'Eerder gepubliceerd op 11 juli 2022', 'status': 'De Kansspelautoriteit stelde vast dat\xa0Gammix Limited door middel van meerdere websites gelegenheid geeft tot deelname aan een kansspel\xa0waarvoor geen vergunning is verleend. Daarmee handelt\xa0Gammix Limited in strijd met de Wet op de kansspelen. De raad van bestuur van de Kansspelautoriteit draagt Gammix Limited op het aanbieden van kansspelen waarvoor geen vergunning ingevolge de Wet op de kansspelen is verleend, te staken en gestaakt te houden door middel van het opleggen van een last onder dwangsom.'}
#     # documents: 6
#   Case: 'Hillside New Media Malta Plc'              # documents: 4
#   Case: 'Betent B.V.'                               # documents: 1
#   Case: 'Cloudflare'                                # documents: 2
#   Case: 'Cloudflare'                                # documents: 2
#   Case: 'Holland Casino'                            # documents: 4
#   Case: 'Betent'                                    # documents: 5
#   Case: 'Bingoal Nederland B.V.'                    # documents: 5
#   Case: 'Vriendenloterij N.V.'                  SKIP: scraping code is missing pdf_url, cur={'title': '30 mei 2023'}
#     # documents: 4
#   Case: 'Nationale Postcode Loterij N.V.'       SKIP: scraping code is missing pdf_url, cur={'title': '30 mei 2023'}
#     # documents: 4
#   Case: 'GoldWin Limited'                           # documents: 2
#   Case: 'MKC Limited'                               # documents: 2
#   Case: 'Blue High House S.A.'                      # documents: 2
#   Case: 'L.C.S Limited'                             # documents: 4
#   Case: 'JOI Gaming Ltd'                            # documents: 5
#   Case: 'Play North Limited'                    SKIP: scraping code is missing pdf_url, cur={'title': 'Openbaarmakingsbesluit Play North', 'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}
#     # documents: 2
#   Case: 'Betent'                                SKIP: scraping code is missing pdf_url, cur={'title': 'Openbaarmakingsbesluit\xa0Betent', 'status': 'Tegen dit besluit kan bezwaar worden gemaakt.'}
#     # documents: 2
#   Case: 'NetX Betting'                              # documents: 2
#   Case: 'GoldWin Ltd'                               # documents: 2
#   Case: 'Merkur Casino Almere B.V.'                 # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=1
# page 2 of 7
#   Case: 'Winning Poker Network'                     # documents: 2
#   Case: 'Red Ridge Marketing'                       # documents: 2
#   Case: 'Probe Investments Limited'                 # documents: 5
#   Case: 'Betpoint Group Limited'                    # documents: 2
#   Case: 'N1 Interactive Limited'                    # documents: 5
#   Case: 'Videoslots Limited'                        # documents: 2
#   Case: 'Fairload Limited'                          # documents: 5
#   Case: 'Equinox Dynamic N.V. & Domiseda and Partners s.r.o.'    # documents: 5
#   Case: 'Bingoal Nederland B.V.'                    # documents: 4
#   Case: 'Shark77.Ltd'                               # documents: 5
#   Case: 'Holland Casino N.V.'                       # documents: 6
#   Case: 'Toto Online B.V.'                          # documents: 0
#   Case: 'Nationale Postcode Loterij N.V.'           # documents: 2
#   Case: 'M.K.C Limited'                             # documents: 2
#   Case: 'Red Ridge Marketing'                       # documents: 4
#   Case: 'Performing Media Limited'                  # documents: 2
#   Case: 'Linkerik B.V.'                             # documents: 4
#   Case: 'Onlinecasinobonus.nl'                      # documents: 2
#   Case: 'LCB CORP'                                  # documents: 2
#   Case: 'Casinoscout.nl'                            # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=2
# page 3 of 7
#   Case: 'Slots Dev'                                 # documents: 2
#   Case: 'Online Casino Ground ltd'                  # documents: 2
#   Case: 'Tipico Co. Ltd'                            # documents: 2
#   Case: 'BSB Shop'                                  # documents: 2
#   Case: 'Luxury Bingo'                              # documents: 2
#   Case: 'N1 Interactive Limited'                    # documents: 5
#   Case: 'Staatsloterij B.V.'                        # documents: 4
#   Case: 'Raging Rhino N.V.'                         # documents: 2
#   Case: 'Lovelto Mar LTD'                           # documents: 4
#   Case: '1X Corp N.V._Exinvest Limited'             # documents: 4
#   Case: 'WL Deal'                                   # documents: 2
#   Case: 'Virtual Coin Gaming N.V.'                  # documents: 6
#   Case: 'Clipboard Publications B.V.'               # documents: 2
#   Case: 'Kelner Automaten Service'                  # documents: 0
#   Case: 'Schinveld BV'                              # documents: 5
#   Case: 'Voormalig exploitant Dordrecht'            # documents: 2
#   Case: 'Voormalig exploitant Amersfoort'           # documents: 2
#   Case: 'Royal Panda Limited'                       # documents: 5
#   Case: 'LeoVegas Gaming p.l.c.'                    # documents: 4
#   Case: 'Pokerstars'                                # documents: 5
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=3
# page 4 of 7
#   Case: 'Chance Publications Malta Ltd'             # documents: 3
#   Case: 'Unibet'                                    # documents: 2
#   Case: 'Bwin'                                      # documents: 5
#   Case: 'Simbat Entertainment Systems en Spinity'    # documents: 7
#   Case: 'Com Coin Operated Machines'                # documents: 2
#   Case: 'Casumo'                                    # documents: 5
#   Case: 'Innovation Labs en Gaming Innovation Group'    # documents: 6
#   Case: 'Content Publishing Limited'                # documents: 5
#   Case: 'Exploiteren zonder vergunning in café'     # documents: 4
#   Case: 'WHG (International) Limited'               # documents: 5
#   Case: 'Voormalig exploitant Abcoude'              # documents: 2
#   Case: 'CyberRock Entertainment N.V. en Honeydew Trading Limited.'    # documents: 6
#   Case: 'Mr Green Limited'                          # documents: 4
#   Case: 'ITC Lounge Plaza'                          # documents: 2
#   Case: 'Corona Limited'                            # documents: 4
#   Case: 'Café restaurant De Kruik'                  # documents: 2
#   Case: 'Bet-at-home'                               # documents: 4
#   Case: 'Visionairy iGaming'                        # documents: 4
#   Case: 'VriendenLoterij N.V.'                      # documents: 8
#   Case: 'BankGiro Loterij N.V.'                     # documents: 8
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=4
# page 5 of 7
#   Case: 'Nationale Postcode Loterij N.V.'           # documents: 10
#   Case: 'Lotto B.V.'                                # documents: 12
#   Case: 'Staatsloterij B.V.'                        # documents: 8
#   Case: 'Holland Casino N.V.'                       # documents: 4
#   Case: 'Catena Operations Limited'                 # documents: 2
#   Case: 'Weddenopvoetbal.org'                       # documents: 4
#   Case: 'JvG speelautomaten'                        # documents: 2
#   Case: 'Trustfulgames.com Limited'                 # documents: 7
#   Case: 'L.S.A. B.V'                                # documents: 4
#   Case: 'M-automaten exploitatie'                   # documents: 2
#   Case: 'Wedwinkel Rotterdam'                       # documents: 2
#   Case: 'Friese ondernemer'                         # documents: 1
#   Case: 'Holland Gaming'                            # documents: 2
#   Case: 'Olders Amusementsautomaten B.V.'           # documents: 1
#   Case: 'Duitse loterijen'                          # documents: 2
#   Case: 'Dolle Pret in Almelo B.V.'                 # documents: 2
#   Case: 'Redslots'                                  # documents: 4
#   Case: 'Café _ Bar Bağci'                          # documents: 4
#   Case: 'Total E Soft Limited en XKL Limited'       # documents: 4
#   Case: 'Belhuis _ Internetcafé Ephesus'            # documents: 2
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=5
# page 6 of 7
#   Case: 'V.O.F. AULON'                              # documents: 2
#   Case: 'V.O.F. Bosma Amusement'                    # documents: 2
#   Case: 'Stichting Sport Twente'                    # documents: 4
#   Case: 'Thee- en koffiehuis Kayseri'               # documents: 4
#   Case: 'Eetcafé De Gouw'                           # documents: 4
#   Case: 'Co Gaming Limited (voorheen Come On Europe Limited)'    # documents: 4
#   Case: 'Stichting Trefcentrum Brinkstraat'         # documents: 4
#   Case: 'Imperial E-club Limited'                   # documents: 4
#   Case: 'Stichting Bil Kazan'                       # documents: 4
#   Case: '7Red.com'                              WARNING - no content?
#   Case: 'Villa Mountain View'                       # documents: 4
#   Case: 'GT Beheersorganisatie'                     # documents: 2
#   Case: 'Koffiehuis Vadi'                           # documents: 2
#   Case: 'Gooische Bingo Show'                       # documents: 2
#   Case: 'Globalstars'                               # documents: 4
#   Case: 'Grand Café Randenbroek'                    # documents: 4
#   Case: 'Onisac Limited en Mansion Online Casino Limited'    # documents: 9
#   Case: 'Café Lucky'                                # documents: 4
#   Case: 'Star SAT Electronica'                      # documents: 2
#   Case: 'Call Internet City'                        # documents: 4
# https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/?pager_page=6
# page 7 of 6
#   Case: 'Huizenloterij'                             # documents: 4

# %%
# Each case is a structure like  (case_dict, doc_dicts, will_explain_below),   and currently _incomplete_
extracted_cases[0]
# Out:
# ({'name': 'Gammix Limited',
#   'date_range': [],
#   'money': [],
#   'ecli': [],
#   'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/gammix-limited/'},
#  [{'title': 'Boetebesluit (29 februari 2024)',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/boetebesluit_gammix_limited_29_februari_2024-pdf.pdf',
#    'status': 'Tegen dit besluit is bezwaar gemaakt.'},
#   {'title': 'Openbaarmaking boetebesluit (29 februari 2024)',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/openbaarmakingsbesluit_boetebesluit_gammix_limited-pdf.pdf',
#    'status': 'Tegen dit besluit is bezwaar gemaakt.'},
#   {'title': 'Invorderingsbesluit Gammix Limited (16 februari 2023)',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230216_01-285-641_invorderingsbesluit_gammix.pdf',
#    'status': 'Tegen dit besluit is bezwaar gemaakt.'},
#   {'title': 'Openbaarmakingsbesluit Gammix Limited (16 februari 2023)',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20230216_01-285-642_besluit_openbaarmaking_gammix.pdf',
#    'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.'},
#   {'title': 'Last onder dwangsom Gammix Limited (11 juli 2022)',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220707_01_270_078_-_lod_gammix_ov.pdf',
#    'status': 'In deze zaak is de beslissing op bezwaar genomen. Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.'},
#   {'title': 'Besluit tot openbaarmaking\xa0Gammix Limited (11 juli 2022)',
#    'pdf_url': 'https://kansspelautoriteit.nl/publish/library/32/20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf',
#    'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.'}],
#  [])

# %% [markdown]
# ### Fetch the PDFs, OCR them
#
# What we have is the basic fetched metadata and links to the PDF.
# What we want is the documents as well.
#
# In the below, we do two or three tasks that could be separated:
# - 'fetch PDFs'
# - 'renders page to image to be able to OCR'
# - 'OCRs those images'
# (and later a fourth, 'take the raw OCR output and try to do smart things')
#
# <!-- -->
#
# We could separate these, and that might be preferable for people adapting this code for their own needs,
# yet doing both at once means we don't have to stuff quite as many things in temporary variables,
# and this notebook is single-purpose anyway - it just needs get the job done.
#
# This produces OCR results in a rawer form, namely a list of (text fragments, its positions) and does not use that yet.
# It sets this data on the same data structure (that third tuple item inited as []) - the section below actually uses it.
# Which is perhaps somewhat confusing.
#
# Doing the OCR for a hundred documents takes a few hours, which is why we cache the raw OCR results.

# %%
print( "FETCHing PDFs,  OCRing pages" )

for case_i, case_tuple in wetsuite.helpers.notebook.ProgressBar( enumerate(extracted_cases) ):
    case_dict, case_doc_dicts, _ = case_tuple
    case_name = case_dict['name']

    print('------------------------')
    #print( "ENUM: %s"%case_i)
    print( "NAME: %s"%case_name)
    #print( "DICTS: %s"%pprint.pformat(case_doc_dicts))
    for case_doc_dict in case_doc_dicts:   # for each PDF document in the case
        pdf_url = case_doc_dict['pdf_url']

        print( "== %s =="%wetsuite.helpers.format.url_basename( pdf_url ) )
        pdfbytes, _ = wetsuite.helpers.localdata.cached_fetch( pdfstore, pdf_url )
        doc_page_fragments = [] # list of lists:   [   [page1fragment1,page1fragment2], [page2fragment1,page2fragment2], etc.  ]   

        ## Render PDF images as images
        # (we previously used wetsuite.datacollect.pdf.page_text but found out that wasn't enough)
        page_images = list( wetsuite.extras.pdf.pages_as_images(pdfbytes, dpi=200) )  # TODO: cache these too
        # high DPI and antialiasing does a _little_ better on things like periods and colons, but less than you'ld think.

        ## For each page image, get OCR. This ic cached because this is sloooow, and PDFs are unlikely to change
        for page_i, page_image in enumerate(page_images):
            page_key = 'ocr::%s::%s'%(page_i, pdf_url)

            if page_key in ocrstore:
                #print('     OCR - CACHED  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = json.loads( ocrstore.get(page_key) )
            else: # generate and cache
                print('     OCR - DOING  for page %d of %d'%(page_i+1, len(page_images)))
                page_ocr_results = wetsuite.extras.ocr.easyocr( page_image, use_gpu=True ) # CONSIDER: prefer?

                ocrstore.put( page_key, json.dumps(page_ocr_results).encode('utf8') )

            #page_image.save( '%s__%s__page_%03d.png'%(case_name,  hash(pdfbytes), page_i+1) )
            # DEBUG: Draw OCR results on the page it came from, and save as PNG:
            #eval_image = wetsuite.extras.ocr.easyocr_draw_eval( page_image, page_ocr_results )
            #eval_image.save('%s__%s__page_%03d-boxes.png'%(case_name,  hash(pdfbytes), page_i+1))

            # I think this is here to potentially merge PDF text objects into the same sort of structure. As is it does nothing.
            page_fragments = []   # fragments of text in a page,  which in the case of EasyOCR will typically be lines at a time
            for bbox, text, cert in page_ocr_results:
                page_fragments.append( (bbox, text, cert) ) 
            doc_page_fragments.append( page_fragments ) # yes, this is currently just page_ocr_results, the idea was that the above might augment/simplify that

        extracted_cases[case_i][2].append( doc_page_fragments )
# Out:
# FETCHing PDFs,  OCRing pages
#   0%|          | 0/121 [00:00<?, ?it/s]
# ------------------------
# NAME: Gammix Limited
# == boetebesluit_gammix_limited_29_februari_2024-pdf.pdf ==
# == openbaarmakingsbesluit_boetebesluit_gammix_limited-pdf.pdf ==
# == 20230216_01-285-641_invorderingsbesluit_gammix.pdf ==
# == 20230216_01-285-642_besluit_openbaarmaking_gammix.pdf ==
# == 20220707_01_270_078_-_lod_gammix_ov.pdf ==
# == 20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf ==
# ------------------------
# NAME: Hillside New Media Malta Plc
# == 15402_01-304-549_beslissing_op_bezwaar.pdf ==
# == 15402_bac_advies_hillside.pdf ==
# == 15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf ==
# == 15402_01-285-941_besluit-signed_openbare_versie.pdf ==
# ------------------------
# NAME: Betent B.V.
# == 15998_01-302-172_betent_sanctiebesluit_openbaar.pdf ==
# ------------------------
# NAME: Cloudflare
# == besluit_bindende_aanwijzing_20231103_01-302-244.pdf ==
# == besluit_obm_woo_ba_cloudflare_20231103_01-302-246.pdf ==
# ------------------------
# NAME: Cloudflare
# == besluit_bindende_aanwijzing_cloudflare_20231016_01-302-181.pdf ==
# == besluit_openbaarmaking_woo_bindende_aanwijzing_cloudflare_20231016_01-302-184.pdf ==
# ------------------------
# NAME: Holland Casino
# == 20231026_01-293-519_openbare_versie_besluit_bindende_aanwijzing_hc_cdb_1.pdf ==
# == 20231026_01-293-518_openbare_versie_openbaarmakingsbesluit_bindende_aanwijzing_hc_cdb_002_.pdf ==
# == 16369-01-305-776_hc_bob_aanwijzing.pdf ==
# == 16369_besluit_openbaarmaking_bob_hc.pdf ==
# ------------------------
# NAME: Betent
# == 15403_01-301-226_beslissing_op_bezwaar_betent.pdf ==
# == 15403_01-301-226_openbaarmakingsbesluit_woo_bob_ov.pdf ==
# == 15403_01-300-884_bac_advies_betent.pdf ==
# == betent_15403_sanctiebesluit.pdf ==
# == 15403_01-301-226_openbaarmakingsbesluit_betent.pdf ==
# ------------------------
# NAME: Bingoal Nederland B.V.
# == beslissing_op_bezwaar_bingoal.pdf ==
# == openbaarmakingsbesluit_bingoal_woo_bob.pdf ==
# == bac_advies_bingoal.pdf ==
# == 01-288-556_15404_sanctiebesluit_bingoal.pdf ==
# == 15404_bingoal_openbaarmakingsbesluit_002_.pdf ==
# ------------------------
# NAME: Vriendenloterij N.V.
# == bob_lod_vl_openbare_versie.pdf ==
# == besluit_openbaarmaking_bob_vl_openbare_versie.pdf ==
# == 20230523_01-291-294_openbaar_besluit_last_onder_dwangsom_vl_spellen.pdf ==
# == 20230523_01-291-296_openbare_versie_openbaarmakingsbesluit_woo_vl_last.pdf ==
# ------------------------
# NAME: Nationale Postcode Loterij N.V.
# == bob_lod_npl_openbare_versie.pdf ==
# == besluit_openbaarmaking_bob_npl_openbare_versie.pdf ==
# == 20230523_01-291-288_openbaar_besluit_last_onder_dwangsom_npl_spellen.pdf ==
# == 20230523_01-291-290_openbare_versie_openbaarmakingsbesluit_woo_npl_last.pdf ==
# ------------------------
# NAME: GoldWin Limited
# == 16442_boetebesluit_goldwin.pdf ==
# == 16442_01-299-883_openbaarmakingsbesluit_goldwin.pdf ==
# ------------------------
# NAME: MKC Limited
# == 16402_boetebesluit_mkc_limited.pdf ==
# == 16402_01-299-881_openbaarmakingsbesluit_mkc_limited.pdf ==
# ------------------------
# NAME: Blue High House S.A.
# == 20230929_01-296-617_besluit_lod_1a_blue_high_house_s-a-.pdf ==
# == 20230929_01-296-618_besluit_openbaarmaking_woo_blue_high_house_s-a-.pdf ==
# ------------------------
# NAME: L.C.S Limited
# == sanctiebesluit_lcs_limited.pdf ==
# == besluit_openbaarmaking_lcs_limited.pdf ==
# == 20220817_01_265_500_-_besluit_lod_sons-of-slots_ov.pdf ==
# == 20220817_01_265_499_-_besluit_openbaarmaking_ov.pdf ==
# ------------------------
# NAME: JOI Gaming Ltd
# == ov_beslissing_op_bezwaar_joi_gaming_limited.pdf ==
# == ov_openbaarmakingsbesluit_woo_bob_joi_gaming_limited.pdf ==
# == ov_bac_advies_joi_gaming_limited.pdf ==
# == sanctiebesluit_joi_gaming_ltd_10_januari_2023_.pdf ==
# == openbaarmakingsbesluit_joi_gaming_ltd.pdf ==
# ------------------------
# NAME: Play North Limited
# == 20230831_01-292-391_aanwijzing_pn_ov.pdf ==
# == 20230619_01-292-392_besluit_op_bezwaar_pn_ov.pdf ==
# ------------------------
# NAME: Betent
# == 20230831_01-292-887_aanwijzing_betent_ov.pdf ==
# == 20230831_01-292-888_besluit_op_bezwaar_ov.pdf ==
# ------------------------
# NAME: NetX Betting
# == besluit_lod_1a_netx_betting_limited_ov_.pdf ==
# == besluit_openbaarmaking_ov_.pdf ==
# ------------------------
# NAME: GoldWin Ltd
# == 20230420_01-291-425_besluit_lod_goldwin_ltd_ov_.pdf ==
# == 20230420_01-191-426_besluit_openbaarmaking_ov_.pdf ==
# ------------------------
# NAME: Merkur Casino Almere B.V.
# == 01-289-330_15484_sanctiebesluit_ov.pdf ==
# == 01-289-336_15484_openbaarmakingsbesluit_woo_ov.pdf ==
# ------------------------
# NAME: Winning Poker Network
# == 20230228_01-285-044_lod_openbare_versie_beveiligd.pdf ==
# == 20220228_01-287-832_besluit_openbaarmaking_openbare_versie_beveiligd.pdf ==
# ------------------------
# NAME: Red Ridge Marketing
# == 01-286-861_15395_sanctiebesluit_ov.pdf ==
# == 15395_openbaarmakingsbesluit_ov.pdf ==
# ------------------------
# NAME: Probe Investments Limited
# == 15269_01-294-564_beslissing_op_bezwaar_ov.pdf ==
# == 15269_01-294-565_openbaarmakingsbesluit_woo_bob_ov.pdf ==
# == 15269_01-293-484_bac_advies_ov.pdf ==
# == 15269_01-281-231_sanctiebesluit_probe_investments_limited_ov.pdf ==
# == 15269_01-281-234_besluit_openbaarmaking_probe_investments_limited_ov.pdf ==
# ------------------------
# NAME: Betpoint Group Limited
# == ov_15164_01-281-226_sanctiebesluit_betpoint.pdf ==
# == ov_15164_01-281-229_betpoint_openbaarmaking.pdf ==
# ------------------------
# NAME: N1 Interactive Limited
# == 01-292-870-beslissing_op_bezwaar_15244_ov.pdf ==
# == 01-292-895_besluit_openbaarmaking_15244_ov.pdf ==
# == 15244_01-291-871_bac_advies_ov_1.pdf ==
# == 01-281-253_sanctiebesluit_15244_ov.pdf ==
# == 01-281-256_openbaarmakingbesluit_15244_ov.pdf ==
# ------------------------
# NAME: Videoslots Limited
# == 15167_01-281-259_sanctiebesluit_videoslots_ov.pdf ==
# == 01-281-262_openbaarmakingsbesluit_videoslots_ov.pdf ==
# ------------------------
# NAME: Fairload Limited
# == 15151_01-294-550_beslissing_op_bezwaar-ov.pdf ==
# == 15151_01-294-553-openbaarmakingsbesluit_woo_bob_ov.pdf ==
# == 15151_bac_advies_ov.pdf ==
# == 15151_ov_fairload_sanctiebesluit_def.pdf ==
# == 15151_01-281-217_ov_fairload_openbaarmaking.pdf ==
# ------------------------
# NAME: Equinox Dynamic N.V. & Domiseda and Partners s.r.o.
# == 01-281-220_sanctiebesluit_2022_openbaar.pdf ==
# == openbaarmakingsbesluit_equinox_dynamic_domiseda.pdf ==
# == 15255_01-293-635_beslissing_op_bezwaar_ov.pdf ==
# == 15255_01-293-637_bac_advies_def_ov.pdf ==
# == 01-293-636_openbaarmakingsbesluit_woo_bob_15255_ov.pdf ==
# ------------------------
# NAME: Bingoal Nederland B.V.
# == sanctiebesluit_bingoal_8_febrauri_2023.pdf ==
# == openbaarmakingsbesluit_bingoal_8_februari_2023.pdf ==
# == 01-289-608_advies_bac_bingoal_nederland_b-v_ov.pdf ==
# == 01-289-607_openbaarmakingsbesluit_ov.pdf ==
# ------------------------
# NAME: Shark77.Ltd
# == beslissing_op_bezwaar_ov.pdf ==
# == openbaarmakingsbesluit_woo_bob_ov.pdf ==
# == advies_bac_shark77_ov.pdf ==
# == sanctiebesluit_shark77.pdf ==
# == openbaarmakingsbesluit_shark77.pdf ==
# ------------------------
# NAME: Holland Casino N.V.
# == 01_252_792_lod_hc.pdf ==
# == 01_252_795_openbaarmakingsbesluit.pdf ==
# == 01_263_938_bob_lod_hc.pdf ==
# == 01_263_939_besluit_openbaarmaking_beslissing_op_bezwaar_holland_casino_n_v.pdf ==
# == 01_264_668_invorderingsbeschikking_lod_hc.pdf ==
# == 01_268_588_besluit_tot_openbaarmaking_holland_casino_n_v.pdf ==
# ------------------------
# NAME: Toto Online B.V.
# ------------------------
# NAME: Nationale Postcode Loterij N.V.
# == sanctiebesluit_npl.pdf ==
# == openbaarmakingsbesluit_npl.pdf ==
# ------------------------
# NAME: M.K.C Limited
# == 20220823_01_265_505_-_besluit_last_onder_dwangsom_ov.pdf ==
# == 20220823_01_265_507_-_besluit_openbaarmaking_ov.pdf ==
# ------------------------
# NAME: Red Ridge Marketing
# == 20220412_01_263_969_besluit_lod_ov_1.pdf ==
# == 20220412_01_263_968_besluit_openbaarmaking_wob_ov_1.pdf ==
# == 20230323_01-288-427_invorderingsbesluit_ov.pdf ==
# == 20230324_01-288-428_besluit_openbaarmaking_woo_invordering_ov.pdf ==
# ------------------------
# NAME: Performing Media Limited
# == last_onder_dwangsom_performing_media_limited.pdf ==
# == besluit_tot_openbaarmaking_performing_media_limited.pdf ==
# ------------------------
# NAME: Linkerik B.V.
# == besluit_last_onder_dwangsom_14508.pdf ==
# == besluit_openbaarmaking_14508.pdf ==
# == invorderingsbesluit_linkerik_b-v_ov_.pdf ==
# == besluit_openbaarmaking_linkerik_b-v-ov_.pdf ==
# ------------------------
# NAME: Onlinecasinobonus.nl
# == last_onder_dwangsom_onlinecasinobonus_nl.pdf ==
# == besluit_openbaarmaking_onlinecasinobonus_nl.pdf ==
# ------------------------
# NAME: LCB CORP
# == lcb_corp_lod_20211213_01_252_632_lod_nl_lcb_org_ov.pdf ==
# == lcb_corp_besluit_openbaarmaking_20211213_01_252_633.pdf ==
# ------------------------
# NAME: Casinoscout.nl
# == casinoscout_nl_besluit_openbaarmaking_ov.pdf ==
# == casinoscout_nl_lod.pdf ==
# ------------------------
# NAME: Slots Dev
# == last_onder_dwangsom_slots_dev.pdf ==
# == besluit_openbaarmaking_slots_dev.pdf ==
# ------------------------
# NAME: Online Casino Ground ltd
# == last_onder_dwangsom_online_casino_ground_ltd.pdf ==
# == besluit_openbaarmaking_online_casino_ground_ltd.pdf ==
# ------------------------
# NAME: Tipico Co. Ltd
# == besluit_tipico_openbaar.pdf ==
# == openbaarmakingsbesluit_tipico_openbaar.pdf ==
# ------------------------
# NAME: BSB Shop
# == besluit_last_onder_dwangsom_bsb_shop.pdf ==
# == besluit_openbaarmaking_bsb_shop.pdf ==
# ------------------------
# NAME: Luxury Bingo
# == besluit_lxury_bingo.pdf ==
# == besluit_openbaarmaking_luxery_bingo.pdf ==
# ------------------------
# NAME: N1 Interactive Limited
# == beslissing_op_bezwaar_n1_interactive_ltd.pdf ==
# == besluit_openbaarmaking_n1_interactive_ltd.pdf ==
# == bac_advies_n1_interactive_ltd.pdf ==
# == besluit_n1_interactive_limited_ov.pdf ==
# == openbaarmakingsbesluit_interactive_limited.pdf ==
# ------------------------
# NAME: Staatsloterij B.V.
# == 20220118_-_01_256_290_intrekkingsbesluit.pdf ==
# == 20220224_-_01_258_184_openbaarmakingsbesluit_intrekkingsbesluit.pdf ==
# == sanctiebesluit_staatsloterij.pdf ==
# == besluit_tot_openbaarmaking_staatsloterij.pdf ==
# ------------------------
# NAME: Raging Rhino N.V.
# == sanctiebesluit_raging_rhino_n_v.pdf ==
# == besluit_tot_openbaarmaking_raging_rhino_n_v.pdf ==
# ------------------------
# NAME: Lovelto Mar LTD
# == 01_237_092_-_invorderingsbeschikking_ov.pdf ==
# == 01_237_093_-_besluit_openb_invorderingsbeschikking_ov.pdf ==
# == lod_ov.pdf ==
# == 01_077_647_-_besluit_openbaarmaking_-_ov_1.pdf ==
# ------------------------
# NAME: 1X Corp N.V._Exinvest Limited
# == 12924_advies_bac_ov.pdf ==
# == 12924_besluit_openbaarmaking_bob_ov.pdf ==
# == 12924_-_01_047_552_sanctiebesluit_-_openbare_versie_met_logo_1.pdf ==
# == 12924_-_01_047_553_openbaarmakingsbesluit_-_openbare_versie_met_logo_1.pdf ==
# ------------------------
# NAME: WL Deal
# == 01_079_482_besluit_lod_wl_deal_openbaar.pdf ==
# == 01_079_484_besluit_openbaarmaking_lod_wl_deal_openbaar.pdf ==
# ------------------------
# NAME: Virtual Coin Gaming N.V.
# == besluit_op_bezwaar_virtual_coin_gaming.pdf ==
# == advies_van_de_adviescommissie_bezwaarschriften.pdf ==
# == besluit_openbaarmaking_virtual_coin_gaming.pdf ==
# == besluit_openbaarmaking_betalingsweigering_virtual_coin_gaming_n_v.pdf ==
# == sanctiebesluit_futgalaxy_openbaar.pdf ==
# == besluit_openbaarmaking_futgalaxy_openbaar.pdf ==
# ------------------------
# NAME: Clipboard Publications B.V.
# == 20200806_01_073_790_lod_bevorderen_ov.pdf ==
# == 20200806_01_073_815_besluit_openbaarmaking_ov_1.pdf ==
# ------------------------
# NAME: Kelner Automaten Service
# ------------------------
# NAME: Schinveld BV
# == beslissing_op_bezwaar.pdf ==
# == advies_bac.pdf ==
# == besluit_openbaarmaking_schinveld_bv.pdf ==
# == sanctiebesluit_schinveld_bv.pdf ==
# == openbaarmakingsbesluit_schinveld_bv.pdf ==
# ------------------------
# NAME: Voormalig exploitant Dordrecht
# == 01_066_052_besluit_lob_openbaar.pdf ==
# == 01_066_053_besluit_openbaarmaking_lob_openbaar.pdf ==
# ------------------------
# NAME: Voormalig exploitant Amersfoort
# == 01_062_613_besluit_lob_openbaar.pdf ==
# == 01_062_614_besluit_openbaarmaking_lob_openbaar.pdf ==
# ------------------------
# NAME: Royal Panda Limited
# == 13384_002_beslissing_op_bezwaar_ov.pdf ==
# == 13384_002_bac_advies_ov.pdf ==
# == 13384_002_besluit_openbaarmaking_ov.pdf ==
# == sanctiebesluit_rp_openbaar_1.pdf ==
# == openbaarmakingsbesluit_rp.pdf ==
# ------------------------
# NAME: LeoVegas Gaming p.l.c.
# == 13385_002_beslissing_op_bezwaar_ov_002.pdf ==
# == 13385_002_bac_advies_ov_002_2.pdf ==
# == sanctiebesluit_lv_openbaar_002.pdf ==
# == openbaarmaking_lv_openbaar.pdf ==
# ------------------------
# NAME: Pokerstars
# == 13366_-_bob_-_pokerstars_ov.pdf ==
# == 13366_bac-advies_pokerstars_ov.pdf ==
# == 13366_-_besluit_openbaarmaking_bob_-_pokerstars_ov.pdf ==
# == besluit_pokerstars.pdf ==
# == openbaarmakingsbesluit_pokerstars.pdf ==
# ------------------------
# NAME: Chance Publications Malta Ltd
# == invorderingsbeschikking.pdf ==
# == 01_061_945_last_onder_dwangsom_openbare_versie.pdf ==
# == 01_061_946_besluit_openbaarmaking_lod_openbare_versie.pdf ==
# ------------------------
# NAME: Unibet
# == 13365_sanctie_besluit_ov.pdf ==
# == 13365_openbaarmakingsbesluit_ov.pdf ==
# ------------------------
# NAME: Bwin
# == 13367_001_01_067_148_openbare_versie_beslissing_op_bezwaar.pdf ==
# == 13367_001_01_064_921_bac-advies-_openbaar.pdf ==
# == 13367_002_01_067_145_besluit_openbaarmaking_bob-_openbaar.pdf ==
# == 13367_-_sanctiebesluit_bwin_openbare_versie.pdf ==
# == 13367_-_besluit_openbaarmaking_bwin_openbare_versie.pdf ==
# ------------------------
# NAME: Simbat Entertainment Systems en Spinity
# == besluit_openbaarmaking_betalingsweigering_simbat_openbaar.pdf ==
# == besluit_openbaarmaking_betalingsweigering_spinity.pdf ==
# == 03_10474_besluit_op_bezwaar_openbare_versie_1.pdf ==
# == 07_10474_openbaarmaking_bob_openbare_versie.pdf ==
# == 06_10474_bijlage_2_bij_het_advies_openbare_versie.pdf ==
# == 01_10474_sanctiebesluit_openbare_versie_1.pdf ==
# == 02_10474_-_openbaarmakingsbesluit_openbare_versie.pdf ==
# ------------------------
# NAME: Com Coin Operated Machines
# == besluit_last_onder_dwangsom.pdf ==
# == besluit_openbaarmaking_lod.pdf ==
# ------------------------
# NAME: Casumo
# == 13078_besluit_op_bezwaar_ov.pdf ==
# == 13078_-_advies_bac_casumo_ov.pdf ==
# == 13078_bombob_ov.pdf ==
# == 13878_-_sanctiebesluit.pdf ==
# == 13078_-_openbaarmakingsbesluit.pdf ==
# ------------------------
# NAME: Innovation Labs en Gaming Innovation Group
# == openbaar_-_last_onder_dwangsom_ill.pdf ==
# == openbaar_-_last_onder_dwangsom_gig.pdf ==
# == openbaar_-_besluit_openbaarmaking_last_onder_dwangsom_ill.pdf ==
# == openbaar_-_besluit_openbaarmaking_last_onder_dwangsom_gig.pdf ==
# == openbaar_-_beslissing_op_bezwaar_ill_en_gig.pdf ==
# == openbaar_-_besluit_tot_openbaarmaking_van_de_beslissing_op_bezwaar_ill_en_gig.pdf ==
# ------------------------
# NAME: Content Publishing Limited
# == uitspraak_rechtbank_den_haag_van_10_januari_2019.pdf ==
# == primair_besluit_tot_oplegging_last_onder_dwangsom_1.pdf ==
# == openbaarmakingsbesluit_van_het_primaire_besluit.pdf ==
# == besluit_op_het_bezwaar_tegen_de_last_onder_dwangsom.pdf ==
# == openbaarmakingsbesluit_van_de_beslissing_op_bezwaar.pdf ==
# ------------------------
# NAME: Exploiteren zonder vergunning in café
# == besluit_01_047_464.pdf ==
# == besluit_tot_openbaarmaking_13052.pdf ==
# == 01_037_509_besluit_last_onder_bestuursdwang.pdf ==
# == 01_037_510_besluit_openbaarmaking.pdf ==
# ------------------------
# NAME: WHG (International) Limited
# == 12920_besluit_openbaarmaking_openbaar.pdf ==
# == 12920_bac_advies_whg_openbaar.pdf ==
# == 12920_bac_advies_whg_openbaar.pdf ==
# == sanctiebesluit_whg.pdf ==
# == openbaarmakingsbesluit_whg.pdf ==
# ------------------------
# NAME: Voormalig exploitant Abcoude
# == 01_044_953_besluit_last_onder_bestuursdwang_openbaar.pdf ==
# == 01_044_954_besluit_openbaarmaking_lob_openbaar.pdf ==
# ------------------------
# NAME: CyberRock Entertainment N.V. en Honeydew Trading Limited.
# == besluit_openbaarmaking_betalingsweigering_cyberrock_honeydew_ov.pdf ==
# == 12863_beslissing_op_bezwaar_cyberrock.pdf ==
# == 12863_advies_van_de_commissie.pdf ==
# == 13324_besluit_tot_openbaarmaking_bob_cyber_rock.pdf ==
# == 12863_-_sanctiebesluit_docx.pdf ==
# == 12863_besluit_tot_openbaarmaking.pdf ==
# ------------------------
# NAME: Mr Green Limited
# == beslissing_op_bezwaar_mr_green_1.pdf ==
# == besluit_openbaarmaking_beslissing_op_bezwaar.pdf ==
# == sanctiebesluit_mr_green.pdf ==
# == besluit_tot_openbaarmaking_mr_green.pdf ==
# ------------------------
# NAME: ITC Lounge Plaza
# == sanctiebesluit_itc_lounge_plaza.pdf ==
# == besluit_tot_openbaarmaking_itc_lounge_plaza.pdf ==
# ------------------------
# NAME: Corona Limited
# == beslissing_op_bezwaar_corona.pdf ==
# == besluit_openbaarmaking_bob_corona.pdf ==
# == 12517_-_sanctiebesluit_ov_def_def.pdf ==
# == 12517_-_openbaarmakingsbesluit_ov.pdf ==
# ------------------------
# NAME: Café restaurant De Kruik
# == last_onder_dwangsom_cafe_restaurant_de_kruik.pdf ==
# == besluit_openbaarmaking_cafe_restaurant_de_kruik.pdf ==
# ------------------------
# NAME: Bet-at-home
# == 20190103-01_048_080_besluit_op_bezwaar.pdf ==
# == 20190103-01_048_077_besluit_tot_openbaarmaking.pdf ==
# == sanctiebesluit_bet-at-home.pdf ==
# == besluit_tot_openbaarmaking_bet-at-home.pdf ==
# ------------------------
# NAME: Visionairy iGaming
# == openbaarmakingsbesluit_v_i_g_openbaar.pdf ==
# == openbaarmakingsbesluit_bestuurder_openbaar.pdf ==
# == sanctiebesluit_visionairy_igaming.pdf ==
# == besluit_tot_openbaarmaking_visionairy_igaming.pdf ==
# ------------------------
# NAME: VriendenLoterij N.V.
# == besluit_intrekken_lod_2.pdf ==
# == besluit_openbaarmaking_intrekking_lod_2.pdf ==
# == besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf ==
# == besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf ==
# == last_onder_dwangsom_vriendenloterij_n_v.pdf ==
# == openbaarmaking_last_onder_dwangsom_vriendenloterij_n_v.pdf ==
# == besluit_last_onder_dwangsom_gdl.pdf ==
# == besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf ==
# ------------------------
# NAME: BankGiro Loterij N.V.
# == besluit_intrekken_lod_1.pdf ==
# == besluit_openbaarmaking_intrekking_lod_1.pdf ==
# == besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf ==
# == besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf ==
# == last_onder_dwangsom_bankgiro_loterij_n_v.pdf ==
# == openbaarmaking_last_onder_dwangsom_bankgiro_loterij_n_v.pdf ==
# == besluit_last_onder_dwangsom_gdl.pdf ==
# == besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf ==
# ------------------------
# NAME: Nationale Postcode Loterij N.V.
# == besluit_intrekken_lod.pdf ==
# == besluit_openbaarmaking_intrekking_lod.pdf ==
# == 190520-01_056_018-01_057_548_invorderingsbeschikking_-_npl_-_openbaar.pdf ==
# == 190520-01_056_019-01_057_549_besluit_openbaarmaking_invorderingsbeschikking_-_npl_-_openbaar.pdf ==
# == besluit_op_bezwaar_last_onder_dwangsom_npl_bgl_en_vl.pdf ==
# == besluit_tot_openbaarmaking_bob_npl_bgl_en_vd.pdf ==
# == last_onder_dwangsom_nationale_postcode_loterij_n_v.pdf ==
# == openbaarmaking_last_onder_dwangsom_nationale_postcode_loterij_n_v.pdf ==
# == besluit_last_onder_dwangsom_gdl.pdf ==
# == besluit_openbaarmaking_last_onder_dwangsom_gdl.pdf ==
# ------------------------
# NAME: Lotto B.V.
# == 20220901_-_01_272_228_openbare_versie_besluit_opheffen_last_lotto.pdf ==
# == 20220901_-_01_273_365_besluit_tot_openbaarmaking_opheffing_lod_van_19-10-2017.pdf ==
# == 20211025_-_01_249_821_openbare_versie_invorderingsbeschikking_toto_def_002.pdf ==
# == openbaarmakingsbesluit_lotto_11.pdf ==
# == invorderingsbeschikking_lotto.pdf ==
# == openbaarmakingsbesluit_lotto.pdf ==
# == 01_047_588_-_01_046_119_invorderingsbeschikking_-_lotto_-_def_openbaar_002.pdf ==
# == 01_047_589_besluit_openbaarmaking_invorderingsbeschikking_-_lotto_-_def_openbaar_002.pdf ==
# == besluit_op_bezwaar_last_onder_dwansom_staatsloterij_en_lotto.pdf ==
# == besluit_tot_openbaarmaking_bob_staatloterij_en_lotto.pdf ==
# == last_onder_dwangsom_lotto_b_v.pdf ==
# == openbaarmaking_last_onder_dwangsom_lotto_b_v.pdf ==
# ------------------------
# NAME: Staatsloterij B.V.
# == 20220114_-_01_255_681_openbare_versie_besluit_opheffen_last_staatsloterij.pdf ==
# == 20220114_-_01_255_680_openbaarmakingsbesluit_staatsloterij.pdf ==
# == 01_047_590_-_01_046_120_invorderingsbeschikking_-_staatsloterij_-_def_openbaar.pdf ==
# == 01_049_931_besluit_openbaarmaking_invorderingsbeschikking_-_staatsloterij_-_def_openbaar.pdf ==
# == besluit_op_bezwaar_last_onder_dwansom_staatsloterij_en_lotto.pdf ==
# == besluit_tot_openbaarmaking_bob_staatloterij_en_lotto.pdf ==
# == last_onder_dwangsom_staatsloterij_b_v.pdf ==
# == openbaarmaking_last_onder_dwangsom_staatsloterij_b_v.pdf ==
# ------------------------
# NAME: Holland Casino N.V.
# == 20220114_-_01_255_682_openbare_versie_besluit_tot_opheffen_last_holland_casino.pdf ==
# == 20220114_-_01_255_677_openbaarmakingsbesluit_hc.pdf ==
# == last_onder_dwangsom_holland_casino.pdf ==
# == openbaarmaking_last_onder_dwangsom_holland_casino.pdf ==
# ------------------------
# NAME: Catena Operations Limited
# == besluit_last_onder_dwangsom_catena_operations_limited.pdf ==
# == besluit_openbaarmaking_last_onder_dwangsom_catena_operations_limited.pdf ==
# ------------------------
# NAME: Weddenopvoetbal.org
# == 10762_-_01_022_342_en_10868_-_01_022_343_besluit_op_bezwaar_openbaar.pdf ==
# == 10762_-_01_022_344_en_10868_-_01_022_345_besluit_tot_openbaarmaking_openbaar.pdf ==
# == besluit_tot_openbaarmaking_besluit_op_bezwaar_weddenopvoetbal_org.pdf ==
# == besluit_last_onder_dwangsom_weddenopvoetbal_org.pdf ==
# ------------------------
# NAME: JvG speelautomaten
# == besluit_last_onder_dwangsom_jvg_amusement_vending_b_v.pdf ==
# == openbaarmakingsbesluit_jvg_amusement_bending_b_v.pdf ==
# ------------------------
# NAME: Trustfulgames.com Limited
# == besluit_openbaarmaking_betalingsweigering_trustfulgames.pdf ==
# == besluit_openbaarmaking_betalingsweigering_bestuurder_1.pdf ==
# == besluit_openbaarmaking_betalingsweigering_bestuurder_2.pdf ==
# == 10507_-_sanctiebesluit_adviescommissie_003.pdf ==
# == 10507_-_besluit_tot_openbaarmaking_003.pdf ==
# == sanctiebesluit_trustfulgames.pdf ==
# == besluit_tot_openbaarmaking_trustfulgames.pdf ==
# ------------------------
# NAME: L.S.A. B.V
# == ecli_nl_rvs_2019_11_uitspraak_inzake_lob_lsa_bv.pdf ==
# == besluit_tot_openbaarmaking.pdf ==
# == besluit_last_onder_bestuursdwang_02112016_geanonimiseerd.pdf ==
# == besluit_openbaarmaking_-_openbare_versie_op_briefpapier.pdf ==
# ------------------------
# NAME: M-automaten exploitatie
# == 00_082_720_openbare_versie_last_onder_bestuursdwang.pdf ==
# == 00_082_721_openbare_versie_besluit_tot_opehbaarmaking.pdf ==
# ------------------------
# NAME: Wedwinkel Rotterdam
# == sanctiebesluit_wedwinkel.pdf ==
# == openbaarmakingsbesluit_wedwinkel.pdf ==
# ------------------------
# NAME: Friese ondernemer
# == besluit_last_onder_bestuursdwang.pdf ==
# ------------------------
# NAME: Holland Gaming
# == besluit_op_bezwaar_holland_gaming.pdf ==
# == besluit_tot_openbaarmaking_holland_gaming.pdf ==
# ------------------------
# NAME: Olders Amusementsautomaten B.V.
# == besluit_last_bestuursdwang_-_olders_amusementsautomaten_bv_-_geanonimiseerde_versie_voor_publicatie.pdf ==
# ------------------------
# NAME: Duitse loterijen
# == 10072_-_00_071_137_en_10136_-_00_071_138_besluit_openbaar.pdf ==
# == 10072_-_00_071_140_en_10136_-_00_071_141_besluit_openbaarmaking_openbaar.pdf ==
# ------------------------
# NAME: Dolle Pret in Almelo B.V.
# == last_onder_dwangsom_dolle_pret_in_almelo.pdf ==
# == besluit_tot_openbaarmaking_dolle_pret_in_almelo.pdf ==
# ------------------------
# NAME: Redslots
# == besluit_openbaarmaking_betalingsweigering_bluemay_enterprises_n_v_-_red.pdf ==
# == besluit_tot_openbaarmaking_bob_redslots.pdf ==
# == sanctiebesluit_redslots.pdf ==
# == besluit_tot_openbaarmaking_redslots.pdf ==
# ------------------------
# NAME: Café _ Bar Bağci
# == besluit_op_bezwaar_cafe_-_bar_bagci.pdf ==
# == besluit_tot_openbaarmaking_cafe_-_bar_bagci_2.pdf ==
# == sanctiebesluit_cafe_-_bar_bagci.pdf ==
# == besluit_tot_openbaarmaking_cafe_-_bar_bagci.pdf ==
# ------------------------
# NAME: Total E Soft Limited en XKL Limited
# == besluit_op_bezwaar_total_e_soft.pdf ==
# == besluit_tot_openbaarmaking_total_e_soft.pdf ==
# == sanctiebesluit_total_e_soft_limited_en_xkl_limited.pdf ==
# == besluit_tot_openbaarmaking_total_e_soft_limited_en_xkl_limited.pdf ==
# ------------------------
# NAME: Belhuis _ Internetcafé Ephesus
# == sanctiebesluit_belhuis_-_internetcafe_ephesus.pdf ==
# == besluit_tot_openbaarmaking_belhuis_-_internetcafe_ephesus.pdf ==
# ------------------------
# NAME: V.O.F. AULON
# == besluit_v_o_f_aulon.pdf ==
# == besluit_tot_openbaarmaking_v_o_f_aulon.pdf ==
# ------------------------
# NAME: V.O.F. Bosma Amusement
# == besluit_v_o_f_bosma_amusement.pdf ==
# == besluit_tot_openbaarmaking_v_o_f_bosma_amusement.pdf ==
# ------------------------
# NAME: Stichting Sport Twente
# == sanctiebesluit_stichting_sport_twente.pdf ==
# == besluit_tot_openbaarmaking_stichting_sport_twente.pdf ==
# == besluit_op_bezwaar_stichting_sport_twente.pdf ==
# == besluit_tot_openbaarmaking_stichting_sport_twente_2.pdf ==
# ------------------------
# NAME: Thee- en koffiehuis Kayseri
# == besluit_op_bezwaar_kayseri.pdf ==
# == besluit_tot_openbaarmaking_kayseri.pdf ==
# == sanctiebesluit_thee-_en_koffiehuis_kayseri.pdf ==
# == besluit_tot_openbaarmaking_thee-_en_koffiehuis_kayseri.pdf ==
# ------------------------
# NAME: Eetcafé De Gouw
# == besluit_op_bezwaar_eetcafe_de_gouw.pdf ==
# == besluit_openbaarmaking_eetcafe_de_gouw.pdf ==
# == sanctiebesluit_eetcafe_de_gouw_1.pdf ==
# == besluit_tot_openbaarmaking_eetcafe_de_gouw_1.pdf ==
# ------------------------
# NAME: Co Gaming Limited (voorheen Come On Europe Limited)
# == besluit_op_bezwaar_co_gaming_limited.pdf ==
# == besluit_tot_openbaarmaking_co_gaming_limited.pdf ==
# == 1_sanctiebesluit_come_on.pdf ==
# == besluit_tot_openbaarmaking_come_on.pdf ==
# ------------------------
# NAME: Stichting Trefcentrum Brinkstraat
# == besluit_op_bezwaar_stichting_trefcentrum_brinkstraat.pdf ==
# == besluit_openbaarmaking_stichting_trefcentrum_brinkstraat.pdf ==
# == sanctiebesluit_stichting_trefcentrum_brinkstraat.pdf ==
# == besluit_tot_openbaarmaking_stichting_trefcentrum_brinkstraat.pdf ==
# ------------------------
# NAME: Imperial E-club Limited
# == besluit_op_bezwaar_imperial_e-club_limited.pdf ==
# == besluit_tot_openbaarmaking_bob_imperial_e-club_limited.pdf ==
# == sanctiebesluit_imperial_e-club_limited.pdf ==
# == besluit_tot_openbaarmaking_imperial_e-club_limited.pdf ==
# ------------------------
# NAME: Stichting Bil Kazan
# == besluit_op_bezwaar_stichting_bil_kazan.pdf ==
# == 7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf ==
# == sanctiebesluit_stichting_biil_kazan_1.pdf ==
# == besluit_tot_openbaarmaking_stichting_bil_kazan_1.pdf ==
# ------------------------
# NAME: 7Red.com
# ------------------------
# NAME: Villa Mountain View
# == besluit_op_bezwaar_villa_mountain_view.pdf ==
# == besluit_tot_openbaarmaking_villa_mountain_view.pdf ==
# == sanctiebesluit_villa_mountain_view.pdf ==
# == besluit_openbaarmaking_villa_mountain_view.pdf ==
# ------------------------
# NAME: GT Beheersorganisatie
# == sanctiebesluit_gt_beheersorganisatie.pdf ==
# == besluit_tot_openbaarmaking_gt_beheersorganisatie.pdf ==
# ------------------------
# NAME: Koffiehuis Vadi
# == sanctiebesluit_koffiehuis_vadi_-_openbaar.pdf ==
# == besluit_tot_openbaarmaking_koffiehuis_vadi_-_openbaar.pdf ==
# ------------------------
# NAME: Gooische Bingo Show
# == 8090_-_00_023_231_sanctiebesluit_gooische_bingo_show.pdf ==
# == 8090_-_00_023_232_openbaarmakingsbesluit_gooische_bingo_show.pdf ==
# ------------------------
# NAME: Globalstars
# == 7822_sanctiebesluit_globalstars.pdf ==
# == 7822_besluit_openbaarmaking_globalstars.pdf ==
# == 7822_-_00_019_152_besluit_op_bezwaar_inclusief_advies_bac_-_openbare_versie.pdf ==
# == 7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf ==
# ------------------------
# NAME: Grand Café Randenbroek
# == besluit_op_bezwaar_openbaar_cafe_randenbroek.pdf ==
# == besluit_openbaarmaking_bob_openbaar_cafe_randenbroek.pdf ==
# == 7861_sanctiebesluit_grand_cafe_randenbroek.pdf ==
# == 7861_besluit_openbaarmaking_grand_cafe_randenbroek.pdf ==
# ------------------------
# NAME: Onisac Limited en Mansion Online Casino Limited
# == 190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf ==
# == 190704_bob_en_bac.pdf ==
# == sanctiebesluit_onisac.pdf ==
# == openbaarmakingsbesluit_sanctiebesluit_onisac.pdf ==
# == 7845_00_021_663_-_sanctiebesluit_openbaar.pdf ==
# == 7845_00_021_664-_openbaarmaking_openbaar.pdf ==
# == 7845_-_advies_bac_ov_pdf.pdf ==
# == 7845_-_beslissing_op_bezwaar_ov_pdf.pdf ==
# == 8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf ==
# ------------------------
# NAME: Café Lucky
# == besluit_op_bezwaar_openbaar_cafe_lucky.pdf ==
# == besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf ==
# == 7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf ==
# == 7938_besluit_openbaarmaking_cafe_lucky.pdf ==
# ------------------------
# NAME: Star SAT Electronica
# == 7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf ==
# == 7971_besluit_openbaarmaking_star_sat_electronica.pdf ==
# ------------------------
# NAME: Call Internet City
# == besluit_op_bezwaar_openbaar_call_internet_city.pdf ==
# == 7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf ==
# == 7970_sanctiebesluit_call_internet_city.pdf ==
# == 7970_besluit_openbaarmaking_call_internet_city.pdf ==
# ------------------------
# NAME: Huizenloterij
# == 7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf ==
# == 7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf ==
# == 7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf ==
# == 7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf ==

# %%
# A case now looks like:
extracted_cases[0]

# (not in this notebook because it's fairly verbose)

# %% [markdown]
# ### Analyse raw OCR output into structured text
#
# Take those OCR fragments and separate off headers, group into paragraphs and such.
#
# A lot of this isn't necessary to produce the text, **but** with bit of tweaking specific to this document layout,
# we can give cleaner output.
#
# Which is also why it's separate from the previous code cell.
#
# <!-- -->
#
# It's also _long_ because a bunch of specific augmentation goes on here.
# It's separate so that we can tweak and re-run it easily.
#
# It's still little more than a bunch of math on numbers, so takes less than a minute.

# %%
# a bunch of helpers
from wetsuite.extras.ocr import doc_extent, page_fragment_filter, bbox_max_x, bbox_max_y, bbox_min_x, bbox_min_y, bbox_height

verbose = False

dataset_cases = [] # distinct name, has a different structure

for case_i, case_tuple in enumerate(extracted_cases):
    case_dict, case_doc_dicts, ocrdata = case_tuple
    case_name = case_dict['name']

    print( 'CASE %d: %s'%(case_i, case_name) )

    case_docs = [] #this part's main output, becomes a dict per case (with keys like 'url', 'pages')
    assert len(case_doc_dicts) == len(ocrdata)

    case_doc_dates = set() # or maybe count?

    ## for each document, analyze the OCR fragments and sort it into more directly useful data
    for doc_i in range(len(case_doc_dicts)): #ocrdata should have the same length
        pdf_dict = case_doc_dicts[doc_i]
        doc_ocr  = ocrdata[doc_i]


        pdf_url = pdf_dict['pdf_url']
        print( '  DOC %d:  %s'%(doc_i,   wetsuite.helpers.format.url_basename( pdf_url ) ) )


        doc_pages = [] # the main output for a document - a list of dicts that each detail a page
        doc_dates = [] # picks out dates from the headers

        doc_wide_extent = doc_extent( doc_ocr ) # the area outside there is no text at all, throughout all of the page's document
        #print( 'doc_min_x, doc_max_x, doc_min_y, doc_max_y', extent )

        for page_i, page in enumerate( doc_ocr ): # page is now all text framents on a page, a list of all (bbox, text, cert) 
            if verbose:
                print( '   PAGE %s ---------------------------------------------------------------------------'%(page_i) )

            ### Determine margins
            # so that we can have logic that extract text that hopefully flows between pages
            head_y_ary, foot_y_ary = [], []
            # - Top margin defined by lowest box extent of 
            #    - "Kansspenautoriteit" (not really necessary)
            #    - "OPENBAAR"
            #    - "Ons kenmerk" plus one extra box's worth
            matches = page_fragment_filter( page, r'^Kansspelautoriteit$', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Kansspelautoriteit MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'^OPENBAAR$', q_max_y=0.3, q_max_x=0.35, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] OPENBAAR MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) )
            matches = page_fragment_filter( page, r'Ons kenmerk', q_max_y=0.25, extent=doc_wide_extent )
            for bbox, text, cert in matches:
                #print ('    [page %d] Ons kenmerk MATCH: %s %s %s'%(page_i, bbox, text, cert))
                head_y_ary.append( bbox_max_y(bbox) + 1.2* bbox_height(bbox) ) # we expect one more line of the same height below it (times fudge factor, for expected whitespace)
            
            # - Bottom margin defined by highest box y of "agina [0-9]+ van [0-9]+" in the bottom right
            matches = page_fragment_filter( page, r'Pagina', q_min_x=0.7, q_min_y=0.75, extent=doc_wide_extent ) # the rest, e.g. (\s*[0-9]+\s*van\s*[0-9]+)?, is optional because it's sometimes detected separately, or not at all
            for bbox, text, cert in matches: # 
                #print ('    [page %d] Pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                foot_y_ary.append( bbox_min_y(bbox)  )
            if len(foot_y_ary)==0: # look harder for page - a lone number to the bottom right that matches roughly with the page number we think it is is probably also the page number
                pages_around = '|'.join( str(pag)  for pag in range(page_i-1, page_i+2) )
                matches = page_fragment_filter( page, r'^(%s)$'%pages_around, q_min_y=0.75, q_min_x=0.7, extent=doc_wide_extent )
                for bbox, text, cert in matches: # (\s*[0-9]+\s*van\s*[0-9]+)?
                    #print ('    [page %d] Bare pagina MATCH: %s %s %s'%(page_i, bbox, text, cert))
                    foot_y_ary.append( bbox_min_y(bbox)  )

            if len(head_y_ary)==0:
                head_bot_y = None
            else:
                head_bot_y = max(head_y_ary)

            if len(foot_y_ary)==0:
                foot_top_y = None
            else:
                foot_top_y = min(foot_y_ary)

            if verbose:
                print("    page head_y: ", head_bot_y) # TODO: call this head_bot_y (and probably rename h)
                print("    page foot_y: ", foot_top_y) # TODO: call this foot_top_y


            ### Figure out some things about the page
            ## list-iten X position
            # Most of these documents have numbering on their headers and paragraphs
            # these list-iten numbers at the start of lines are not detected consistently by OCR,
            # nor are they linguistic information, so attempt to remove them.
            # We like to be sure (to not remove such things from actual text), so 
            lnum_righty = []
            matches = page_fragment_filter( page, r'^[0-9.]+$', q_max_x=0.2, q_min_y=head_bot_y,q_max_y=foot_top_y, extent=doc_wide_extent ) 
            for bbox, text, cert in matches:
                if verbose:
                    print ('    [page %d] LI NUM MATCH: %s %s %s'%(page_i, bbox, text, cert))
                lnum_righty.append( bbox_max_x(bbox)  )            
            if len(lnum_righty) < 4: # not sure enough - be more conservative
                lnum_righty = doc_wide_extent[0] + 20 # TODO: avoid that constant
            else:
                lnum_righty = max(lnum_righty)

            ## average box size
            box_heights = []
            for bbox, text, cert in page:
                box_heights.append( bbox_height( bbox ) )
            median_boxheight = numpy.median(box_heights)
            #print(box_heights)
            #print("Median bbox height: %d"%median_boxheight)


            ### Group and process fragments   (in passes, to make logic like 'is this the last thing in the body' easier)
            # - separate into head, body, foot
            # - polish the body, e.g. 
            #   'is this the last thing on the page AFTER we removed the footer' logic easier
            #   replace '-' at end of paragraph with '.'

            page_contents = {
                'head_fragments':[],
                'body_fragments':[],
                'misc_fragments':[],
                'foot_fragments':[],
                'body_text':[],
            }


            ## Sort fragments into header, body, and footer
            prev_topy, prev_boty = 0,0 
            for frag_i, (bbox, text, cert) in enumerate(page):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]

                text = re.sub('[_-]\s*$','.', text) # mistaken for period sometimes. Could be more thorough, but this is a start

                if head_bot_y is not None and topy < head_bot_y :
                    page_contents['head_fragments'].append( (bbox, text, cert) )

                elif foot_top_y is not None and boty > foot_top_y: # CONSIDER: also remove numbers from left of boxes that start at the -- IF we think it's such a number.
                    page_contents['foot_fragments'].append( (bbox, text, cert) )

                elif wetsuite.helpers.strings.is_numeric( text) and topleft[0] < lnum_righty+5:
                    pass
                    #page_contents['misc_fragments'].append( (bbox, text, cert) )

                else: #probably useful body
                    #print( '      %6s  %12s %-12s  fs:%-5s  %s '%( keep_ignore, topleft, botright, boxheight, text ) )
                    page_contents['body_fragments'].append( (bbox, text, cert) )

                    case_dict['money'].extend( find_eur_money(text, minimum=5001) )

                prev_topy, prev_boty = topy, boty

            ## Header stuff. Little smartness yet.
            head_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['head_fragments']):
                head_text.append(text)

                _, dts = wetsuite.helpers.date.find_dates_in_text(text)
                for dt in dts:
                    if dt is not None:
                        case_doc_dates.add( dt )
                        doc_dates.append( wetsuite.helpers.date.format_date(dt) )
                # CONSIDER: getting out kenmerk


            foot_text = [] 
            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['foot_fragments']):
                foot_text.append(text)

            ## Figure out body's paragraphs, seprate where sensible
            body_text = [] 
            temp_par  = []
            prev_topy, prev_boty, prev_boxheight, prev_text = 0,0, 0, ''
            def flush_par():
                global temp_par, body_text
                if len(temp_par)>0:
                    body_text.append( ' '.join(temp_par) )
                    temp_par=[] 


            for body_frag_i, (bbox, text, cert) in enumerate(page_contents['body_fragments']):
                topleft, topright, botright, botleft = bbox
                topy, boty = topleft[1], botright[1]
                boxheight = bbox_height(bbox) # is a good indicator of font size

                same_line            = (boty - prev_boty) < 0.6*boxheight
                current_line_shorter = len(text) < 0.5 * len(prev_text) 
                prev_line_shorter    = 0.5 * len(prev_text) < len(text)

                #if topy-prev_boty > -5:
                #    print( "                                                   [ydist %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )

                #if topy < prev_boty by roughly boxheight it's the same line

                if topy < prev_boty-200:
                    if verbose:
                        print( "LARGE DECREASE IN Y HUH?")
                        print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )
                    #continue
                    break
                    
                if prev_boty!=0  and  topy-prev_boty > median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif prev_boty!=0  and  topy-prev_boty > 0.6*median_boxheight: 
                    if verbose:
                        print( "                                                   [YSEP %d (%s->%s)]"%(topy-prev_boty, prev_boty, topy) )
                    flush_par()

                elif (boxheight > 1.25 * prev_boxheight)  and  current_line_shorter  and  not same_line:  # larger text, and shorter
                    # A large title of a new section is generally  caught by YSEP, actually
                    #print( 'size diff;   line diff?  botdiff is %d,  relative to 0.5*boxheight=%d'%( (boty-prev_boty),  0.5*boxheight ) )

                    if verbose:
                        print( "                                                   [LARGER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                elif boxheight < 0.8 * prev_boxheight  and  prev_line_shorter  and not same_line: # font smaller than the previous line, and the previous line was shorter
                    if verbose:
                        print( "                                                   [SMALLER_TEXT %s->%s]"%(prev_boxheight, boxheight) )
                    flush_par()

                temp_par.append( text )

                if verbose:
                    print( '      %12s %-12s  fs:%-5s  %s '%( topleft, botright, boxheight, text ) )

                prev_topy, prev_boty, prev_boxheight, prev_text = topy, boty,  boxheight, text

            flush_par()

            del page_contents['body_fragments']
            del page_contents['head_fragments']
            del page_contents['foot_fragments']
            del page_contents['misc_fragments']

            page_contents['head_text'] = head_text
            page_contents['body_text'] = body_text
            page_contents['foot_text'] = foot_text

            doc_pages.append( page_contents )

            #print( 'body_text' )
            #pprint.pprint( page_contents['body_text'] )
            #for par in page_contents['body_text']:
            #    for line in textwrap.wrap(par):
            #        print( '[%s]'%line )
            #    print()

        case_docs.append( 
            {
                'url':pdf_url, 
                'pages':doc_pages,
                'header_dates':doc_dates,
                'status':pdf_dict.get('status'),
            }
        )

        # summarize document
        #pprint.pprint( doc_contents )

        if 0:
            for page in doc_pages:
                for temp_par in page['body_text']:
                    for line in textwrap.wrap(temp_par):
                        print( '%s'%line )
                    print()


    date_range = ()
    if len(case_doc_dates)>0:
        date_range = (
            wetsuite.helpers.date.format_date( min(case_doc_dates) ), 
            wetsuite.helpers.date.format_date( max(case_doc_dates) )
        )

    dataset_cases.append( { 
                'name': case_name,
                'docs': case_docs,
        'date_range': date_range,

        # CONSIDER: maybe just start with case_dict so we don't have to manually do:
                'money': case_dict['money'],
                'ecli': case_dict['ecli'],
    'case_detail_url': case_dict['case_detail_url'],
    } )

print( len(dataset_cases) )
# Out:
# CASE 0: Gammix Limited
#   DOC 0:  boetebesluit_gammix_limited_29_februari_2024-pdf.pdf
#   DOC 1:  openbaarmakingsbesluit_boetebesluit_gammix_limited-pdf.pdf
#   DOC 2:  20230216_01-285-641_invorderingsbesluit_gammix.pdf
#   DOC 3:  20230216_01-285-642_besluit_openbaarmaking_gammix.pdf
#   DOC 4:  20220707_01_270_078_-_lod_gammix_ov.pdf
#   DOC 5:  20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf
# CASE 1: Hillside New Media Malta Plc
#   DOC 0:  15402_01-304-549_beslissing_op_bezwaar.pdf
#   DOC 1:  15402_bac_advies_hillside.pdf
#   DOC 2:  15402_01-304-539_openbaarmakingsbesluit_woo_bob.pdf
#   DOC 3:  15402_01-285-941_besluit-signed_openbare_versie.pdf
# CASE 2: Betent B.V.
#   DOC 0:  15998_01-302-172_betent_sanctiebesluit_openbaar.pdf
# CASE 3: Cloudflare
#   DOC 0:  besluit_bindende_aanwijzing_20231103_01-302-244.pdf
#   DOC 3:  7861_besluit_openbaarmaking_grand_cafe_randenbroek.pdf
# CASE 116: Onisac Limited en Mansion Online Casino Limited
#   DOC 0:  190625_besluit_openbaarmaking_bob_onisac_openbaar_003.pdf
#   DOC 1:  190704_bob_en_bac.pdf
#   DOC 2:  sanctiebesluit_onisac.pdf
#   DOC 3:  openbaarmakingsbesluit_sanctiebesluit_onisac.pdf
#   DOC 4:  7845_00_021_663_-_sanctiebesluit_openbaar.pdf
#   DOC 5:  7845_00_021_664-_openbaarmaking_openbaar.pdf
#   DOC 6:  7845_-_advies_bac_ov_pdf.pdf
#   DOC 7:  7845_-_beslissing_op_bezwaar_ov_pdf.pdf
#   DOC 8:  8051_-_besluit_openbaarmaking_bob_ov_pdf.pdf
# CASE 117: Café Lucky
#   DOC 0:  besluit_op_bezwaar_openbaar_cafe_lucky.pdf
#   DOC 1:  besluit_openbaarmaking_bob_openbaar_cafe_lucky.pdf
#   DOC 2:  7938_-_00_018_637_sanctiebesluit_openbare_versie.pdf
#   DOC 3:  7938_besluit_openbaarmaking_cafe_lucky.pdf
# CASE 118: Star SAT Electronica
#   DOC 0:  7971_-_00_019_052_sanctiebesluit_openbare_versie.pdf
#   DOC 1:  7971_besluit_openbaarmaking_star_sat_electronica.pdf
# CASE 119: Call Internet City
#   DOC 0:  besluit_op_bezwaar_openbaar_call_internet_city.pdf
#   DOC 1:  7822_-_00_019_154_besluit_openbaarmaking_bob_-_openbare_versie.pdf
#   DOC 2:  7970_sanctiebesluit_call_internet_city.pdf
#   DOC 3:  7970_besluit_openbaarmaking_call_internet_city.pdf
# CASE 120: Huizenloterij
#   DOC 0:  7982_-_00_020_754_kennisgeving_als_bedoeld_in_art_5_50_lid_2_sub_a_awb_openbaar.pdf
#   DOC 1:  7982_-_00_020_755_besluit_tot_openbaarmaking_openbaar.pdf
#   DOC 2:  7982_-_00_026_508_en_8140_-_00_026_510_besluit_op_bezwaar_openbaar1.pdf
#   DOC 3:  7982_-_00_025_509_en_8140_-_00_026_511_besluit_openbaarmaking_bob_openbaar1.pdf
# 121

# %%
# a case now looks like:
dataset_cases[0]
# Out:
# {'name': 'Gammix Limited',
#  'docs': [{'url': 'https://kansspelautoriteit.nl/publish/library/32/boetebesluit_gammix_limited_29_februari_2024-pdf.pdf',
#    'pages': [{'body_text': ['Besluit van de raad van bestuur van de Kansspelautoriteit als bedoeld in artikel 35a van de Wet op de kansspelen tot oplegging van een boete aan Gammix Limited.',
#       'Zaak: 15765 Kenmerk: 15765 /01.304.455 Openbaarmaking onder kenmerk: 15765/ 01.304.867',
#       'Besluit',
#       'Inleiding',
#       'De raad van bestuur van de Kansspelautoriteit (hierna: de Kansspelautoriteit) is belast met het toezicht op de naleving van de Wet op de kansspelen (hierna: Wok) . De Wok bevat een verbod op het gelegenheid geven tot deelname aan kansspelen zonder vergunning. Het handhaven van dit verbod is één van de prioriteiten van de Kansspelautoriteit. In dit besluit stelt de Kansspelautoriteit vast dat Gammix Limited (hierna: Gammix) dit verbod heeft overtreden. Daarom wordt aan Gammix een boete van € 19.679.000,. opgelegd . De Kansspelautoriteit zet dat hieronder nader uiteen.',
#       "Onderzoek naar webpagina's en betrokkene",
#       'De websites',
#       "Op en 8 maart 2022 heeft de Kansspelautoriteit de webpagina's www.rantcasino.com, www.betoriginal.com, WWW bluvegas.com, www.cashimashi.com, www.goslot.com, www.nordslot.com, WWW. .vegadream.com en Www.scatters.com (hierna: de websites) onderzocht.",
#       'Hierbij is onder meer het volgende gebleken.',
#       'Rapport 14829/01.286.006, 24 februari 2023.'],
#      'head_text': ['Kansspelautoriteit', 'OPENBAAR'],
#      'foot_text': ['Pagina', 'van 29']},
#     {'body_text': ['2.1.1 Gelegenheid tot deelneming aan kansspelen',
#       'De websites waren bereikbaar vanaf een Nederlands IP-adres en het was voor de toezichthouder van de Kansspelautoriteit (hierna: toezichthouder) mogelijk om met Nederlandse (adres)gegevens een account aan te maken, daarop in te loggen, een storting te doen deel te nemen aan kansspelen. 2 Er waren geen technische maatregelen genomen om deelnemers vanuit Nederland de toegang tot de kansspelen te beletten ',
#       'Op de websites werden virtuele versies van slotmachines aangeboden: 3 Deze spellen zijn aan te merken als kansspelen.',
#       'Met deelname aan de kansspelen kan worden meegedongen naar prijzen of premies. Dat is onder andere gebleken uit paragraaf 4 en paragraaf 5 van de Terms & Conditions (hierna: T&Cs) van de websites. Zo staat in artikel 4.10 van de T&Cs: "If you wish to divide a part of the winnings which is amounted to',
#       '20,000 EUR or more, we have the right to divide the pay-out into instalments until the full amount is paid out."4',
#       'Op de websites stond vermeld dat Gammix is gevestigd in Malta en een vergunning heeft in Malta voor het aanbieden van kansspelen. 5',
#       'Bij het inschrijvingsproces werd de leeftijd niet zichtbaar geverifieerd voordat het inschrijvingsproces was voltooid.',
#       '2.1.2 Gerichtheid op de Nederlandse markt',
#       'Zoals benoemd onder randnummer 4 waren de websites bereikbaar vanaf een Nederlands IP-adres en kon vanuit Nederland een account worden aangemaakt en worden deelgenomen aan kansspelen.',
#       'Uit de data van Similarweb blijkt dat de websites veelvuldig vanuit Nederland zijn bezocht.',
#       'Bijlagen 14829/01.257.078/1A/1B/1C/2A/2B/2C/3A/3B/3C/4A/4B/4C/5A/5B/5C/6A/6B/6C/ 7A/7B/7C/8A/8B/8C . Bijlagen 14829/01.257.078/1C/1D/2C/2D/3C/3D/4C/4D/5C/5D/6C/6D/7C/7D/8C/8D . Bijlagen 14829/01.257.078/1E/2E/3E/4E/5E/6E/7E/8E Bijlagen 14829/01.257.078/1D/2D/3D/4D/5D/6D/7D/8D. Bijlagen 14829/01.257.078/1A/1B/1C/2A/2B/2C/3A/3B/3C/4A/4B/4C/5A/5B/5C/6A/6B/6C/ 7A/7B/7C/8A/8B/8C . Bijlage 14829/01.284.377 .'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#       '21 . Hierbij is onder meer het volgende gebleken.',
#       "2.2.1 Gelegenheid tot deelneming aan kansspelen 22 . De andere websites waren bereikbaar vanaf een Nederlands IP-adres en het was voor de toezichthouder mogelijk om met Nederlandse (adres)gegevens een account aan te maken; daarop in te loggen; een storting te doen en deel te nemen aan kansspelen. '7 Er waren geen technische maatregelen genomen om deelnemers vanuit Nederland de toegang tot de kansspelen te beletten.",
#       '23 . Op de andere websites werden virtuele versies van slotmachines aangeboden. 18 Deze spellen zijn aan te merken als kansspelen.',
#       '24 . Op de andere websites stond vermeld dat Gammix is gevestigd in Malta en een vergunning heeft in Malta voor het aanbieden van kansspelen. 19',
#       'Bij het inschrijvingsproces werd de leeftijd niet zichtbaar geverifieerd voordat het inschrijvingsproces was voltooid. 20',
#       'Bijlage 14829/01.277.724/1A/1B/1G/1D Rapport 14829/01.286.006, 24 februari 2023 Bijlagen 14829/01.263.965/3A/3B/3C/4A/4B/4C/5A/5B/5C/6A/6B/6C. Bijlagen 14829/01.263.965/3C/3D/4G/4D/5G/5D/6C/6D. Bijlagen 14829/01.263.965/3D/4D/5D/6D . Bijlagen 14829/01.263.965/34/3B/4A/4B/5A/5B/6A/6B.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina', '4 van 29']},
#     {'body_text': ['2.2.2 Gerichtheid op de Nederlandse markt Zoals benoemd onder randnummer 22 waren de andere websites bereikbaar vanaf een Nederlands IP-adres en kon vanuit Nederland een account worden aangemaakt en worden deelgenomen aan kansspelen.',
#       'Uit de data van Similarweb blijkt dat de andere websites veelvuldig vanuit Nederland zijn bezocht. 21',
#       '28 . Er zijn door een toezichthouder vanuit een Nederlandse bank en betaalrekening stortingen van € 20, op de spelersrekeningen verricht. 22',
#       'Daarnaast waren de andere websites internationaal georiënteerd, waaruit medegerichtheid op Nederland bleek. Spelers konden geld storten in diverse munteenheden, waaronder de euro De websites waren beschikbaar in de Engelse taal. Er is sprake van internationale topleveldomeinnamen; namelijk een com . extensie .',
#       'De betrokkene',
#       "30 . Naast de webpagina's is ook betrokkene onderzocht. Uit het onderzoek blijkt dat Gammix gelegenheid biedt tot deelname aan de kansspelen op de (andere) websites. Dat blijkt onder meer uit het volgende. Op de homepagina staat dat de (andere) websites worden geëxploiteerd door Gammix. 23 Daarnaast wordt Gammix als contractpartij genoemd in paragraaf van de T&Cs. 24",
#       'Rapport',
#       '31 . De Kansspelautoriteit heeft op grond van de hierboven genoemde onderzoeken op 24 februari 2023 een rapport (hierna: het rapport) opgesteld. In het rapport is geconstateerd dat Gammix door middel van de (andere) websites gelegenheid heeft gegeven om mede te dingen naar prijzen of premies, waarbij de aanwijzing van de winnaars geschiedt door enige kansbepaling waarop de deelnemers in het algemeen geen overwegende invloed kunnen uitoefenen, terwijl daarvoor geen',
#       'Bijlage 14829/01.284.377 .',
#       'Bijlagen 14829/01.263.956/1B/2B/3B/4B. Bijlagen 14829/01.257.078/1D/2D/3D/4D/5D/6D/7D/BD en bijlagen 14829/01.263.965/3D/4D/5D/6D',
#       'Bijlagen 14829/01.257.078/1E/2E/3E/4E/5E/6E/7E/8E.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 5 van 29']},
#     {'body_text': ['vergunning is verleend. Dat is een overtreding van artikel 1, eerste lid, aanhef en onder a, van de Wok.',
#       'Zienswijze',
#       'Procedureel',
#       'Bij brief van 19 mei 2023 hebben [advocaat 1], [advocaat 2] en [advocaat 3] namens Gammix een schriftelijke zienswijze gegeven op het rapport.',
#       '33 . Op 30 mei 2023 hebben [advocaat 1], [advocaat 2] en [advocaat 3] namens Gammix de schriftelijke zienswijze mondeling toegelicht. Op 7 juni 2023 is het verslag van de hoorzitting per e-mail naar Gammix verzonden. Op 14 juni 2023 heeft Gammix gereageerd op het verslag.',
#       'Inhoudelijk',
#       'Namens Gammix is aangevoerd dat het rapport de conclusie dat Gammix de Wok zou hebben overtreden niet draagt en dat er daarom geen grondslag is voor het opleggen van een sanctie. Het rapport is in strijd met de algemene beginselen van behoorlijk bestuur en de besluitvorming die is gebaseerd op het rapport is daarom ook in strijd met de algemene beginselen van behoorlijk bestuur. Samengevat voert Gammix aan dat: a de Kansspelautoriteit in strijd heeft gehandeld met artikel 4:8 en 5:53 van de Awb; b de (andere) websites van Gammix niet gericht waren op Nederland; C. de Kansspelautoriteit zich bij de (andere) websites van Gammix heeft voorgedaan als ingezetene van een ander land; d. het door de Kansspelautoriteit verrichte onderzoek onrechtmatig is; e er grond was om het rapport op te stellen; nu Gammix reeds was geconfronteerd met een last onder dwangsom; f. de geschatte omzet, afkomstig van Nederlandse bezoekers, onrealistisch en onjuist is; 9 er sprake is van strijd met het rechtszekerheidsvereiste (lex certa) en het evenredigheidsvereiste .',
#       'De Kansspelautoriteit zal hieronder ingaan op deze punten.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 6 van 29']},
#     {'body_text': ['Juridische beoordeling',
#       'De wettelijke bepalingen',
#       '36 . Artikel 1 eerste lid, aanhef en onder a, van de Wok bepaalt dat het verboden is om gelegenheid te geven om mede te dingen naar prijzen of premies; indien de aanwijzing der winnaars geschiedt door enige kansbepaling waarop de deelnemers geen overwegende invloed kunnen uitoefenen, tenzij daarvoor ingevolge deze wet vergunning is verleend.',
#       '37 . Artikel 35a, eerste lid, van de Wok bepaalt dat de Kansspelautoriteit een bestuurlijke boete kan opleggen wegens overtreding van onder andere de voorschriften vastgesteld bij of krachtens artikel 1, eerste lid, onder a',
#       'Artikel 35a, tweede lid, van de Wok bepaalt dat de bestuurlijke boete die voor een overtreding als bedoeld in het eerste lid kan worden opgelegd ten hoogste het bedrag van de zesde categorie, bedoeld in artikel 23, vierde lid, van het Wetboek van Strafrecht bedraagt of, indien dat meer is, tien procent van de omzet in het boekjaar voorafgaande aan de beschikking.',
#       'Artikel 23, vierde lid, van het Wetboek van Strafrecht bepaalt dat het hiervoor bedoelde bedrag van de zesde categorie € 900.000, is.',
#       'Voornemen',
#       'Gammix stelt dat de Kansspelautoriteit geen voornemen bekend heeft gemaakt waarin de hoogte van de op te leggen sanctie was opgenomen. Volgens Gammix is dit in strijd met artikel 4:8 en 5:53 van de Awb.',
#       'Ten aanzien hiervan overweegt de Kansspelautoriteit als volgt.',
#       'De Kansspelautoriteit heeft Gammix met de uitnodiging van 28 februari 2023 voor een hoorzitting in kennis gesteld van het voornemen om een sanctie op te leggen en dit besluit openbaar te maken. Daarop heeft Gammix op 19 mei 2023 een schriftelijke zienswijze ingediend, welke zij op 30 mei 2023 mondeling heeft toegelicht.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina', '7 van 29']},
#     {'body_text': ['De Kansspelautoriteit is niet gehouden Gammix een uitgeschreven voorgenomen besluit toe te sturen bij de uitnodiging tot het indienen van een zienswijze. 25 Met het toesturen van het rapport is Gammix voldoende in de gelegenheid gesteld om de zienswijze te onderbouwen op zowel het sanctiebesluit als het openbaarmakingsbesluit.',
#       'Voor zover Gammix bedoelt te stellen dat artikel 5:53, derde lid, van de Awb een extra zienswijzemogelijkheid inhoudt, volgt de Kansspelautoriteit haar daar niet in. Gammix is immers vooraf op de hoogte gesteld van het voornemen tot het opleggen van een sanctie opdat zij zich kon voorbereiden op het naar voren brengen van haar zienswijze. Op grond van artikel 5:50, eerste lid, van de Awb is de Kansspelautoriteit slechts eenmaal gehouden om gelegenheid te geven tot het indienen van een zienswijze met betrekking tot de besluiten. Daarbij is de Kansspelautoriteit niet gehouden zich vóór het nemen van het sanctiebesluit reeds uit te laten over voor de boetehoogte relevante aspecten; zoals de ernst en duur van de overtreding en de mate van verwijtbaarheid. 26 Het is niet in strijd met artikel 5:53, derde lid, in samenhang met artikel 5:50 van de Awb, dat mede op grond van de zienswijze eerst is beslist of al dan niet een boete zal worden opgelegd en pas toen was besloten om daartoe over te gaan de hoogte van de boete is bepaald. 27 Dit brengt niet met zich mee dat Gammix daardoor in haar verdedigingsbelang is geschonden.',
#       'De Kansspelautoriteit merkt verder op dat artikel 4:8 van de Awb slechts een beperkt toepassingsbereik kent. Met het horen wordt immers beoogd de verificatie en verzameling van gegevens vanuit een oogpunt van een zorgvuldige voorbereiding te bevorderen, teneinde een zorgvuldige afweging van feiten en belangen mogelijk te maken. Het gaat niet om het mogelijk maken van inspraak, maar om het bieden van een mogelijkheid aan Gammix om gegevens te corrigeren of aan te leveren.',
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 10 van 29']},
#     {'body_text': ["56 . De (andere) websites hadden een internationale topleveldomeinnaam, namelijk een .com-extensie. 36 Spelers konden geld storten in de valuta euro. Gammix had op de (andere) websites kansspelen en te winnen prijzen geëtaleerd. Een dergelijke internationale oriëntatie door Gammix van haar commerciële activiteiten is mede gericht op Nederland. Verder had Gammix de (andere) websites z0 ingericht dat vanaf een Nederlandse bankrekening geld gestort kon worden en dat er geld kon worden gestort in de munteenheid van Nederland (euro) . Daar komt bij een aantal websites bij dat in het inschrijvingsproces de 'Netherlands werd aangeboden in een aantal keuzemenu's en dat het netnummer +31= tussen de beschikbare netnummers stond.",
#       'Ook het betoog van Gammix ten aanzien van het arrest Pammer/Alpenhof van het HvJEU kan niet slagen. Gammix stelt dat daaruit volgt dat noch de verkoop van een dienst, noch de toegankelijkheid van een medium in een lidstaat de kwalificatie "gerichtheid" rechtvaardigt. Gerichtheid impliceert en vereist volgens haar een actief handelen van de ondernemer dat is gericht op de werving van klanten uit bepaalde lidstaten wat bij Gammix niet het geval was',
#       'Het arrest Pammer/Alpenhof betreft de toepassing van Verordening (EG) nr. 44/2001. Deze verordening wordt toegepast in burgerlijke en handelszaken, ongeacht de aard van het gerecht. Zij heeft met name geen betrekking op fiscale zaken; douanezaken of administratiefrechtelijke zaken, aldus artikel van de verordening. Het arrest betreft de bevoegdheid van de rechter in gevallen waarin de partijen die een overeenkomst sluiten (de consument en de ondernemer) in verschillende lidstaten van de Europese Unie wonen.',
#       'Het HvJEU overweegt dat in dat geval de vraag is of er aanwijzingen zijn dat de ondernemer zijn activiteiten richtte op andere lidstaten, waaronder de lidstaat waarin de consument woonplaats heeft. Het HvJEU een niet limitatieve opsomming van dergelijke aanwijzingen, zoals het gebruik van een topleveldomeinnaam (.com) en een internationaal telefoonnummer .',
#       "De verordening en het arrest hebben geen werking tussen de ondernemer en de toezichthouder, maar tussen de ondernemer en de afnemer (consument). Evenmin zijn de verordening en het arrest bedoeld om ondernemers te vrijwaren van handhavend optreden, zolang zij maar stellen te voldoen aan de 'criteria' uit het arrest of hun werkwijze en bedrijfsvoering zodanig (aan het arrest) aanpassen, dat een toezichthouder het nakijken heeft .",
#       '36 Hof van Justitie van de Europese Unie 7 december 2010, C-585/08 en C-144/09, (Pammer en Alpenhof) r.o 83'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 11 van 29']},
#     {'body_text': ['61 . Ook in de memorie van toelichting bij de Wet Kansspelen op afstand staat een verwijzing naar het arrest Pammer/Alpenhof. 37 Er is ingegaan op de vraag of er meer verduidelijking nodig is met betrekking tot de overtreding van artikel 1 aanhef en eerste lid, onder a, van de Wok. Volgens de wetgever is het voor iedereen duidelijk wat hier wordt bedoeld. De wetgever verwijst hiervoor naar het eerdergenoemde Ladbrokes-arrest en merkt vervolgens op:',
#       '"Ook de jurisprudentie van het Hof van Justitie biedt voldoende',
#       'aanknopingspunten voor de vraag wanneer sprake is van het in Nederland organiseren van kansspelen op afstand. Verwezen wordt naar het arrest van 7 december 2010 in de gevoegde zaken C-585/08 en C-144/09 (Pammer en Alpenhof) .',
#       'Ook de omstandigheid dat de (andere) websites niet in de Nederlandse taal raadpleegbaar waren; leidt niet tot de conclusie dat deze niet mede was gericht op Nederland. 38 Het gebruik van de Engelse taal bij de inrichting van een website vormt juist een kenmerk van medegerichtheid op Nederland. Het maakt het voor veel Nederlandse ingezetenen mogelijk om via hun computer rechtstreeks aan de kansspelen deel te nemen. Immers, niet alleen is Engels een internationale taal, maar het is een feit van algemene bekendheid dat veel Nederlanders Engels 39 kunnen spreken, lezen en schrijven.',
#       '5.3.2 Prioriteringscriteria 63 . Gammix stelt dat op grond van de kenmerken van gerichtheid, zoals weergegeven in de meest recente prioriteringscriteria van de Kansspelautoriteit, in redelijkheid niet kan worden gesteld dat Gammix zich richt op de Nederlandse consument.',
#       '64 . De Kansspelautoriteit merkt op dat de prioriteringscriteria andere criteria zijn dan de criteria die worden gebruikt om te beoordelen of sprake is van een overtreding. Op grond van onderdeel 5.2, onder D, van deze criteria kan de mate van gerichtheid op de Nederlandse consument meewegen in de prioritering voor onderzoek naar een mogelijke overtreding . De mate van gerichtheid op de Nederlandse consument kan uit verschillende kenmerken blijken. 40 Ook bij aanbieders die niet voldoen aan de prioriteringscriteria kan sprake zijn van een overtreding.',
#       '37 Kamerstukken II 2013-2014, 33 996, nr. 3, p 75 Afdeling 22 februari 2017, ECLI:NL:RVS:2017:484 Bluemay) , r.0. 5. 39 Zie ook: Afdeling 17 januari 2018, ECLI:NL:RVS:2018:155 Imperial E-Club Ltd.) , r.0 5.2. https: L /kansspelautoriteit nlover-onslpublicaties/regels-leidradenlaanbieders-online. kansspelen/handhavingsbeleid-prioritering.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 12 van 29']},
#     {'body_text': ['Ook wijst de Kansspelautoriteit erop dat uit een ander sanctiebesluit blijkt dat reclame is gemaakt gericht op de Nederlandse consument voor verschillende websites van Gammix. 41 Zowel Gammix als deze websites zijn genoemd in dit sanctiebesluit. Uit dit besluit volgt dat reclame is gemaakt voor het onvergunde kansspelaanbod van Gammix. Op grond hiervan zijn de prioriteringscriteria dus ook van toepassing op Gammix.',
#       '66 . Gammix had (als belanghebbende) bezwaar kunnen maken tegen dit sanctiebesluit. Dat heeft Gammix echter niet gedaan. Het besluit is thans onherroepelijk.',
#       '5.3.3 Intentie 67 . Gammix stelt verder dat zij geen enkele intentie had om gelegenheid te bieden tot deelname aan kansspelen op de Nederlandse markt.',
#       "74 . De toezichthouder van de Kansspelautoriteit heeft zich bij het onderzoek naar de websites op 24 mei 2022 en bij het onderzoek naar de andere websites op 2 juni 2022 geregistreerd met een emailadres van de Kansspelautoriteit. Bij het registreren stond 'Nederland' niet meer tussen de lijst met beschikbare landen. De toezichthouder heeft daarom 'Luxemburg' aangeklikt. Vervolgens heeft de toezichthouder de adresgegevens van de Kansspelautoriteit in Den Haag opgegeven . 43 Aan de hand daarvan was het mogelijk om op het account in te loggen en deel te nemen aan een kansspel op de (andere) websites .",
#       'Gammix stelt dat de Kansspelautoriteit hiermee buiten de grenzen van haar bevoegdheid is getreden. Daarbij zou niet zijn aangegeven waarom dit redelijkerwijs noodzakelijk was. De Kansspelautoriteit heeft geen andere, minder ingrijpende middelen ingezet, zoals een informatieverzoek. Volgens Gammix is hiermee het onderzoek onrechtmatig en kan het bewijs niet worden gebruikt.',
#       'Bijlage 14829/01.284.378.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 14 van 29']},
#     {'body_text': ['De Kansspelautoriteit volgt Gammix niet in haar betoog. De toezichthouder heeft bij het onderzoek geen gebruik gemaakt van zijn eigen identiteitsgegevens; in zoverre is er sprake van het gebruik van de bevoegdheid van artikel 34c, eerste lid, van de Wok. Dit neemt niet weg dat de gegevens die gebruikt zijn; zowel de onjuiste als de juiste (het adres en het e-mailadres) te herleiden zijn naar de Kansspelautoriteit. Er zijn slechts onjuistelonvolledige gegevens opgegeven voor zover dit redelijkerwijs noodzakelijk is geweest voor het onderzoek.',
#       "In het verslag ter beantwoording van de aanvullende vragen inzake dossier 14829 van 16 februari 2023 is gemotiveerd dat het invullen van deze gegevens nodig was om te onderzoeken of er mogelijkheid werd gegeven tot deelname aan een kansspel vanuit Nederland. Hierbij is onderzocht of er technische maatregelen waren genomen om deelnemers vanuit Nederland de toegang tot de kansspelen te beletten. Daarom is het account aangemaakt, is er een storting verricht en is er deelgenomen aan een kansspel. Hoewel er bij registratie op de website geen mogelijkheid was om het land 'Nederland' te kiezen; was er verder geen belemmering voor de toezichthouder om in te loggen op het account en deel te nemen aan een kansspel vanuit Nederland. Hiermee is naar het standpunt van de Kansspelautoriteit voldoende aangetoond waarom gebruik is gemaakt van de bevoegdheid en dat dit redelijkerwijs noodzakelijk was. Aanleiding voor het bestuurlijk rapport",
#       'Gammix voert aan dat er geen grond was om een sanctieonderzoek te starten. Na ontvangst van het voornemen last onder dwangsom in juni 2022 heeft Gammix zich open, ontvankelijk en coöperatief opgesteld. In dat licht acht Gammix het alsnog opmaken van een rapport op grond van artikel 5.48 van de Algemene wet bestuursrecht (kennelijk met het doel om alsnog een boete op te leggen) onzorgvuldig en onevenredig .',
#       'Volgens vaste jurisprudentie kunnen een toezichthoudend bestuursorgaan en de bij haar werkzame toezichthouders om adequaat toezicht te kunnen uitoefenen op de naleving van de bij en krachtens de wet gestelde regels, beschikken over verschillende bevoegdheden die zij steeds en spontaan kunnen uitoefenen. 44 Het aanbieden van online kansspelen die zijn gericht op de Nederlandse markt zonder de daarvoor benodigde vergunning is zonder uitzondering verboden en tegen illegale aanbieders kan, ook spontaan; door de Kansspelautoriteit handhavend worden opgetreden. 45 Het argument kan daarom geen doel treffen. ',
#       'College van Beroep voor het bedrijfsleven 15 oktober 2019, ECLI:NL:CBB:2019.496, r.0. 4.5 Afdeling 29 juni 2022, ECLI:NL:RVS:2022:1833 (Corona Limited) , r.0 10.2'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 15 van 29']},
#     {'body_text': ['80 . Ten aanzien van het opleggen van een last onder dwangsom overweegt de Kansspelautoriteit als volgt. Een (voornemen) last onder dwangsom is een herstelsanctie. Het doel hiervan is om de overtreding te doen beëindigen. De boete is een punitieve sanctie . Daarbij is het doel om (ook) leed toe te voegen; als straf voor de overtreding (speciale preventie) . Daarnaast heeft een punitieve sanctie een afschrikkende werking (generale preventie) . Het enkel opleggen van een (voornemen) last onder dwangsom zou tot gevolg hebben dat een illegale aanbieder ongestraft kan aanbieden totdat er een herstelsanctie wordt opgelegd. Een last onder dwangsom heeft immers geen; of in veel mindere mate, afschrikwekkende werking. Kortom, het voornemen last onder dwangsom en het opstarten van deze sanctieprocedure , met dit boetebesluit tot gevolg, dienen twee verschillende doelen. Dat alsnog een rapport is opgemaakt na de last onder dwangsom maakt dan ook niet dat dit onevenredig of onzorgvuldig is. De Kansspelautoriteit volgt het standpunt van Gammix dan ook niet.',
#       'Schatting omzet vanuit Nederland',
#       'Gebruik data Similarweb 81 . De Kansspelautoriteit gebruikt gegevens van Similarweb om het aantal bezoeken op een bepaalde website in een bepaalde periode te schatten. Similarweb is een platform voor marktinformatie dat voorziet in inzichten over webverkeer . Het platform biedt geen directe metingen van dat webverkeer , maar geschatte cijfers gegenereerd door Similarweb . De cijfers zijn gebaseerd op informatie verkregen van verschillende bronnen, waaronder derde partijen. 46 De inzichten zijn naar hun aard schattingen en extrapolaties. Similarweb geeft geen garanties voor de nauwkeurigheid van de inzichten.',
#       'De Kansspelautoriteit kan niet vaststellen hoeveel bezoekers of bezoeken een website heeft, hoeveel spelersaccounts er zijn, hoeveel er verdiend wordt met de exploitatie van een website, etc. Daarom maakt zij , naast de gegevens van Similarweb, een inschatting op basis van gegevens die uit onafhankelijke en objectieve bronnen zijn verkregen. De Kansspelautoriteit is van mening dat zij op die manier een correcte maatstaf hanteert voor de inschatting van het aantal bezoeken. Het staat Gammix vrij om verifieerbare gegevens over haarzelf te verstrekken. Zulke gegevens zouden ertoe kunnen leiden dat de Kansspelautoriteit de betreffende variabelen bijstelt (in het voordeel van Gammix) , maar Gammix heeft uitdrukkelijk te kennen gegeven niet van deze mogelijkheid gebruik te willen maken. Tijdens de hoorzitting op 30 mei 2023 had Gammix nog aangegeven te overwegen omzetcijfers aan te leveren over 2022,',
#       'https:L/www_similarweb comlcorplourdatal.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 16 van 29']},
#     {'body_text': ['maar op 9 juni 2023 heeft Gammix per brief aan de Kansspelautoriteit laten weten geen nadere gegevens aan te leveren; omdat zij niet gehouden is deze gegevens te verstrekken en omdat het eventueel overleggen van omzetgegevens zelf . incriminerend zou zijn. Gammix heeft evenmin gemotiveerd waarom de gegevens van Similarweb onjuist zijn of zodanig afwijken van de werkelijke cijfers dat zij niet geschikt zijn voor het doel waarvoor de Kansspelautoriteit ze gebruikt (het bepalen van een proportionele boete) . De Kansspelautoriteit benadrukt dat zij niet gehouden is om de exacte in Nederland behaalde omzet van Gammix te bepalen, noch de vorm of wijze die ze kiest voor het bepalen van een proportionele boete. Het er uiteindelijk om dat aan Gammix een boete wordt opgelegd die in redelijke verhouding staat tot de overtreding.',
#       "De Kansspelautoriteit gebruikt het aantal bezoeken om een beredeneerde schatting te maken van de omzet van Gammix. Volgens Gammix is het bezoeken van alleen de homepage van de website iets anders dan deelnemen aan een kansspel; niet iedere bezoeker is een speler. Dat niet ieder bezoek leidt tot deelname, wordt ook niet betwist door de Kansspelautoriteit, maar dit is ook niet relevant. Er wordt bij het bepalen van de boete immers, naast een geschat aantal bezoeken; uitgegaan van de gemiddelde omzet per bezoek. Daarin is dus verdisconteerd dat sommige bezoeken geen omzet genereren en andere bezoeken juist veel meer dan het gemiddelde. 5.6.2 Definitie begrip 'omzet' in de Boetebeleidsregels 84 . Volgens Gammix wijkt de definitie van 'omzet' die de Kansspelautoriteit in haar Boetebeleidsregels gebruikt af van de definitie uit het BW en is deze in strijd met het rechtszekerheidsbeginsel. De Kansspelautoriteit heeft in haar Boetebeleidsregels uiteengezet hoe zij de boete berekent en hoe zij relevante begrippen uitlegt. Deze beleidsregels zijn kenbaar voor Gammix. Met deze Boetebeleidsregels bepaalt de Kansspelautoriteit hoe zij een passende hoogte van de boete vaststelt. Daartoe heeft zij een rekenmethode ontwikkeld, waarbij zij onder meer gebruik maakt van het begrip 'omzet' .",
#       "Het is de Kansspelautoriteit ambtshalve bekend dat aanbieders zonder vergunning in de regel geen belasting afdragen in Nederland en geen kortingen en dergelijke geven als bedoeld in artikel 2:377, zesde lid, van het BW. Gammix heeft ook niet laten weten welke belastingen zij in Nederland heeft betaald en welke kortingen zij zou hebben gegeven. Dat betekent dat het door de Kansspelautoriteit gehanteerde begrip 'omzet' en het begrip 'omzet als gedefinieerd in het BW in de praktijk gelijke resultaten opleveren."],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 17 van 29']},
#     {'body_text': ["86 . In de beleidsregels is de Kansspelautoriteit niet verplicht om daarbij de in het BW vervatte definitie van omzet' te gebruiken. Het gaat er immers om dat duidelijk is hoe de Kansspelautoriteit het boetebedrag bepaalt. Niet betwist wordt dat de Kansspelautoriteit daar duidelijk over is. De definitie van het begrip 'omzet' uit het BW is alleen relevant om te bepalen of de boete niet het bedrag overschrijdt als bedoeld in artikel 35a, tweede lid, van de Wok. Gelet op de uitleg uit randnummer 85 is daarvan geen sprake.",
#       '87 . Volgens Gammix baseren de Boetebeleidsregels de omzet op de som van alle inzetten en wordt geen rekening gehouden met de bedragen die aan spelers worden uitgekeerd. Gammix stelt dat de Kansspelautoriteit de boete moet bepalen aan de hand van het Bruto Spel Resultaat (hierna: BSR) . Het is onevenredig om de hoogte van de boete te bepalen aan de hand van de som van de inzetten/inleggen; aldus Gammix.',
#       '88 . De Kansspelautoriteit merkt op dat het klopt dat de omzet gebaseerd is op de som van alle inzetten. Dit is in de rekenmethode in het verslag over de vaststelling van het BSR en de omzetschatting (hierna: de rekenmethode) als volgt uitgelegd: de Kansspelautoriteit gaat uit van een gemiddeld BSR van € 11,51 per bezoek. Dit heeft de Kansspelautoriteit vermenigvuldigd met 20, gebaseerd op een return to player (hierna: RTP) van 95 procent. Dit betekent dat dat er een gemiddelde omzet per bezoek is van € 230,24.47 Het BSR is daarmee dus verwerkt in de omzetberekening van de Kansspelautoriteit.',
#       "Gammix heeft niet gemotiveerd waarom een rekenmethode gebaseerd op het begrip 'omzet' dat de Kansspelautoriteit hanteert, tot een ander boetebedrag zou leiden dan een rekenmethode die uitgaat van het BSR. 48 De Kansspelautoriteit wijst er nogmaals op dat zij de inschatting van de omzet gebaseerd heeft op een inschatting van het BSR. Voor zover Gammix bedoelt dat de maximale boete niet meer dan 10% van het BSR mag bedragen; verwijst de Kansspelautoriteit naar wat hierna wordt toegelicht.",
#       'Dit bedrag is voor de berekening van de boetehoogte ten gunste van de overtreder met een factor 2 verlaagd Zie verder onder paragraaf 5.6.3 van dit besluit. 48 De Kansspelautoriteit hanteert nu 4 procent van de omzet als boete in gevallen waarin de omzet hoger dan € 15 miljoen euro is. Indien de Kansspelautoriteit niet een percentage van de omzet zou nemen; maar van het BSR, zou dat percentage natuurlijk veel hoger zijn dan 4 procent.'],
#      'head_text': ['VERTROUWELIJK',
#       'Kansspelautoriteit',
#       'Kansspelautoriteit',
#       'Datum',
#       '12 december 2023',
#       'Ons kenmerk',
#       '15765/01.304.867'],
#      'foot_text': ['Pagina 18 van 29']},
#     {'body_text': ['90 . Daarnaast is het niet z0 dat aanbieders die een hoge RTP hanteren met deze rekenmethode benadeeld worden, zoals Gammix beweert. Zoals toegelicht gaat de rekenmethode die de Kansspelautoriteit hanteert, uit van een RTP van 95 procent. Het is de Kansspelautoriteit ambtshalve bekend dat dit in de praktijk een realistisch uitgangspunt is. Gesteld noch gebleken is dat Gammix een hogere (of lagere) RTP hanteert. Bovendien gaat het erom of de boete die aan Gammix is opgelegd evenredig is met de overtreding. Als Gammix een hogere RTP hanteert; is daarmee nog niet gegeven dat de opgelegde boete onevenredig is.',
#       "Verder stelt Gammix dat de Kansspelautoriteit op grond van artikel 35a, tweede lid, van de Wok en artikel 2.377, zesde lid, van het BW een boete zou mogen opleggen van maximaal 10 procent van het BSR. De term 'omzet' moet in die bepalingen immers begrepen worden als BSR' . Zoals de Kansspelautoriteit hiervoor heeft overwogen wijkt BSR significant af van omzet. Alleen al daarom kan de wetgever niet bedoeld hebben dat de term 'omzet' in artikel 35a, tweede lid, van de Wok moet worden gelezen als BSR' . De Kansspelautoriteit wijst er bovendien op dat vergunninghouders jaarlijks 29 procent kansspelbelasting betalen over het BSR. Ook daaruit blijkt dat het niet de bedoeling van de wetgever kan zijn dat illegale aanbieders, die helemaal geen kansspelbelasting betalen in Nederland, slechts 10 procent boete over het BSR hoeven te betalen. De wetgever kan niet beoogd hebben dat illegaal aanbieden profijtelijker is dan legaal aanbieden.",
#       'Volgens Gammix erkent de Kansspelautoriteit in haar rapport \'Omvang online kansspelmarkten" zelf ook dat \'omzet\' weinig zeggend is. In het betreffende rapport wordt uitgelegd dat het begrip omzet\' in dat rapport niet wordt gehanteerd omdat inleggen die uit hetzelfde startbedrag worden gefinancierd bij elkaar worden opgeteld, waardoor een vertekend beeld ontstaat. Daarbij wordt echter uitgegaan van een andere berekening van het begrip \'omzet\' dan de Kansspelautoriteit doet conform de Boetebeleidsregels. De verwijzing naar het begrip \'omzet\' in het genoemde rapport kan Gammix daarom niet baten.',
#       '5.6.3 Bepalen van de hoogte van de boete 93 . In het verslag over de vaststelling van het BSR en de omzetschatting heeft de Kansspelautoriteit uiteengezet hoe zij het bedrag van € 115,12 per bezoek heeft bepaald. 49 Ook heeft zij aangegeven hoe zij de aantallen bezoeken heeft bepaald. Daaruit blijkt dat de Kansspelautoriteit heeft besloten om ten gunste van Gammix een tweetal correcties uit te voeren op de geschatte omzet.',
# ...
#       '48.Dat het aanbod Nederlandse deelnemers bereikt, blijkt tevens uit de hoge bezoekersaantallen op de websites, zoals beschreven in de randnummers 34 en 35.',
#       '49. De zienswijze van overtreder heeft geen aanleiding gegeven om af te zien van het voornemen last onder dwangsom.',
#       'Overwegingen tot oplegging last',
#       '50. Handhavend optreden tegen aanbieders van kansspelen waarvoor geen vergunning is verleend is noodzakelijk om de overtreding te doen beëindigen, en beëindigd te houden, en de zwaarwegende belangen van de Wok zoals hierboven vermeld, te beschermen. Naast het opleggen van boetes  kan de Kansspelautoriteit ook handhaven door middel van het opleggen van een last onder dwangsom.',
#       '51.Met het oog op het evenredigheidsbeginsel van artikel 3:4, tweede lid, van de Awb is de Kansspelautoriteit van oordeel dat de belangen van overtreder derhalve niet onevenredig worden geschaad door dit besluit en het daarmee gediende belang. Zij verwijst daarvoor naar de overwegingen in paragrafen 5 en 6 '],
#      'head_text': ['Kansspelautoriteit'],
#      'foot_text': ['11']},
#     {'body_text': ['22 juni 2022 Kenmerk 14829/01.270.078',
#       'Hoogte dwangsom en begunstigingstermijn',
#       'c Na het verstrijken van de onder randnummer a genoemde begunstigingstermijn verbeurt overtreder een dwangsom van €1.470.000, per week tot een maximum van €4.412.000,- .',
#       "'s-Gravenhage, 22 juni 2022",
#       'Handhavingsbeleid , Prioritering van handhavingsonderzoeken, Stcrnt. 2021/44765.'],
#      'head_text': ['Kansspelautoriteit'],
#      'foot_text': ['13']},
#     {'body_text': ['22 juni 2022 Kenmerk 14829/01.270.078',
#       'De raad van bestuur van de Kansspelautoriteit, namens deze,',
#       'W.g.',
#       'mr. Ella J. Seijsener Waarnemend afdelingshoofd Handhaving',
#       'Bezwaar maken U kunt tegen deze beslissing bezwaar maken door een gemotiveerd bezwaarschrift in te dienen binnen zes weken na bekendmaking van deze beslissing. U kunt uw bezwaarschrift sturen naar het volgende adres:',
#       'Kansspelautoriteit Afdeling Juridische Zaken en Vergunningen Postbus 298 2501 CG Den Haag',
#       'U kunt uw bezwaarschrift ook door uw gemachtigde laten indienen. Als de gemachtigde geen advocaat is, moet u een machtiging bijvoegen bij uw bezwaarschrift.',
#       'Zorg ervoor dat uw bezwaarschrift in elk geval het volgende bevat: uw naam en adres; de datum waarop u het bezwaarschrift schrijft; een kopie van de beslissing; de gronden van uw bezwaar; UW handtekening of de handtekening van UW gemachtigde.',
#       'Let wel: het instellen van bezwaar schort de werking van dit besluit niet op. Kunt u de beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan kunt u bij de sector bestuursrecht van de rechtbank in uw arrondissement een verzoek om voorlopige voorziening indienen.'],
#      'head_text': ['Kansspelautoriteit'],
#      'foot_text': ['14']}],
#    'header_dates': [],
#    'status': 'In deze zaak is de beslissing op bezwaar genomen. Tegen deze beslissing op bezwaar is inmiddels beroep ingesteld bij de rechtbank.'},
#   {'url': 'https://kansspelautoriteit.nl/publish/library/32/20220707_01_270_081_-_besluit_openbaarmaking_gammix_ov.pdf',
#    'pages': [{'body_text': ['Besluit als bedoeld in artikel 3.1 van de Wet open overheid.',
#       'Datum: 22 juni 2022 Kenmerk: 14829/01.265.483 Openbaarmaking onder kenmerk: 14829/01.270.081',
#       'Besluit tot openbaarmaking',
#       'Besluit tot openbaarmaking van het besluit van 22 juni 2022 (kenmerk 14829/01.263.965) tot oplegging van een last onder dwangsom aan Gammix Limited.',
#       'Inleiding',
#       'Bij besluit van 22 juni 20221 aan Gammix Limited heeft de raad van bestuur van de Kansspelautoriteit (hierna: de raad van bestuur) op grond van artikel 1, eerste lid, aanhef en onder a, van de Wet op de kansspelen besloten tot oplegging van een last onder dwangsom (hierna: de last onder dwangsom) .',
#       'Overwegingen',
#       'De raad van bestuur maakt sanctiebesluiten en daarop volgende besluiten in beginsel openbaar op grond van artikel 3.1 van de Wet open overheid (hierna: Woo) .',
#       "De raad van bestuur hecht eraan sanctiebesluiten openbaar te maken vanwege het maatschappelijk belang om de consument te informeren over dan wel te waarschuwen voor bepaalde handelspraktijken van aanbieders van kansspelen zonder vergunning en de risico's die consumenten daarbij lopen. Daarnaast beoogt de raad van bestuur met de openbaarmaking van sanctiebesluiten transparantie te",
#       'Besluit van 22 juni 2022, kenmerk 14829/01.263.965.'],
#      'head_text': ['Kansspelautoriteit', 'OPENBAAR'],
#      'foot_text': []},
#     {'body_text': ['bieden met betrekking tot het functioneren van zijn organisatie: Ten slotte is openbaarmaking van belang in verband met de preventieve werking die van sanctiebesluiten kan uitgaan naar andere ondernemingen en natuurlijke personen.',
#       'De raad van bestuur acht openbaarmaking ook in dit concrete geval in het belang',
#       'van consumenten die aldus kennis kunnen nemen van het feit dat ten aanzien van Gammix Limited is vastgesteld dat zij in strijd heeft gehandeld met artikel 1, eerste lid, onder a, van de Wok en dat de raad van bestuur hiertegen heeft opgetreden.',
#       'De raad van bestuur neemt hierbij het volgende in aanmerking .',
#       'De Afdeling bestuursrechtspraak van de Raad van State (hierna: de Afdeling) heeft bij uitspraak van 10 november 2010, ECLI:NL:RVS:2010.B03468, bepaald: Het boetebesluit is een bevoegd genomen besluit in het kader van een aan het college door de wetgever toegekende taak om toezicht te houden op de naleving van regelgeving en de daarmee samenhangende bevoegdheid om handhavend op te treden tegen overtreding van die regelgeving. In het kader van deze toezichthoudende taak past dat boetebesluiten worden gepubliceerd, zodat bekendheid wordt gegeven aan de wijze van uitvoering van deze taak" (overweging 2.5)',
#       'Ten aanzien van de vereiste belangenafweging bepaalde de Afdeling in voornoemde uitspraak: "Van een onevenredige benadeling zal in gevallen als de onderhavige naar het oordeel van de Afdeling sprake kunnen zijn als het boetebesluit uiteindelijk in rechte geen stand houdt en de betrokken rechtspersoon ten onrechte als overtreder kenbaar is gemaakt. Of sprake is van onevenredige benadeling hangt',
#       'dan af van een oordeel over de rechtmatigheid van het boetebesluit."',
#       'Ook voor andere informatie die een bezwarend karakter kan dragen voor betrokkenen geldt dat artikel 3 van de Woo de grondslag vormt om die informatie openbaar te maken, mits de openbaarmaking van die informatie past in de taak van het betrokken bestuursorgaan. De raad van bestuur is van oordeel dat in dit kader ook openbaarmaking van andere sanctiebesluiten, zoals besluiten waarbij herstelsancties zijn opgelegd, en daarop volgende besluiten, zoals een besluit tot',
#       'Afdeling bestuursrechtspraak Raad van State 25 maart 2015, ECLI:NL:RVS:2015.938, AB 2015/194.'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': []},
#     {'body_text': ['invordering van verbeurde dwangsommen of een besluit tot vaststelling van de kosten van bestuursdwang, in de rede ligt. Gammix Limited is per brief van 12 april 20223 geïnformeerd over het voornemen tot oplegging van een last onder dwangsom en de openbaarmaking daarvan en is in de gelegenheid gesteld om hierover een zienswijze te geven. De Kansspelautoriteit heeft op 12 mei 2022 een zienswijze ontvangen. De Kansspelautoriteit heeft echter geen zienswijze op de openbaarmaking van u ontvangen.',
#       '10.De raad van bestuur wijst erop dat de namen van natuurlijke personen en de namen van rechtspersonen die in het onderzoek zijn genoemd, maar van wie geen overtreding is vastgesteld, nimmer openbaar worden gemaakt. Verwijzingen naar namen die genoemd worden in jurisprudentie en reeds openbaar gemaakte besluiten van de Kansspelautoriteit vallen hier niet onder.',
#       '11.De raad van bestuur merkt voorts op dat er een belang is bij openbaarmaking uit het oogpunt van consumentenbescherming. De websites wwwnordslot com en WWW rantcasino com zijn mede gericht op de Nederlandse markt. Het spelen van kansspelen bij een aanbieder zonder vergunning is een overtreding van artikel 1, eerste lid, onder c, van de Wok als een speler ook bekend is met het feit dat geen vergunning is verleend. Deze strafbaarstelling richt zich nadrukkelijk tot spelers.',
#       '12. Openbaarmaking geschiedt met het oog op de hiervoor weergegeven belangen: het informeren van consumenten, generale en speciale preventie en transparantie van het werk van de Kansspelautoriteit. Openbaarmaking is derhalve zeer relevant. Openbaarmaking is eens te meer van belang omdat consumenten zo kunnen worden behoed voor het plegen van een overtreding.',
#       '13.De raad van bestuur is tevens van oordeel dat er geen aanleiding is te veronderstellen dat het sanctiebesluit in rechte geen stand zal houden. Naar het oordeel van de raad van bestuur is afdoende aangetoond dat er sprake is van een overtreding van artikel 1, eerste lid, onder a, van de Wok.',
#       '14.Van andere belangen of omstandigheden  op grond waarvan zou moeten worden afgezien van openbaarmaking, is de raad van bestuur niet gebleken.',
#       'Kenmerk 14829/01.257.087'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': ['3']},
#     {'body_text': ['Besluit',
#       '15.Op grond van het voorgaande zal de raad van bestuur overgaan tot openbaarmaking van het besluit van 22 juni 2022 met kenmerk 14829/01.263.965. Tevens zal dit besluit tot openbaarmaking openbaar worden gemaakt.',
#       '16.In de openbaar te maken besluiten blijft vermelding van de namen van alle in de zaak betrokken natuurlijke personen achterwege. Ook blijft achterwege openbaarmaking van de namen van rechtspersonen ten aanzien van wie geen overtreding wordt vastgesteld en geen sanctie wordt opgelegd.',
#       '17. Openbaarmaking geschiedt door middel van publicatie op de website Www_kansspelautoriteitnl',
#       "'s-Gravenhage, 22 juni 2022",
#       'De raad van bestuur van de Kansspelautoriteit, namens deze,',
#       'W.g.',
#       'mr. Ella J. Seijsener Waarnemend afdelingshoofd Handhaving'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': []},
#     {'body_text': ['Bezwaar maken U kunt tegen deze beslissing bezwaar maken door een gemotiveerd bezwaarschrift in te dienen binnen zes weken na bekendmaking van deze beslissing. U kunt uw bezwaarschrift sturen naar het volgende adres:',
#       'Kansspelautoriteit Afdeling Juridische Zaken en Vergunningen Postbus 298 2501 CG Den Haag',
#       'U kunt uw bezwaarschrift ook door uw gemachtigde laten indienen. Als de gemachtigde advocaat moet u een machtiging bijvoegen bij uw bezwaarschrift.',
#       'Zorg ervoor dat uw bezwaarschrift in elk geval het volgende bevat: uw naam en adres; de datum waarop u het bezwaarschrift schrijft; een kopie van de beslissing; de gronden van uw bezwaar; UW handtekening of de handtekening van UW gemachtigde.',
#       'Let wel: het instellen van bezwaar schort de werking van dit besluit niet op. Kunt u de beslissing op uw bezwaarschrift niet afwachten vanwege een spoedeisend belang? Dan kunt u bij de sector bestuursrecht van de rechtbank in UW arrondissement een verzoek om voorlopige voorziening indienen.'],
#      'head_text': ['OPENBAAR'],
#      'foot_text': []}],
#    'header_dates': [],
#    'status': 'Tegen dit besluit is geen bezwaar gemaakt. Het besluit is thans onherroepelijk.'}],
#  'date_range': ('2023-12-12', '2023-12-13'),
#  'money': ['19679000',
#   '900000',
#   '20000',
#   '302765715',
#   '302765715',
#   '302765715',
#   '19679000',
#   '19679000',
#   '4410000',
#   '1470000',
#   '4410000',
#   '4410000',
#   '1470000',
#   '4410000',
#   '4410000',
#   '1470000',
#   '4410000',
#   '20000',
#   '1470000',
#   '4412000'],
#  'ecli': [],
#  'case_detail_url': 'https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/gammix-limited/'}

# %% [markdown]
# # Write out
#
# Now write that augmented structure into something we can call a dataset

# %%
import wetsuite.datasets

kse = wetsuite.helpers.localdata.MsgpackKV('kansspelautoriteit-sancties-struc.db', key_type=str)


kse._put_meta('description_short', 'Metadata and plain text form of the set of PDFs you can find under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/ ' )

kse._put_meta('description', '''This is a plaintext form of the set of documents you can find under https://kansspelautoriteit.nl/aanpak-misstanden/sanctiebesluiten/ as PDFs.

        Since almost half of those PDFs do not have a text stream, this data is entirely OCR'd,
        so expect some typical OCR errors.  The OCR quality seems fairly decent, and some effort was made to remove headers and footers,
        yet there are some leftovers  like _ instead of . and = instead of :


        The data is a fairly nested structure of python objects (or JSON, before it's parsed).
        - .data is a list of cases.

        - each case is a dict, with a 
            - 'name', 
            - 'docs' (a list) 
            - and some extracted information like mentioned money amounts, the apparent date span of the case

        - each document in that mentioned list is is a dict, with keys like
            - 'url' - to the PDF it came from
            - 'status' - from the detail page (if we could find it - not 100%) 
            - extracted informations like 'header_dates' (comes from PDF contents)
            - 'pages' (a list)

        - each page in that list is a dict, which has keys:
            - 'body_text' - a list, which containts text fragments that are _almost_ like paragraphs 
                except that text may continue between pages anyway - currently still up to you to detect - 
                plus the post-OCR processing isn't perfect.
            - 'foot_text' - generally just [ "Pagina 1 van 27" ]
            - 'head_text' - fragments like []"Kansspelautoriteit", "OPENBAAR"] but also the date and kenmerk lines


        (TODO: update this example)
        For example (body text edited for brevity), one case's dict, with one document:
            { # dict for a case
                'name': 'Toto Online B.V.',  # case's name
                'docs': [                    # list of PDF documents in this case
                    { # dict detailing first document in case
                        'url': 'https://kansspelautoriteit.nl/publish/library/32/01_278_071_15091_sanctiebesluit_toto_ov.pdf',
                        'pages': [
                            {  # first page's dict   (currently contains only body's text fragments; idea was to split off header contents)
                                'body_text':[  # first page's text fragments
                                    'Besluit van de raad van [more sentence]',
                                    'Zaak: 15091 Kenmerk: 15091 [more kenmerk]',
                                    'Besluit',
                                    'Inleiding',
                                    'De raad van bestuur van de Kansspelautoriteit [more paragraph]'
                                ]
                            },
                            { # second page's dict
                                'body_text': [   # second page text fragment
                                'heeft heeft ontvangen sinds hij daar [more paragraph]',
                                'De toezichthouders zijn naar aanleiding [more paragraph]'
                                ]
                            } 
                            # ...more pages
                        ], 
                    }, # end of document dict
                    # ...more documents
                ]
            }
        '''+wetsuite.datasets.generated_today_text())

for d in dataset_cases:
    kse.put( d.get('case_detail_url'), d)
