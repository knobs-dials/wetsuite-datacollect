# %% [markdown]
# <a href="https://colab.research.google.com/github/knobs-dials/wetsuite-datacollect/blob/main/tweede_kamer_apis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Purpose of this notebook
#
# Mainly to explore the two APIs at the [tweede kamer open data portal](https://opendata.tweedekamer.nl/),
# seeing what you might use them for.

# %% [markdown]
# Those two interface are:
# - an [Atom-style API called SyncFeed](https://opendata.tweedekamer.nl/documentatie/syncfeed-api), and
#   - a little easier to interact without a whole library.
# - an [OData API](https://opendata.tweedekamer.nl/documentatie/odata-api).
#   - The OData is a little bit more up-front preparation, but can be more thorough and flexible.
#
# The formats in the interaction are XML and JSON.

# %% [markdown]
# Both APIs adhere to the same [relational data model](https://opendata.tweedekamer.nl/documentatie/informatiemodel) that you should be thinking of.
#
# This notebook and its compantion will end up not being interested in most of its parts,
# yet we try to give at least _some_ introduction to the less trivial bits.
#
# Relational means that data refers to other data, so much of the below is trying to explore/show
# what kind of interesting things might be in there in the first place.
#
# ...because we probably don't want to just fetch everything,
# we want to show how to figure how to get and use the parts you need for a specific purpose.

# %% [markdown]
# A footnote before we get intro technical details:
#
# Neither API is is a very _fast_ interface,
# nor will they be efficient when your goal is sifting through the entire collection in ways it was not initially designed for.
# (It also seems it sometimes refuses to connect?)
# That is part of why it might be interesting to some to have this notebook, and the produced dataset just give you the actual list.

# %% [markdown]
# ## Atom/SyncFeed API
#
# Let's take a look at this API first.

# %% [markdown]
# ### "Fetch one resource type"
#
# SyncFeed starts by interacting with an URL like:
#
#         https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Persoon
#
# ...if you load that in a browser, you will see the first bunch/page of them, and links to successive pages.
#
# To fetch all resources of the mentioned soort/category, and to then perhaps make a single list of it,
# you need something that follows and fetches those links. Code like our `wetsuite.datacollect.tweedekamer_nl.fetch_all` does just that.
#
# That said, due to the relational nature of of the data (pointing at related objects, and you often wanting to fetch a related constellation of them),
# it quickly becomes interesting to interrogate the data with more foresight - we'll get to that later.

# %%
import random
import collections
import pprint
import os 

import wetsuite.datacollect.tweedekamer_nl  # contains some basic code dealing with the syncfeed API
from wetsuite.helpers  import etree
from wetsuite.helpers  import strings
from wetsuite.helpers  import notebook

# %%
wetsuite.datacollect.tweedekamer_nl.resource_types  # This is a list from our library.  We could also fetch these, but they would be the same.
# Out:
# ('Activiteit',
#  'ActiviteitActor',
#  'Agendapunt',
#  'Besluit',
#  'Commissie',
#  'CommissieContactinformatie',
#  'CommissieZetel',
#  'CommissieZetelVastPersoon',
#  'CommissieZetelVastVacature',
#  'CommissieZetelVervangerPersoon',
#  'CommissieZetelVervangerVacature',
#  'Document',
#  'DocumentActor',
#  'DocumentVersie',
#  'Fractie',
#  'FractieAanvullendGegeven',
#  'FractieZetel',
#  'FractieZetelPersoon',
#  'FractieZetelVacature',
#  'Kamerstukdossier',
#  'Persoon',
#  'PersoonContactinformatie',
#  'PersoonGeschenk',
#  'PersoonLoopbaan',
#  'PersoonNevenfunctie',
#  'PersoonNevenfunctieInkomsten',
#  'PersoonOnderwijs',
#  'PersoonReis',
#  'Reservering',
#  'Stemming',
#  'Vergadering',
#  'Verslag',
#  'Zaak',
#  'ZaakActor',
#  'Zaal')

# %% [markdown]
# Uses vary.
# - Below, we'll end up extracting who is member of what party,
#   which is a somewhat manual piecing together of 'Persoon', 'Fractie', 'FractieZetel', and 'FractieZetelPersoon'.
#
# - If you wanted a record of what gets done in an everyday way, you might care about 'Vergadering', 'Verslag', 'Stemming',
#
# - if you are more interested in documentation, then 'Document', 'Kamerstukdossier'
#
# - The 'Zaak' type lies somewhere inbetween
#
# - Kamerstukdossiers are interesting for their wocnents, relating/organizing Zaken, Documents, and more.
#   Their relations are a little more complex than they seem at first, which is why it's not our first example.
#
# For a list of types with some explanation of their relations, see [the documentation](https://opendata.tweedekamer.nl/documentatie/).

# %% [markdown]
# #### Smaller example: Zaal
#
# This doesn't do much by itself.
#
# You would probably only do this when you want to know what Activiteiten happened where.
#
# This just serves as an example of basic interation, that doesn't have spammy output.

# %%
zaal_etrees = wetsuite.datacollect.tweedekamer_nl.fetch_all( 'Zaal' ) 
# The helper functions consider that this comes from separate fetches, and that in some cases you may not want to fetch all
# (consider that e.g. all Stemming, Zaak, Document total to hundreds of megabytes)

# So fetch_all() specifically _does_ return all, as a list of etree objects, one for each page of results. 
# Chances are we want to see that as one big list...
zaal_tree = wetsuite.datacollect.tweedekamer_nl.merge_etrees( zaal_etrees )

# %%
# ...whether you want write it out into a file...
with open('Zaal.xml', 'wb') as zaal_file:
    zaal_file.write( wetsuite.helpers.etree.tostring( zaal_tree ) )

# %%
# ...or consume it in code. For which you probably want to use the following helpers to see that XML as python dicts...
entry_dicts = wetsuite.datacollect.tweedekamer_nl.entry_dicts( zaal_tree )

pprint.pprint( entry_dicts[:2] ) # show a few

# and for reference, the XML that came from:
#print( wetsuite.helpers.etree.debug_pretty( zaal_tree ) )
# Out:
# [{'category': 'zaal',
#   'content': {'bijgewerkt': '2019-08-12T12:56:35.4070000',
#               'id': '6e7dfdae-583a-4191-8818-a89a538c469f',
#               'naam': 'Z7 - Statenpassage - Petitie',
#               'sysCode': '154',
#               'tagname': 'zaal',
#               'verwijderd': 'false'},
#   'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/6e7dfdae-583a-4191-8818-a89a538c469f',
#   'title': '6e7dfdae-583a-4191-8818-a89a538c469f',
#   'updated': '2019-08-15T14:45:52Z'},
#  {'category': 'zaal',
#   'content': {'bijgewerkt': '2019-08-12T12:56:34.8600000',
#               'id': 'f207b9d5-434e-4cdc-aa1b-7e5a55bc1791',
#               'naam': 'Eerste Kamer',
#               'sysCode': '101',
#               'tagname': 'zaal',
#               'verwijderd': 'false'},
#   'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/f207b9d5-434e-4cdc-aa1b-7e5a55bc1791',
#   'title': 'f207b9d5-434e-4cdc-aa1b-7e5a55bc1791',
#   'updated': '2019-08-15T14:45:52Z'}]

# %%
# ...where the dicts are mor3e directly useful. An example of picking things from such dicts:
for detail_dict in wetsuite.datacollect.tweedekamer_nl.entry_dicts( zaal_tree ):
    print(f"{detail_dict['content']['naam']:40s}    {detail_dict['updated']}")
# Out:
# Z7 - Statenpassage - Petitie                2019-08-15T14:45:52Z
# Vondelingkamer                              2021-06-18T19:20:21Z
# (Nog) geen zaal beschikbaar                 2021-06-25T12:59:02Z
# Max van der Stoelzaal                       2021-06-29T08:15:20Z
# Groen van Prinstererzaal                    2021-07-08T06:42:59Z
# VVD Fractiekamer                            2021-09-03T09:47:55Z
# Klompézaal                                  2022-03-30T14:16:33Z
# Balzaal                                     2023-03-29T08:10:29Z

# %% [markdown]
# ### What about documents?
#
# The above does not mention documents part of the dossiers.
#
# So what do documents mention?

# %%
# break_actually stops after the first page, because the full set is 700+ MByte and would easily take ten minutes 
# (you don't really need to run this, this is mainly here for a point we are about to make below)
firstpage = wetsuite.datacollect.tweedekamer_nl.fetch_all( 'Document', break_actually=True )[0]

#print( wetsuite.helpers.etree.debug_pretty( firstpage.find('entry') ) ) # first entry, for reference.
doc_dicts = wetsuite.datacollect.tweedekamer_nl.entry_dicts( firstpage )
pprint.pprint( doc_dicts[-2:] )
# Out:
# [{'category': 'document',
#   'content': {'bijgewerkt': '2019-07-03T15:32:12.6700000',
#               'id': 'd1bd5ec5-72fb-4702-8115-b6d24b552cdb',
#               'tagname': 'document',
#               'verwijderd': 'true'},
#   'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/d1bd5ec5-72fb-4702-8115-b6d24b552cdb',
#   'title': 'd1bd5ec5-72fb-4702-8115-b6d24b552cdb',
#   'updated': '2019-07-03T13:33:10Z'},
#  {'category': 'document',
#   'content': {'bijgewerkt': '2019-07-03T15:33:02.7970000',
#               'id': '3f75d7c1-379e-4241-9f82-539d244887ff',
#               'tagname': 'document',
#               'verwijderd': 'true'},
#   'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/3f75d7c1-379e-4241-9f82-539d244887ff',
#   'title': '3f75d7c1-379e-4241-9f82-539d244887ff',
#   'updated': '2019-07-03T13:33:10Z'}]

# %% [markdown]
# Documents seem to just be their _content_, and basically no metadata.
#
# That turns out not the be that useful.
# They seem meaningful only in the context of other things,
# for example as the things that are contained within kamerstukdossiers - and you would probably _start_ looking at kamerstukdossiers.
#
# This turns out to be a little more complex (see part 2). First, we do something that requires less investigation:

# %% [markdown]
# ### What about parties?
#
# Our quest is "make a list of who is part of what party".
#
# This information is spread four different resource types: `Persoon`, `FractieZetelPersoon`, `FractieZetel`, `Fractie`.
#
# You can see FractieZetelPersoon as something like [many-to-many junction table](https://en.wikipedia.org/wiki/Many-to-many_(data_model)):
# - a reference to a FractieZetel, which itself just references a Fractie
# - a reference to a and Persoon
#
# Persoon and Fractie have no references, so are just details to each item.
#
# The below code
# does the relational joins for party membership,
# then flattens the results by adding membership to the persoon details.

# %%
import json
import pprint
import random

import wetsuite.datacollect.tweedekamer_nl   # contains some basic code dealing with this API
import wetsuite.helpers.etree

# %%
# Fetch all resources of the mentioned soort.
# The combination should take no longer than a minute or two.
print("Fetching Persoon")
data_Persoon            = wetsuite.datacollect.tweedekamer_nl.merge_etrees( wetsuite.datacollect.tweedekamer_nl.fetch_all( 'Persoon' ) )
print("Fetching Fractie")
data_Fractie            = wetsuite.datacollect.tweedekamer_nl.merge_etrees( wetsuite.datacollect.tweedekamer_nl.fetch_all( 'Fractie' ) )
print("Fetching FractieZetel")
data_FractieZetel       = wetsuite.datacollect.tweedekamer_nl.merge_etrees( wetsuite.datacollect.tweedekamer_nl.fetch_all( 'FractieZetel' ) )
print("Fetching FractieZetelPersoon")
data_FractieZetelPesoon = wetsuite.datacollect.tweedekamer_nl.merge_etrees( wetsuite.datacollect.tweedekamer_nl.fetch_all( 'FractieZetelPersoon' ) )
# Out:
# Fetching Persoon
# Fetching Fractie
# Fetching FractieZetel
# Fetching FractieZetelPersoon

# %%
# For some insight/reference, the XML form of a FractieZetelPersoon entry:
print( wetsuite.helpers.etree.debug_pretty(data_FractieZetelPesoon.find('entry')) )
# and the way we flatten that into dicts:
display( wetsuite.datacollect.tweedekamer_nl.entry_dicts( data_FractieZetelPesoon ) [0] )
# Out:
# <entry>
#   <title>808fcd50-a0dc-4f60-8b9d-c404a2eb5b2e</title>
#   <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/808fcd50-a0dc-4f60-8b9d-c404a2eb5b2e</id>
#   <author>
#     <name>Tweede Kamer der Staten-Generaal</name>
#   </author>
#   <updated>2023-08-29T13:23:13Z</updated>
#   <category term="fractieZetelPersoon"/>
#   <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=FractieZetelPersoon&amp;skiptoken=16687327"/>
#   <content type="application/xml">
#     <fractieZetelPersoon id="808fcd50-a0dc-4f60-8b9d-c404a2eb5b2e" bijgewerkt="2023-08-29T11:10:24Z" verwijderd="false">
#       <fractieZetel ref="ca826e72-cf57-4cca-b090-d5c444ec6c2d"/>
#       <persoon ref="ec273841-069f-408b-b434-8524904ae314"/>
#       <functie>Lid</functie>
#       <van>2002-05-23</van>
#       <totEnMet>2010-10-11</totEnMet>
#     </fractieZetelPersoon>
#   </content>
# </entry>
# {'title': '808fcd50-a0dc-4f60-8b9d-c404a2eb5b2e',
#  'updated': '2023-08-29T13:23:13Z',
#  'category': 'fractieZetelPersoon',
#  'content': {'refs': {'fractieZetel': 'ca826e72-cf57-4cca-b090-d5c444ec6c2d',
#    'persoon': 'ec273841-069f-408b-b434-8524904ae314'},
#   'tagname': 'fractieZetelPersoon',
#   'id': '808fcd50-a0dc-4f60-8b9d-c404a2eb5b2e',
#   'bijgewerkt': '2023-08-29T11:10:24Z',
#   'verwijderd': 'false',
#   'functie': 'Lid',
#   'van': '2002-05-23',
#   'totEnMet': '2010-10-11'},
#  'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/808fcd50-a0dc-4f60-8b9d-c404a2eb5b2e'}

# %%
# Since we just fetched completely separate things,
# we need to _ourselves_ do what amounts to a manual JOIN of relational data

# We can make that job a little more bite-sized by making some assisting data
# specifically making it easier to fetch varied individual items
# by letting ourselves later do by id, and by type. 
# Why we do this should become clearer in the next code block.
id_thing = {}   #               guid -> detailsdict
by_type  = {}   #     soort/category -> list of all such detailsdicts

for etree in (data_Persoon, data_Fractie, data_FractieZetel, data_FractieZetelPesoon):
    for entry_dict in wetsuite.datacollect.tweedekamer_nl.entry_dicts( etree ):
        id_thing[ entry_dict['content']['id'] ] = entry_dict

        category = entry_dict['category']
        if category not in by_type:
            by_type[category] = []
        by_type[ category ].append( entry_dict )

# %%
# That join-y code could look like:
persoon_combined = {}  # which is mostly still the persoon dicts, except we added a key that is the membership

for fzp_dict in by_type['fractieZetelPersoon']:
    content = fzp_dict['content']

    if 'fractieZetel' not in content['refs']:
        print("  FractieZetelPersoon item without FractieZetel - huh? %r"%fzp_dict)
        continue

    fractiezetel_id = content['refs']['fractieZetel']
    persoon_id      = content['refs']['persoon']

    fractiezetel_dict = id_thing[ fractiezetel_id ]
    persoon_dict      = id_thing[ persoon_id ]

    fractie_id = fractiezetel_dict['content']['refs']['fractie']
    frac_dict = id_thing[ fractie_id ]

    if persoon_id not in persoon_combined:
        persoon_combined[ persoon_id ] = persoon_dict
        persoon_combined[ persoon_id ]['fractie_membership'] = []
        
    persoon_combined[ persoon_id ]['fractie_membership'].append( 
        {
            'fractie_id':frac_dict['content']['id'], 
            'fractie_afkorting':frac_dict['content']['afkorting'], 
            # maybe more or all of frac_dict?
            'functie':fzp_dict['content']['functie'], 
            'van':fzp_dict['content']['van'], 
            'totEnMet':fzp_dict['content']['totEnMet'],
        } 
    )
# Out:
#   FractieZetelPersoon item without FractieZetel - huh? {'title': 'd73d7f69-1235-4746-aa94-84b593909bfc', 'updated': '2023-08-29T14:00:09Z', 'category': 'fractieZetelPersoon', 'content': {'refs': {}, 'tagname': 'fractieZetelPersoon', 'id': 'd73d7f69-1235-4746-aa94-84b593909bfc', 'bijgewerkt': '2023-08-29T11:10:32Z', 'verwijderd': 'true'}, 'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/d73d7f69-1235-4746-aa94-84b593909bfc'}
#   FractieZetelPersoon item without FractieZetel - huh? {'title': '8cca26af-365a-46fc-b72f-c42b2a17a992', 'updated': '2023-12-06T13:48:37Z', 'category': 'fractieZetelPersoon', 'content': {'refs': {}, 'tagname': 'fractieZetelPersoon', 'id': '8cca26af-365a-46fc-b72f-c42b2a17a992', 'bijgewerkt': '2023-12-05T14:58:31Z', 'verwijderd': 'true'}, 'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/8cca26af-365a-46fc-b72f-c42b2a17a992'}
#   FractieZetelPersoon item without FractieZetel - huh? {'title': '6d685347-a5c8-498b-94df-b7bbb1bc1272', 'updated': '2023-12-06T13:48:37Z', 'category': 'fractieZetelPersoon', 'content': {'refs': {}, 'tagname': 'fractieZetelPersoon', 'id': '6d685347-a5c8-498b-94df-b7bbb1bc1272', 'bijgewerkt': '2023-12-05T15:00:13Z', 'verwijderd': 'true'}, 'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/6d685347-a5c8-498b-94df-b7bbb1bc1272'}

# %%
fracs = {} # id -> details, for consistency with the above and easier lookup
for fracs_dict in by_type['fractie']:
    fracs[ fracs_dict['id'] ] = fracs_dict

# %% [markdown]
# As an indication of what we have just constructed:

# %%
random.choice( list(fracs.values()) )
# Out:
# {'title': '8fd1a907-0355-4d27-8dc1-fd5a531b471e',
#  'updated': '2023-10-27T08:47:09Z',
#  'category': 'fractie',
#  'content': {'refs': {},
#   'tagname': 'fractie',
#   'id': '8fd1a907-0355-4d27-8dc1-fd5a531b471e',
#   'bijgewerkt': '2023-10-27T08:46:51Z',
#   'verwijderd': 'false',
#   'contentType': 'image/png',
#   'contentLength': '3715',
#   'nummer': '2756',
#   'afkorting': 'GL',
#   'naamNl': 'GroenLinks',
#   'naamEn': 'Green Left',
#   'aantalZetels': '0',
#   'aantalStemmen': '537308',
#   'datumActief': '1990-11-24',
#   'datumInactief': '2023-10-26'},
#  'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/8fd1a907-0355-4d27-8dc1-fd5a531b471e'}

# %%
random.choice( list(persoon_combined.values()) )
# Out:
# {'title': 'fcdd8eba-ce4c-40ad-b68e-4fe542abd6b3',
#  'updated': '2023-08-29T11:15:11Z',
#  'category': 'persoon',
#  'content': {'refs': {},
#   'tagname': 'persoon',
#   'id': 'fcdd8eba-ce4c-40ad-b68e-4fe542abd6b3',
#   'bijgewerkt': '2023-08-29T11:09:45Z',
#   'verwijderd': 'false',
#   'contentType': 'image/jpeg',
#   'contentLength': '30297',
#   'nummer': '1044',
#   'titels': 'drs.',
#   'initialen': 'M.I.',
#   'tussenvoegsel': None,
#   'achternaam': 'Hamer',
#   'voornamen': 'Mariëtte Iris',
#   'roepnaam': 'Mariëtte',
#   'geslacht': 'vrouw',
#   'functie': 'Oud Kamerlid',
#   'geboortedatum': '1958-06-07',
#   'geboorteplaats': 'Amsterdam',
#   'geboorteland': 'Nederland',
#   'overlijdensdatum': None,
#   'overlijdensplaats': None,
#   'woonplaats': 'Maassluis',
#   'land': 'NL',
#   'fractielabel': None},
#  'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/fcdd8eba-ce4c-40ad-b68e-4fe542abd6b3',
#  'fractie_membership': [{'fractie_id': '8d46d23c-4f20-49be-b279-5439a2ef8d17',
#    'fractie_afkorting': 'PvdA',
#    'functie': 'Lid',
#    'van': '2004-11-10',
#    'totEnMet': '2014-09-09'},
#   {'fractie_id': '8d46d23c-4f20-49be-b279-5439a2ef8d17',
#    'fractie_afkorting': 'PvdA',
#    'functie': 'Lid',
#    'van': '1998-05-19',
#    'totEnMet': '2004-11-09'}]}

# %%
print("WRITING as JSON (tweedekamer-fracties-struc.json, tweedekamer-fractie-membership-struc.json)")

with open('tweedekamer-fracties-struc.json','wb') as jsonfile:
    jsonfile.write( json.dumps({ 
        'description_short':''' Description of political parties/fracties. ''',
        'description':      ''' Description of political parties/fracties.

    Items look something like: 
        {'title': 'ae48391e-ce4d-47e0-86e3-ee310282f66f',
        'updated': '2023-12-06T13:48:37Z',
        'category': 'fractie',
        'nummer': '50311',
        'afkorting': 'Volt',
        'naamNl': 'Volt',
        'naamEn': 'Volt',
        'aantalZetels': '2',
        'aantalStemmen': '178802',
        'datumActief': '2021-03-31',
        'datumInactief': None,
        'id': 'ae48391e-ce4d-47e0-86e3-ee310282f66f'}
        ''',
        'data':fracs} ).encode('ascii')
    )

with open('tweedekamer-fractie-membership-struc.json','wb') as jsonfile:
    jsonfile.write( json.dumps({ 
        'description_short':''' Description of people, including party memberships over time. ''',
        'description':      ''' Description of people, including party memberships over time(each with fractie_afkorting, functie, van, totEnMet) ''',
        'data':persoon_combined} ).encode('ascii')
    )

# %%
import wetsuite.helpers.localdata

print("WRITING as dataset store (tweedekamer-fracties-struc.db, tweedekamer-fractie-membership-struc.db)")

with wetsuite.helpers.localdata.MsgpackKV('tweedekamer-fracties-struc.db') as fracties_db:
    fracties_db._put_meta('description_short', ''' Description of political parties/fracties. ''')
    fracties_db._put_meta('description',       ''' Description of political parties/fracties.

    Items look something like: 
        {'title': 'ae48391e-ce4d-47e0-86e3-ee310282f66f',
        'updated': '2023-12-06T13:48:37Z',
        'category': 'fractie',
        'nummer': '50311',
        'afkorting': 'Volt',
        'naamNl': 'Volt',
        'naamEn': 'Volt',
        'aantalZetels': '2',
        'aantalStemmen': '178802',
        'datumActief': '2021-03-31',
        'datumInactief': None,
        'id': 'ae48391e-ce4d-47e0-86e3-ee310282f66f'}
        ''')
    for k, v in fracs.items():
        fracties_db.put( k, v) 

with wetsuite.helpers.localdata.MsgpackKV('tweedekamer-fractie-membership-struc.db') as membership_db:
    membership_db._put_meta('description_short', ''' Description of people, including party memberships over time. ''')
    membership_db._put_meta('description',       ''' Description of people, including party memberships over time(each with fractie_afkorting, functie, van, totEnMet) ''')

    for k, v in persoon_combined.items():
        membership_db.put( k, v)
# Out:
# WRITING as dataset store (tweedekamer-fracties-struc.db, tweedekamer-fractie-membership-struc.db)

# %% [markdown]
# ## Looking at kamerstukdossiers

# %%
# Fetch all kamerstukdossiers.    
# may take half a minute or so to fetch all, because that's ~30 fetches amounting to ~6MByte of XML.
ks_tree = wetsuite.datacollect.tweedekamer_nl.merge_etrees( wetsuite.datacollect.tweedekamer_nl.fetch_all( 'Kamerstukdossier' ) )

# %%
# Just the first entry:
print( wetsuite.helpers.etree.debug_pretty( ks_tree.find('entry') ))
# Out:
# <entry>
#   <title>1f031e16-cb3b-45b5-b3c9-a8abd27c913a</title>
#   <id>https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/1f031e16-cb3b-45b5-b3c9-a8abd27c913a</id>
#   <author>
#     <name>Tweede Kamer der Staten-Generaal</name>
#   </author>
#   <updated>2019-06-28T20:34:35Z</updated>
#   <category term="kamerstukdossier"/>
#   <link rel="next" href="https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Feed?category=Kamerstukdossier&amp;skiptoken=53457"/>
#   <content type="application/xml">
#     <kamerstukdossier id="1f031e16-cb3b-45b5-b3c9-a8abd27c913a" bijgewerkt="2008-08-26T12:13:04.6270000" verwijderd="false">
#       <titel>Wijziging van de Wet ruimtelijke ordening inzake de grondexploitatie</titel>
#       <citeertitel nil="true"/>
#       <alias nil="true"/>
#       <nummer>30218</nummer>
#       <toevoeging nil="true"/>
#       <hoogsteVolgnummer>25</hoogsteVolgnummer>
#       <afgesloten>false</afgesloten>
#       <kamer>Tweede Kamer</kamer>
#     </kamerstukdossier>
#   </content>
# </entry>

# %%
# parse that into dicts, as before
ks_dicts = list( wetsuite.datacollect.tweedekamer_nl.entry_dicts( ks_tree ) )

# %%
ks_dicts[:2]
# Out:
# [{'title': '1f031e16-cb3b-45b5-b3c9-a8abd27c913a',
#   'updated': '2019-06-28T20:34:35Z',
#   'category': 'kamerstukdossier',
#   'content': {'refs': {},
#    'tagname': 'kamerstukdossier',
#    'id': '1f031e16-cb3b-45b5-b3c9-a8abd27c913a',
#    'bijgewerkt': '2008-08-26T12:13:04.6270000',
#    'verwijderd': 'false',
#    'titel': 'Wijziging van de Wet ruimtelijke ordening inzake de grondexploitatie',
#    'citeertitel': None,
#    'alias': None,
#    'nummer': '30218',
#    'toevoeging': None,
#    'hoogsteVolgnummer': '25',
#    'afgesloten': 'false',
#    'kamer': 'Tweede Kamer'},
#   'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/1f031e16-cb3b-45b5-b3c9-a8abd27c913a'},
#  {'title': '860d1812-f14c-4830-910b-6c206454decb',
#   'updated': '2019-06-28T20:34:35Z',
#   'category': 'kamerstukdossier',
#   'content': {'refs': {},
#    'tagname': 'kamerstukdossier',
#    'id': '860d1812-f14c-4830-910b-6c206454decb',
#    'bijgewerkt': '2008-08-25T17:01:35.4670000',
#    'verwijderd': 'false',
#    'titel': 'Wachttijden in de curatieve zorg',
#    'citeertitel': None,
#    'alias': None,
#    'nummer': '25170',
#    'toevoeging': None,
#    'hoogsteVolgnummer': '42',
#    'afgesloten': 'false',
#    'kamer': 'Tweede Kamer'},
#   'id': 'https://gegevensmagazijn.tweedekamer.nl/SyncFeed/2.0/Entiteiten/860d1812-f14c-4830-910b-6c206454decb'}]

# %%
num_toe = collections.defaultdict( list )
for kd in ks_dicts:
    num_toe[ kd['content'].get('nummer') ].append( kd['content'].get('toevoeging') )

for nummer in num_toe:
    if num_toe[nummer] != [None]:
        print(nummer, num_toe[nummer])
# Out:
# 30800 ['VIII', 'XVI', 'XIV']
# 31314 ['(R1843)']
# 31444 ['IXB', 'X', None, 'XIV', 'VII', 'XII']
# 31200 ['XV', 'XIV', 'A', None, 'B', 'I', 'D', 'IXB', 'IV', 'VII', 'XVIII', 'XVII', 'VIII', 'III', 'XIII', 'XI', 'XVI', 'VI', 'XII', 'V', 'X']
# 31725 ['(R1867)']
# 31449 ['(R1857)']
# 31792 ['F', 'IIA', 'C', 'B', 'XII', 'A', 'XIII', 'VII', 'IXA', 'D', 'XVIII', 'IXB', 'XI', 'X', 'IV', None, 'V', 'XVI', 'XVII', 'XV', 'XIV', 'VI', 'VIII', 'III', 'G', 'IIB']
# 31754 ['(R1869)']
# 31740 ['(R1868)']
# 31422 ['(R1853)']
# 31429 ['(R1855)']
# 31900 ['(R1879)']
# 31846 ['(R1875)']
# 31882 ['(R1878)']
# 32167 ['(R1895)']
# 31965 ['XIII', 'III', 'E', 'VI', 'XVII', 'IXA', 'VIII', 'D', 'IXB', 'XVIII', 'V', 'B', 'C', 'VII', 'X', 'A', 'G', 'IIA', 'IV', 'XVI', 'IIB', 'XIV', 'XV', 'F', 'XII', None, 'XI']
# 31700 ['IXA', 'IIA', 'I', 'G', 'F', 'IXB', 'D', 'XIII', 'XII', 'XV', 'V', 'A', 'C', 'B', 'IV', None, 'VII', 'XVII', 'VI', 'III', 'XVIII', 'VIII', 'XVI', 'XI', 'XIV', 'E', 'IIB', 'X']
# 32148 ['(R1893)']
# 32123 ['E', 'G', 'IXA', 'IIA', 'F', 'IXB', 'D', 'C', 'III', 'VI', 'XIII', 'XVII', 'I', 'XI', 'X', None, 'XVIII', 'XVI', 'B', 'IV', 'XV', 'V', 'XIV', 'XII', 'A', 'VIII', 'VII', 'IIB']
# 32049 ['(R1891)']
# 32222 ['XIII', 'XVI', 'G', 'VI', 'III', 'XVIII', 'XV', 'XIV', 'X', 'IV', 'XI', 'XII', 'F', 'E', 'IIA', 'XVII', 'VII', 'V', 'VIII', 'A', 'IXB', 'B', 'C', 'IXA', 'D', None, 'IIB']
# 31924 ['F', None, 'D', 'IXA', 'A', 'IV', 'G', 'E', 'III', 'IIB', 'C', 'B', 'IIA', 'I', 'XVIII', 'XI', 'XVI', 'X', 'IXB', 'XVII', 'VI', 'XII', 'VIII', 'XIII', 'V', 'XV', 'VII', 'XIV']
# 32227 ['(R1904)']
# 32170 ['(R1896)']
# 31969 ['(R1881)']
# 32142 ['(R1892)']
# 31970 ['(R1882)']
# 32166 ['(R1894)']
# 31808 ['(R1872)']
# 31797 ['(R1871)']
# 32020 ['(R1887)']
# 32360 ['VI', 'IXA', 'VII', 'F', 'XVIII', 'XII', 'I', 'IXB', 'X', 'IIB', 'A', 'IIA', 'G', 'XIV', 'B', 'XIII', 'III', 'C', 'D', 'XVI', 'XVII', 'XI', 'V', 'E', 'IV', 'XV', 'VIII', None]
# 32395 ['B', 'XII', 'XV', 'D', 'IXB', 'IIB', 'I', 'XI', 'IV', 'C', 'XVI', 'E', 'IXA', 'XVIII', 'XVII', 'V', 'VII', 'XIV', 'VIII', 'G', 'F', 'X', 'IIA', 'A', 'VI', 'XIII', None, 'III']
# 32178 ['(R1898)']
# 32406 ['(R1913)']
# 32251 ['(R1905)']
# 32329 ['(R1909)']
# 32485 ['(R1917)']
# 32500 ['D', 'E', 'G', 'C', 'H', 'F', 'IIA', 'B', 'IXA', 'III', None, 'XV', 'XI', 'I', 'VIII', 'IV', 'VI', 'VII', 'XVII', 'XIV', 'XVIII', 'XII', 'IXB', 'X', 'XVI', 'XIII', 'V', 'A', 'IIB']
# 32179 ['(R1899)']
# 32510 ['(R1918)']
# 32313 ['(R1908)']
# 32330 ['(R1910)']
# 32041 ['(R1890)']
# 31879 ['(R1877)']
# 32482 ['(R1916)']
# 32354 ['(R1911)']
# 32407 ['(R1914)']
# 32511 ['(R1919)']
# 31872 ['(R1876)']
# 32710 ['III', 'I', 'E', 'XVII', 'XV', 'G', 'D', 'IIA', 'IV', 'B', 'IXA', 'IIB', 'C', 'F', 'XI', 'XVIII', 'A', 'IXB', 'VI', 'V', 'VII', 'X', 'XIII', None, 'XII', 'VIII', 'XVI', 'XIV']
# 32028 ['(R1889)']
# 32365 ['(R1912)']
# 32780 ['IXA', 'III', 'F', 'V', 'XV', 'XVI', 'IV', 'VII', 'B', 'H', 'C', 'IXB', 'X', 'XII', 'G', 'IIB', 'A', 'I', 'XIII', 'VI', 'VIII', 'IIA', None]
# 32565 ['IV', 'XVIII', 'IXB', 'xiii', 'VII', 'III', 'F', 'X', 'B', 'C', 'XIV', 'XVI', 'I', 'V', 'G', 'XV', 'VIII', 'D', 'IIA', 'VI', 'XII', 'IXA', 'XI', 'XVII', 'A', None, 'IIB']
# 32816 ['(R1955)']
# 32609 ['XVI', 'V', 'VII', 'XVIII', 'XII', 'VI', 'IXB', 'XIV', 'XV', 'XI', 'VIII', 'XVII', 'XIII']
# 32686 ['(R1941)']
# 32691 ['(R1946)']
# 32682 ['(R1937)']
# 32724 ['(R1951)']
# 32662 ['(R1933)']
# 32690 ['(R1945)']
# 32628 ['(R1925)']
# 32535 ['(R1923)']
# 32689 ['(R1944)']
# 32630 ['(R1927)']
# 32737 ['(R1952)']
# 32629 ['(R1926)']
# 32684 ['(R1939)']
# 32688 ['(R1943)']
# 32663 ['(R1934)']
# 32631 ['(R1928)']
# 32704 ['(R1948)']
# 32687 ['(R1942)']
# 32685 ['(R1940)']
# 32675 ['(R1936)']
# 32632 ['(R1929)']
# 32661 ['(R1932)']
# 32719 ['(R1950)']
# 32692 ['(R1947)']
# 32633 ['(R1930)']
# 32683 ['(R1938)']
# 33090 ['I', 'X', 'V', 'III', 'IXA', 'XII', 'IV', 'C', 'A', 'B', 'IIB', 'XVI', 'VI', 'G', 'XIII', 'XV', 'F', 'IIA', None, 'VII', 'IXB', 'VIII']
# 33198 ['(R1976)']
# 32899 ['(R1965)']
# 33000 ['F', 'IIB', 'C', 'IIA', 'IXA', 'B', 'IXB', None, 'IV', 'I', 'III', 'H', 'X', 'XV', 'VI', 'V', 'XIII', 'VIII', 'VII', 'XVI', 'A', 'XII']
# 32860 ['(R1962)']
# 32817 ['(R1956)']
# 33240 ['IXB', 'A', 'IIA', 'H', 'I', 'IIB', 'F', 'B', 'G', 'III', 'IXA', 'XV', 'C', 'XII', 'IV', 'VI', 'V', 'VIII', None, 'X', 'VII', 'XVI', 'XIII']
# 33216 ['(R1980)']
# 33087 ['(R1971)']
# 32900 ['(R1966)']
# 33265 ['(R1983)']
# 33271 ['(R1984)']
# 32897 ['(R1963)']
# 33272 ['(R1985)']
# 33280 ['VI', 'VII', 'VIII', 'III', 'IXB', 'I', 'F', 'C', 'V', 'XIII', 'XVI', 'IIB', 'IV', 'H', 'B', 'A', 'IIA', 'X', 'XV', 'IXA', 'XII', None]
# 33160 ['(R1973)']
# 33205 ['(R1978)']
# 32898 ['(R1964)']
# 33256 ['(R1982)']
# 33206 ['(R1979)']
# 33480 ['XVI', 'VII', 'IV', 'I', 'X', 'IXA', 'XII', 'V', 'IIA', 'C', 'B', 'III', 'VIII', 'IXB', 'XV', 'VI', 'F', 'H', 'XIII', 'IIB', 'A', None]
# 33560 ['(R2001)']
# 33429 ['(R1988)']
# 33400 ['IIB', 'H', 'F', 'C', 'IIA', 'XVII', 'IX', 'III', 'J', 'XVIII', 'B', 'VIII', 'A', 'I', None, 'XII', 'IV', 'VII', 'XVI', 'V', 'XV', 'X', 'XIII', 'VI']
# 33624 ['(R2004)']
# 33600 ['(R2002)']
# 33491 ['(R1996)']
# 33524 ['(R1999)']
# 33631 ['(R2006)']
# 33437 ['(R1989)']
# 33492 ['(R1997)']
# 33605 ['F', 'IV', 'XV', 'I', 'XII', 'A', 'III', 'IXB', 'IIB', 'IXA', 'B', 'V', 'IIA', 'C', 'H', 'X', 'VII', None, 'VIII', 'VI', 'XVI', 'XIII']
# 33559 ['(R2000)']
# 33514 ['(R1998)']
# 33604 ['(R2003)']
# 33629 ['(R2005)']
# 33930 ['IIA', 'IV', 'IIB', 'III', 'J', 'VII', 'H', 'F', 'I', 'B', 'A', 'X', 'C', 'V', 'VIII', 'IX', 'XV', 'XII', 'VI', 'XIII', 'XVI', None]
# 33940 ['H', 'IIA', 'XII', 'IV', 'F', 'VIII', 'X', 'VII', 'I', 'XIII', 'XVIII', 'IIB', 'B', 'XVI', 'VI', 'A', 'C', 'XV', 'XVII', 'V', 'IX', None, 'J', 'III']
# 33750 ['IIA', 'F', 'C', 'H', 'B', 'IIB', None, 'XVII', 'XII', 'IX', 'III', 'X', 'A', 'J', 'VI', 'XV', 'XVIII', 'I', 'VII', 'XVI', 'VIII', 'IV', 'V', 'XIII']
# 33705 ['(R2029)']
# 33810 ['(R2021)']
# 33655 ['(R2007)']
# 33868 ['(R2025)']
# 33805 ['H', 'F', 'VII', 'IV', 'A', 'XV', 'XII', 'IIA', 'X', 'VI', 'IX', 'IIB', 'C', 'B', 'I', 'XVI', 'VIII', 'V', 'XIII', None, 'J', 'III']
# 33776 ['(R2015)']
# 33881 ['(R2028)']
# 33794 ['(R2019)']
# 33814 ['(R2022)']
# 33784 ['(R2018)']
# 33878 ['(R2027)']
# 33739 ['(R2009)']
# 33921 ['(R2031)']
# 33365 ['(R1987)']
# 34085 ['J', 'I', 'F', 'XII', 'H', 'IIB', 'VII', 'X', 'C', 'VI', 'XIII', 'XVIII', 'IIA', 'IV', 'XV', 'IX', 'B', 'XVI', None, 'XVII', 'V', 'VIII', 'A', 'III']
# 34210 ['XVI', 'VII', 'IIA', 'XV', 'C', 'XII', 'VI', 'X', 'I', 'XVII', 'J', 'IV', 'H', 'A', 'B', 'IIB', 'XVIII', 'IX', 'V', None, 'XIII', 'VIII', 'III']
# 34350 ['IIA', 'XII', 'XVIII', 'IIB', 'H', 'A', 'I', 'IX', 'J', 'XIII', 'X', 'IV', 'VII', 'B', 'C', 'XV', 'V', 'XVI', 'VI', 'XVII', None, 'VIII', 'III']
# 34200 ['A', 'J', 'F', 'I', 'B', 'C', 'VII', 'IIA', 'III', 'IIB', 'XVIII', 'XVII', 'IX', 'IV', 'V', 'H', 'XVI', 'XII', 'X', 'XV', 'VI', None, 'XIII', 'VIII']
# 34282 ['(R2060)']
# 34131 ['(R2044)']
# 34278 ['(R2056)']
# 33968 ['(R2033)']
# 34057 ['(R2043)']
# 32008 ['(R1883)']
# 34337 ['(R2063)']
# 33992 ['(R2034)']
# 34283 ['(R2061)']
# 34048 ['(R2040)']
# 34043 ['(R2041)']
# 34281 ['(R2059)']
# 34133 ['(R2045)']
# 34000 ['IIA', 'IIB', 'H', 'XV', 'VI', 'C', 'XVIII', 'III', 'IX', 'XII', None, 'B', 'J', 'I', 'XVII', 'IV', 'XVI', 'A', 'VII', 'VIII', 'V', 'X', 'XIII']
# 34202 ['(R2051)']
# 34300 ['IIA', 'C', 'IIB', 'IX', 'B', 'J', 'XIII', 'VII', 'XII', 'V', 'XVII', 'XVIII', 'I', 'A', 'X', None, 'VIII', 'XVI', 'XV', 'VI', 'IV', 'III']
# 34277 ['(R2057)']
# 34223 ['(R2052)']
# 34485 ['A', 'J', 'I', 'XII', 'B', 'IV', 'IIB', 'C', 'X', 'V', 'IX', 'VII', 'VI', 'IIA', None, 'VIII', 'XVIII', 'XVI', 'XVII', 'XV', 'XIII', 'III']
# 31582 ['(R1866)']
# 31937 ['(R1880)']
# 33640 ['IX', 'I', 'J', 'H', 'VII', 'XIII', 'IIA', 'IV', 'XII', 'A', 'XVI', 'VI', 'VIII', 'IIB', 'X', 'C', 'F', 'B', 'XV', 'V', None, 'III']
# 34579 ['(R2076)']
# 34475 ['A', 'J', 'IX', 'XVIII', 'H', 'IV', 'III', 'IIB', 'C', 'IIA', 'B', 'I', 'VII', 'VI', None, 'X', 'V', 'XVII', 'XVI', 'XIII', 'XV', 'VIII', 'XII']
# 34610 ['(R2078)']
# 34533 ['(R2072)']
# 31794 ['(R1870)']
# 34549 ['(R2073)']
# 33463 ['(R1993)']
# 33706 ['(R2008)']
# 34640 ['(R2081)']
# 34725 ['J', 'A', 'IV', 'IIA', 'B', 'IIB', 'III', 'C', 'I', 'XVIII', 'VIII', 'XVII', 'XVI', 'XIII', 'VI', 'XII', 'X', 'VII', None, 'XV', 'IX', 'V']
# 34713 ['(R2089)']
# 33795 ['(R2020)']
# 34515 ['(R2070)']
# 33445 ['(R1991)']
# 34660 ['(R2085)']
# 32866 ['(R1958)']
# 34519 ['(R2071)']
# 34712 ['(R2088)']
# 34550 ['C', 'IIA', 'IIB', 'XV', 'I', 'XII', 'B', 'IV', 'VI', None, 'V', 'J', 'VII', 'XVIII', 'XVII', 'X', 'XIII', 'A', 'IX', 'VIII', 'XVI', 'III']
# 34657 ['(R2082)']
# 34730 ['B', 'C', 'VII', 'J', 'XVIII', 'X', 'I', 'A', 'IV', 'XIII', 'XII', 'IIB', 'IIA', 'IX', 'XVII', 'VIII', 'VI', 'V', 'XVI', 'XV', None, 'III']
# 33668 ['(R2013)']
# 32879 ['(R1960)']
# 34659 ['(R2084)']
# 34158 ['(R2048)']
# 34845 ['J', 'VII', 'XIII', 'X', 'B', 'VI', 'C', 'XII', 'I', 'IIB', 'IIA', 'A', 'XVI', 'XVII', 'IX', 'IV', 'XVIII', None, 'XV', 'V', 'VIII', 'III']
# 34840 ['(R2095)']
# 34898 ['(R2101)']
# 34811 ['(R2092)']
# 34473 ['(R2069)']
# 34775 ['C', 'IIA', 'B', 'XV', 'IIB', 'XVIII', 'J', 'XVII', 'I', 'XII', 'A', 'VII', 'IX', 'V', 'IV', 'VI', 'X', None, 'XVI', 'XIII', 'III', 'VIII']
# 34922 ['(R2103)']
# 34823 ['(R2093)']
# 34876 ['(R2100)']
# 34875 ['(R2099)']
# 34960 ['XII', 'I', 'A', 'XVII', 'IIA', 'X', 'J', 'C', 'IIB', 'XVI', 'VII', 'IV', 'IX', 'B', None, 'XV', 'VI', 'VIII', 'V', 'XIII', 'III']
# 31539 ['(R1865)']
# 34950 ['J', 'A', 'IV', 'IX', 'B', 'I', 'C', 'IIA', 'III', 'IIB', 'VII', 'XVIII', None, 'XIII', 'VI', 'X', 'V', 'XVII', 'XVI', 'XV', 'XII', 'VIII']
# 35051 ['(R2109)']
# 34557 ['(R2074)']
# 35023 ['(R2107)']
# 35000 ['IIB', 'C', 'I', 'XIII', 'V', 'IX', 'X', 'XVII', 'IV', 'IIA', 'A', 'XIV', 'B', 'XVI', 'XV', 'J', 'VI', 'XII', 'III', None, 'VII', 'VIII']
# 34949 ['(R2105)']
# 35081 ['(R2111)']
# 35095 ['VI', 'X', 'I', 'IV', 'V', None, 'B', 'C', 'IIA', 'J', 'IX', 'VIII', 'XII', 'XVII', 'VII', 'XVI', 'A', 'IIB', 'XV', 'III', 'XIII']
# 34839 ['(R2094)']
# 35085 ['(R2113)']
# 35210 [None, 'IX', 'XV', 'B', 'A', 'C', 'I', 'J', 'IIA', 'IIB', 'VII', 'XII', 'XIV', 'XVII', 'VIII', 'IV', 'V', 'X', 'XIII', 'XVI', 'VI', 'III']
# 35200 ['A', 'J', 'VIII', 'X', 'XVII', 'VI', 'IX', 'XV', None, 'V', 'IV', 'XIII', 'XVI', 'XII', 'III', 'B', 'C', 'I', 'IIA', 'IIB', 'VII']
# 34865 ['(R2097)']
# 34927 ['(R2104)']
# 35215 ['(R2128)']
# None [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 33873 ['(R2026)']
# 34038 ['(R2039)']
# 34016 ['(R2036)']
# 32415 ['(R1915)']
# 34992 ['(R2106)']
# 32017 ['(R1884)']
# 31487 ['(R1862)']
# 35128 ['(R2118)']
# 34658 ['(R2083)']
# 34358 ['(R2065)']
# 32026 ['(R1888)']
# 33174 ['(R1974)']
# 21501 ['27', '03', '04', '28', '30', '07', '34', '31', '33', '32', '02', '20', '08']
# 34853 ['(R2096)']
# 34620 [None, 'A', 'B', 'XVIII', 'XVII', 'XV', 'XVI', 'XII', 'XIII', 'X', 'VII', 'VI', 'VIII', 'IX', 'IV', 'J', 'V', 'IIB', 'IIA', 'C', 'III']
# 34899 ['(R2102)']
# 32187 ['(R1902)']
# 33865 ['(R2024)']
# 31813 ['(R1873)']
# 35082 ['(R2112)']
# 35071 ['(R2110)']
# 33446 ['(R1992)']
# 33486 ['(R1994)']
# 35127 ['(R2117)']
# 31504 ['(R1864)']
# 31324 ['(R1844)']
# 34356 ['(R2064)']
# 33852 ['(R2023)']
# 33201 ['(R1977)']
# 35172 ['(R2123)']
# 35171 ['(R2122)']
# 34235 ['(R2053)']
# 35308 ['(R2132)']
# 35187 ['(R2124)']
# 35258 ['(R2130)']
# 35312 ['(R2134)']
# 35313 ['(R2135)']
# 35314 ['(R2136)']
# 35315 ['(R2137)']
# 35350 ['I', 'B', 'IIB', 'IIA', 'IV', 'VII', 'IX', 'VIII', 'X', 'XVI', 'C', 'A', 'J', 'XII', 'XIV', None, 'V', 'XVII', 'XIII', 'XV', 'VI', 'III']
# 35231 ['(R2129)']
# 35329 ['(R2139)']
# 35300 ['J', 'IX', 'IIB', 'A', 'IIA', 'I', 'C', 'XII', 'B', 'XVI', 'X', 'XV', 'V', 'VII', 'XIII', 'XVII', 'III', 'IV', 'VI', 'XIV', None, 'VIII']
# 35206 ['(R2127)']
# 35346 ['(R2141)']
# 35425 ['(R2145)']
# 35432 ['(R2146)']
# 35047 ['(R2108)']
# 35449 ['(R2147)']
# 35450 ['C', 'XV', 'XVII', 'XVI', 'IX', 'IV', 'V', 'I', 'VI', 'A', 'XII', 'J', 'XIII', 'XIV', 'B', 'IIA', 'VII', 'X', None, 'IIB', 'III', 'VIII']
# 35323 ['(R2138)']
# 35381 ['(R2143)']
# 35391 ['(R2144)']
# 35570 ['K', 'C', 'J', 'A', 'XV', 'IX', 'IIA', 'IIB', 'I', 'XVII', 'X', 'XIII', 'III', 'IV', 'XVI', 'B', 'VII', 'VI', 'XII', 'XIV', 'XIX', None, 'VIII', 'V']
# 35369 ['(R2142)']
# 35650 ['J', 'B', 'C', 'IIA', 'III', 'IIB', 'A', 'I', 'V', 'XVII', 'IX', 'VII', 'XII', 'XIV', 'XVI', 'X', 'IV', 'VIII', None, 'XV', 'VI', 'XIII']
# 35470 ['XII', 'A', 'IX', 'J', 'XIII', 'XIV', None, 'VII', 'III', 'IIA', 'IIB', 'C', 'B', 'V', 'IV', 'XV', 'VI', 'X', 'XVI', 'I', 'XVII', 'VIII']
# 35202 ['(R2126)']
# 35847 ['(R2156)']
# 35163 ['(R2121)']
# 35850 ['B', 'A', 'IIB', 'IIA', 'IV', 'V', 'VI', 'X', 'XII', 'XVII', 'C', 'J', 'XIV', 'IX', 'XV', 'XVI', 'XIII', 'XIX', None, 'I', 'VII', 'III', 'K', 'VIII']
# 35834 ['(R2153)']
# 35835 ['(R2154)']
# 35830 ['IX', 'XIV', 'VIII', 'XII', 'A', 'J', 'IV', 'XV', 'XVII', 'XVI', 'III', 'IIB', 'IIA', 'I', 'C', 'B', 'X', 'VII', 'VI', None, 'XIII', 'V']
# 35925 ['IIB', 'C', 'IIA', 'J', 'A', 'XV', 'XVII', 'VI', 'XII', 'III', 'VII', 'I', 'XIV', 'XVI', 'K', 'X', 'IV', 'XIX', 'XIII', None, 'VIII', 'B', 'V', 'IX']
# 22594 ['(R1434)']
# 35975 ['I', 'IIA', 'IIB', 'V', 'IX', 'XIX', 'B', 'C', 'J', 'XIV', 'A', 'XII', 'XV', 'IV', 'XVII', 'XVI', 'VI', None, 'VII', 'III', 'X', 'K', 'XIII', 'VIII']
# 36054 ['(R2165)']
# 36066 ['(R2167)']
# 36060 ['(R2166)']
# 35846 ['(R2155)']
# 36120 ['B', 'C', 'K', 'I', 'IIA', 'IIB', 'V', 'IX', 'IV', 'XII', 'J', 'A', 'VI', 'XIV', 'VIII', 'III', 'XVI', 'XVII', 'XV', 'VII', 'X', 'XIII', 'XIX', None]
# 36116 ['(R2169)']
# 36117 ['(R2170)']
# 36141 ['(R2172)']
# 36017 ['(R2159)']
# 34589 ['(R2077)']
# 36100 ['XV', 'A', 'J', 'XII', 'XIV', 'VIII', 'IV', None, 'XVI', 'V', 'VI', 'XIX', 'XVII', 'B', 'C', 'I', 'IIA', 'IIB', 'III', 'VII', 'K', 'X', 'XIII', 'IX']
# 30300 ['VIII']
# 36224 ['(R2173)']
# 36200 ['C', 'K', 'IX', 'IIB', 'IIA', 'I', 'B', 'XII', 'J', 'A', 'XV', 'XVI', 'X', 'XIV', 'III', 'L', 'XIII', 'IV', 'VIII', None, 'XVII', 'VI', 'V', 'VII']
# 36250 ['A', 'IIB', 'C', 'IIA', 'B', 'J', 'XIII', 'K', 'X', 'VI', 'XVI', 'V', 'XIV', 'XVII', 'IV', None, 'XII', 'IX', 'XV', 'VII', 'I', 'III', 'XIX', 'VIII']
# 36255 ['(R2176)']
# 36297 ['(R2177)']
# 36298 ['(R2178)']
# 36303 ['(R2179)']
# 31384 ['(R1850)']
# 35649 ['(R2150)']
# 35584 ['(R2149)']
# 35688 ['(R2151)']
# 36319 ['(R2180)']
# 36347 ['(R2183)']
# 36112 ['(R2168)']
# 36031 ['(R2161)']
# 36118 ['(R2171)']
# 36360 ['IIB', 'IX', 'I', 'IIA', 'III', 'IV', 'V', 'VI', 'VII', 'XII', 'X', 'XIII', 'XV', 'XVII', 'XIX', 'A', 'B', 'C', 'J', 'K', 'XVI', 'VIII', None, 'XIV']
# 36233 ['(R2175)']
# 36232 ['(R2174)']
# 35099 ['(R2114)']
# 36350 ['IX', 'XVI', 'XV', 'VI', None, 'IIB', 'III', 'IV', 'V', 'VIII', 'X', 'XII', 'XIV', 'A', 'B', 'C', 'J', 'K', 'L', 'XIII', 'VII', 'I', 'IIA', 'XVII']
# 30166 ['(R1795)']
# 31355 ['(R1848)']
# 32172 ['(R1897)']
# 32183 ['(R1900)']
# 31838 ['(R1874)']
# 32516 ['(R1920)']
# 32517 ['(R1921)']
# 32518 ['(R1922)']
# 32256 ['(R1906)']
# 32714 ['(R1949)']
# 32738 ['(R1953)']
# 32671 ['(R1935)']
# 33051 ['(R1970)']
# 32901 ['(R1967)']
# 32865 ['(R1957)']
# 32560 ['(R1924)']
# 32019 ['(R1886)']
# 32309 ['(R1907)']
# 32018 ['(R1885)']
# 27570 ['(R1672)']
# 32213 ['(R1903)']
# 30874 ['(R1818)']
# 32186 ['(R1901)']
# 32748 ['(R1954)']
# 32649 ['(R1931)']
# 32908 ['(R1968)']
# 32909 ['(R1969)']
# 32868 ['(R1959)']
# 33710 ['(R2017)']
# 33760 ['(R2010)']
# 34029 ['(R2037)']
# 33955 ['(R2032)']
# 34037 ['(R2038)']
# 34056 ['(R2042)']
# 34173 ['(R2049)']
# 34141 ['(R2047)']
# 33440 ['(R1990)']
# 35859 ['(R2157)']
# 36043 ['(R2164)']
# 33487 ['(R1995)']
# 33228 ['(R1981)']
# 34561 ['(R2075)']
# 34612 ['(R2079)']
# 33359 ['(R1986)']
# 34417 ['(R2068)']
# 34134 ['(R2046)']
# 34742 ['(R2091)']
# 35119 ['(R2116)']
# 34667 ['(R2086)']
# 33183 ['(R1975)']
# 34371 ['(R2066)']
# 35143 ['(R2120)']
# 35260 ['(R2131)']
# 35290 ['(R2133)']
# 35552 ['(R2148)']
# 35809 ['(R2152)']
# 33782 ['(R2016)']
# 33701 ['(R2012)']
# 33906 ['(R2030)']
# 33700 ['(R2014)']
# 34263 ['(R2055)']
# 34185 ['(R2050)']
# 34380 ['(R2067)']
# 34009 ['(R2035)']
# 34280 ['(R2058)']
# 34709 ['(R2087)']
# 34873 ['(R2098)']
# 34733 ['(R2090)']
# 34237 ['(R2054)']
# 35199 ['(R2125)']
# 35343 ['(R2140)']
# 36353 ['(R2185)']
# 36039 ['(R2163)']
# 36374 ['(R2187)']
# 35106 ['(R2115)']
# 35934 ['(R2158)']
# 36363 ['(R2186)']
# 33134 ['(R1972)']
# 36351 ['(R2184)']
# 36435 ['XV', 'XIII', 'I', 'IIB', 'IIA', 'V', 'IX', 'XIV', 'X', 'XVI', 'A', 'B', 'K', 'J', 'C', 'L', 'VIII', 'VII', 'VI', 'XVII', 'XII', 'IV']
# 34332 ['(R2062)']
# 24493 ['R1557']
# 36470 [None, 'I', 'IIA', 'IIB', 'IV', 'VI', 'V', 'VIII', 'IX', 'X', 'XVI', 'XVII', 'XII', 'B', 'A', 'XIII', 'XV', 'XIV', 'C', 'J', 'K', 'L', 'VII', 'III']
# 36410 ['B', 'I', 'K', 'L', 'IIA', 'IIB', 'III', 'XVI', 'V', 'XIII', None, 'C', 'J', 'IV', 'VI', 'XVII', 'IX', 'XII', 'VIII', 'X', 'XV', 'A', 'XIV', 'VII']
# 36455 ['(R2188)']
# 35130 ['(R2119)']
# 36497 ['(R2189)']
# 36032 ['(R2162)']
# 34632 ['(R2080)']
# 36509 ['(R2190)']
# 36323 ['(R2182)']
# 36027 ['(R2160)']
# 36321 ['(R2181)']
# 23908 ['(R1519)']

# %% [markdown]
# ## OData interface
#
# The SyncFeed API is perfectly functional, though it leaves you to do interpretation of the relations yourself,
# so let's see if the OData API is any more help.
#
# There is a helpful library out there, [tkapi](https://github.com/openkamer/tkapi), which means much less work for us.

# %%
# if you haven't already:
# !pip3 install tkapi

# %%
import tkapi, tkapi.document   
from tkapi.document import DocumentSoort
api = tkapi.TKApi()

# %%
# Get an idea of what this API even does
#   the document types are function calls, to wit:
list(name   for name in dir(api)   if name.startswith('get_'))
# Out:
# ['get_activiteiten',
#  'get_agendapunten',
#  'get_all_items',
#  'get_antwoorden',
#  'get_besluiten',
#  'get_commissies',
#  'get_documenten',
#  'get_dossiers',
#  'get_fractie_zetels',
#  'get_fracties',
#  'get_geschenken',
#  'get_item',
#  'get_items',
#  'get_kamervragen',
#  'get_personen',
#  'get_reizen',
#  'get_related',
#  'get_stemmingen',
#  'get_vergaderingen',
#  'get_verslagen',
#  'get_verslagen_van_algemeen_overleg',
#  'get_zaken']

# %%
all_dossiers = api.get_dossiers( ) # a few thousand of them, fetching takes a handful of seconds
len(all_dossiers)

#If you only wanted a specific dossier, use something like:
#from tkapi.dossier import Dossier
#dossier_filter = Dossier.create_filter()
#dossier_filter.filter_nummer('35302')
#dossiers = api.get_dossiers( dossier_filter )
# Out:
# 6934

# %%
# tkapi knows about properties, and relationships to other objects, 
# and allows you to fetch them via attributes and functions it puts on each object  (for the programmers: it's much like an ORM)
# the following (while not a clean list) but helps illistrate that point, in particular see documenten, zaken (which are its relations mentioned in the diagram from ealier)
list( name  for name in dir(all_dossiers[0])  if not name.startswith('_'))
# Out:
# ['afgesloten',
#  'begin_date_key',
#  'create_filter',
#  'documenten',
#  'end_date_key',
#  'expand_params',
#  'filter_param',
#  'get_date_from_datetime_or_none',
#  'get_date_or_none',
#  'get_datetime_or_none',
#  'get_param_expand',
#  'get_params_default',
#  'get_property_enum_or_none',
#  'get_property_or_empty_string',
#  'get_property_or_none',
#  'get_resource_url_or_none',
#  'get_year_or_none',
#  'gewijzigd_op',
#  'id',
#  'nummer',
#  'orderby_param',
#  'organisatie',
#  'print_json',
#  'related_item',
#  'related_items',
#  'related_items_deep',
#  'titel',
#  'toevoeging',
#  'type',
#  'url',
#  'zaken']

# %%
# Let's get a basic summary of dossiers.
#    we find out apparently  dossier nummers  are not unique without the  toevoeging

# fetch all, sort by dossier number (and toevoeging, which requires minor syntax-fu right now)
#all_dossiers = api.get_dossiers() # we just did this above
some_dossiers = random.sample( all_dossiers, 50)
sorted_dossiers = sorted(  some_dossiers,   key=lambda dossier:str(dossier.nummer)+(dossier.toevoeging or '')  )

i = 0
for dossier in sorted_dossiers:
    print('\n\n')

    # you could e.g. figure out other zaken that refer to the same documents
    #zaaknrs = set()
    #for zaak in dossier.zaken:
    #    zaaknrs.add( zaak.nummer ) # zaak.onderwerp)

    nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')
    print( f"== Dossier {nummer_and_toevoeging} == {dossier.titel} ==" )
    #print( '  ',dossier.url.replace(')','%29') ) # the replace is to make the notebook's url include the final bracket

    # It seems that many documenten have a related zaal, but it's not one-to-one;  TODO: 
    for zaak in dossier.zaken:
        print(f'   ZAAK      {zaak.nummer}  {str(zaak.soort).split(".",1)[1]:18s} {zaak.onderwerp}')
        #print('         ',zaak.url)
    
    for document in sorted(dossier.documenten, key=lambda doc:doc.volgnummer):
        print( f'   DOC #{str(document.volgnummer):3s}  {str(document.nummer):10s} - {str(document.datum):12s} - {document.onderwerp:100s} - {document.bestand_url:30s}')
        
        #for zaak in document.zaken:
        #    print(f'     DOCZAAK      {zaak.nummer}  {str(zaak.soort).split(".",1)[1]:18s} {zaak.onderwerp}')

# short examples include 
#  34865-(R2097)
#  33805-VIII
#  35169
# Out:
# == Dossier 26488 == Programma doorontwikkeling F-35 ==
#    ZAAK      2009Z02151  BRIEF_REGERING     Geluidsgegevens kandidaat-toestellen Vervanging F-16
#    ZAAK      2016Z23302  BRIEF_REGERING     Informatie over de financiële gegevens Block Buy
#    ZAAK      2014Z07871  BRIEF_REGERING     Reactie op berichten in de media over het naar Nederland halen van een F-35 testtoestel
#    ZAAK      2008Z09934  BRIEF_REGERING     Toezending rapporten actualisering kandidatenvergelijking project vervanging F-16
#    ZAAK      2014Z08304  BRIEF_REGERING     Informatievoorziening project Vervanging F-16
#    ZAAK      2011Z11048  BRIEF_REGERING     Lijst van vragen en antwoorden over de rapportage van het project Vervanging F-16 over het jaar 2010
#    ZAAK      2010Z08586  BRIEF_REGERING     M6.5-softwaremodificatie voor de F-16
#    ZAAK      2009Z04569  BRIEF_REGERING     Regeerakkoord en herijking businesscase
#    ZAAK      2008Z03307  BRIEF_REGERING     Rafale en Eurofighter
#    ZAAK      2020Z01791  BRIEF_REGERING     Financiële gevolgen van de schorsing van Turkije uit het F-35 programma en van de deelname aan de block buy
#    ZAAK      2009Z07211  BRIEF_REGERING     Addendum en jaarrapportage ‘Vervanging F-16’ over het jaar 2008
#    ZAAK      2009Z06079  BRIEF_REGERING     Beantwoording vragen inzake de reactie op verzoek van de Kamer om toezending van de bij Defensie beschikbare geluidsgegevens van de kandidaat-toestellen voor vervanging F-16
#    ZAAK      2019Z09601  BRIEF_REGERING     Financiële verantwoording 2018 Project Verwerving F-35
#    ZAAK      2008Z05598  MOTIE              Motie Voordewind/Eijsink over uitstel van het besluit tot aankoop van de testvliegtuigen
#    ZAAK      2017Z12326  BRIEF_REGERING     Achttiende voortgangsrapportage van het project Verwerving F-35
#    ZAAK      2009Z03940  MOTIE              Motie Van Velzen c.s. over advies van de Raad van State inzake vertrouwelijke informatie van de regering
#    ZAAK      2013Z06143  BRIEF_REGERING     Reactie op het Amerikaanse GAO-rapport over het F-35 programma
#    ZAAK      2014Z23314  BRIEF_REGERING     Werkgelegenheidsaspecten F-35 programma
#    ZAAK      2014Z22322  BRIEF_REGERING     Informatie over toezending van een rapport van de Audit Dienst Rijk met de D-brief over de Vervanging van de F-16
#    ZAAK      2009Z07057  BRIEF_REGERING     Uitvoering van de motie-Van Velzen c.s. inzake voorlichting van de Raad van State over vertrouwelijke informatie (26488, nr.148)
#    ZAAK      2008Z05596  MOTIE              Motie Pechtold over extra tijd voor kandidaat-producenten voor een simulatie
#    ZAAK      2008Z00712  BRIEF_REGERING     Studie van PricewaterhouseCoopers naar de spin-off, spill over en werkgelegenheidseffecten van een Nederlandse deelname aan het JSF-programma
#    ZAAK      2021Z10929  BRIEF_REGERING     Nieuwe versie van het Memorandum of Understanding (MoU) voor de productie-, instandhoudings- en doorontwikkelingsfase voor de F-35, die het bestaande MoU uit 2006 vervangt
#    ZAAK      2014Z14008  BRIEF_REGERING     F-35 Selected Acquisition Report 2013
#    ZAAK      2016Z12384  BRIEF_REGERING     Meerjarige bevestiging F-35 toestellen
#    ZAAK      2020Z09084  BRIEF_REGERING     Financiële verantwoording 2019 project Verwerving F-35
#    ZAAK      2014Z18064  RAPPORT_ALGEMENE_REKENKAMER Monitoring Vervanging F-16
#    ZAAK      2009Z23301  BRIEF_REGERING     JSF Afdrachtpercentage
#    ZAAK      2017Z02179  BRIEF_REGERING     Jaarverslag Amerikaanse DOT&E over het F-35 programma
#    ZAAK      2020Z18962  BRIEF_REGERING     Beantwoording vragen commissie over de eenentwintigste voortgangsrapportage project Verwerving F-35 (Kamerstuk 26488-461)
#    ZAAK      2013Z20436  BRIEF_REGERING     Antwoorden op vragen van de commissie over  het gebruik van de Nederlandse testtoestellen
#    ZAAK      2012Z13611  BRIEF_REGERING     Lijst van vragen en antwoorden inzake de tiende jaarrapportage van het project Vervanging F-16 over 2011
#    ZAAK      2008Z05807  BRIEF_REGERING     Aanschaf JSF testtoestel
#    ZAAK      2011Z07841  BRIEF_REGERING     Lijst van vragen en antwoorden inzake de optietermijn voor de aanschaf van het tweede F-35 testtoestel
#    ZAAK      2012Z05037  MOTIE              Motie Jasper van Dijk over een onderzoek door het parlement
#    ZAAK      2009Z19179  BRIEF_REGERING     Lijst van vragen en antwoorden over de Geluidscontouren F-35
#    ZAAK      2009Z11191  BRIEF_REGERING     Reactie op verzoek Pechtold over werkgelegenheidseffecten JSF-programma
#    ZAAK      2009Z25315  BRIEF_REGERING     Amerikaanse besluitvorming over de tweede motor voor de F-35
#    ZAAK      2016Z05278  BRIEF_REGERING     Voortgangsrapportage over het project Verwerving F-35
#    ZAAK      2015Z02738  BRIEF_REGERING     Antwoorden op vragen commissie over D-brief Vervanging F-16
#    ZAAK      2010Z06050  BRIEF_REGERING     Reactie op het verzoek van de commissie Defensie om aanvullende informatie afronding arbitrage JSF
#    ZAAK      2013Z06336  RAPPORT_ALGEMENE_REKENKAMER Errata in het rapport Uitstapkosten Joint Strike Fighter van 25 oktober 2012
#    ZAAK      2008Z09927  BRIEF_REGERING     Resultaten actualisering kandidatenvergelijking project Vervanging F-16
#    ZAAK      2013Z08007  BRIEF_REGERING     Antwoord vragen commissie over de nadere informatie over de Nederlandse testtoestellen t.b.v. de operationele testfase (Algemeen Overleg vervanging F-16)
#    ZAAK      2009Z07197  MOTIE              Motie Brinkman over de aanschaf van JSF-testtoestellen
#    ZAAK      2015Z05644  BRIEF_REGERING     Voortgangsrapportage project Vervanging F-16
#    ZAAK      2014Z23235  BRIEF_REGERING     Versie DMP-D document Vervanging F-16
#    ZAAK      2009Z01984  BRIEF_REGERING     Uitst beantw vrg Cie inzak het besluit tot aanschaf F-35 toestellen
#    ZAAK      2010Z05340  BRIEF_REGERING     Lijst van vragen en antwoorden over de JSF Afdrachtpercentage
#    ZAAK      2013Z18621  BRIEF_REGERING     Risicoreservering project Vervanging F-16
#    ZAAK      2008Z04594  BRIEF_REGERING     Herberekening van de JSF Businesscase
#    ZAAK      2009Z02984  BRIEF_REGERING     Reactie op verzoek cie's over het project Vervanging F-16
#    ZAAK      2010Z05172  BRIEF_REGERING     Aanvullende informatie herstructurering F-35-programma
#    ZAAK      2020Z16385  BRIEF_REGERING     Eenentwintigste voortgangsrapportage project Verwerving F-35
#    ZAAK      2013Z09930  RAPPORT_ALGEMENE_REKENKAMER Aanbieding Informatiepositie Tweede Kamer Vervanging F-16 (reconstructie)
#    ZAAK      2013Z03128  RAPPORT_ALGEMENE_REKENKAMER Antwoorden op vragen van de commissie over het rapport Uitstapkosten Joint Strike Fighter
#    ZAAK      2010Z20072  BRIEF_REGERING     Validatie F-35 geluidsbelasting
#    ZAAK      2012Z05033  MOTIE              Motie El Fassed/Jasper van Dijk over het niet aanschaffen van extra JSF-toestellen
#    ZAAK      2017Z02170  BRIEF_REGERING     Antwoorden op vragen van de commissie over het NLR-rapport “Geluidsbeleving F-35 ten opzichte van F-16”
#    ZAAK      2008Z09861  BRIEF_REGERING     Vervanging F-16: briefing kandidatenvergelijking
#    ZAAK      2011Z08927  BRIEF_REGERING     Uitstapkosten testfase en F136 motor
#    ZAAK      2014Z15434  BRIEF_REGERING     MoU operationele testfase F-35
#    ZAAK      2009Z19615  BRIEF_REGERING     Reactie op rapport van het CBO over de toekomstige samenstelling van de Amerikaanse luchtstrijdkrachten en over het rapport van het CSBA over het begrotingsvoorstel van het Amerikaanse ministerie van Defensie voor begrotingsjaar 2010.
#    ZAAK      2020Z03275  MOTIE              Motie van het lid Bosman c.s. over snel duidelijkheid over het gebruik van laagvliegroute 10a
#    ZAAK      2015Z02739  BRIEF_REGERING     Onderbouwing raming van de Nederlandse F-35 productieomzet van circa 9 miljard dollar
#    ZAAK      2015Z19228  MOTIE              Motie van het lid Hachchi over het probleem van wisselingen in de dollarkoers
#    ZAAK      2015Z04494  MOTIE              Motie van het lid Knops over toekomstige verkoopopbrengsten van F-16's
#    ZAAK      2009Z14911  OVERIG             Verslag van een werkbezoek aan Zweden
#    ZAAK      2010Z00213  BRIEF_REGERING     Informatie over de geluidsbelasting van de JSF
#    ZAAK      2013Z02652  BRIEF_REGERING     F-35 programma en Nederlandse testtoestellen
#    ZAAK      2012Z22419  RAPPORT_ALGEMENE_REKENKAMER Aanvaarding verzoekonderzoek Visie op de krijgsmacht en vervanging F-16
#    ZAAK      2017Z17079  BRIEF_REGERING     Reactie op het Amerikaanse GAO-rapport van 26 oktober 2017 met betrekking tot F-35 Aircraft Sustainment
#    ZAAK      2020Z03280  MOTIE              Motie van de leden Kerstens en Karabulut over afzien van heringebruikname van een laagvliegroute
#    ZAAK      2011Z11046  BRIEF_REGERING     Informatie over het kopie van het getekend contract en afschrift brief tweede F-35 testtoestel
#    ZAAK      2013Z23761  BRIEF_REGERING     Informatie over de Bijzondere Vertegenwoordiger Industriële Inschakeling F-35
#    ZAAK      2010Z18400  BRIEF_REGERING     Geactualiseerde kostenraming project Vervanging F-16
#    ZAAK      2013Z03741  BRIEF_REGERING     Vertrouwelijke informatie inzake door SEO voor haar F-35 rapport benaderde bedrijven, instellingen en personen
#    ZAAK      2014Z23160  BRIEF_REGERING     D-brief Vervanging F-16
#    ZAAK      2011Z00641  BRIEF_REGERING     Antwoorden op vragen van de commissie inzake degeactualiseerde kostenraming van het project Vervanging F-16
#    ZAAK      2016Z15337  BRIEF_REGERING     Informatie meerjarige bestelling F-35 (Block Buy)
#    ZAAK      2010Z03014  BRIEF_REGERING     Reactie op presentatie ‘Joint Programs TOC Affordability, Cost Department, Naval Air Systems’
#    ZAAK      2023Z08626  BRIEF_REGERING     Financiële verantwoording 2022 project Verwerving F-35
#    ZAAK      2011Z00137  BRIEF_REGERING     Reactie op verzoek commissie om een actualisering van het project Vervanging F-16
#    ZAAK      2015Z02382  RAPPORT_ALGEMENE_REKENKAMER Reactie Algemene Rekenkamer op de DMP-D-brief Vervanging F-16 (Kamerstuk 26 488, nr. 369)
#    ZAAK      2017Z16950  BRIEF_REGERING     Beantwoording vragen commissie over de achttiende voortgangsrapportage van het project Verwerving F-35
#    ZAAK      2016Z14476  MOTIE              Motie van het lid Belhaj over kinderen die rondom vliegbasis Leeuwarden en vliegbasis Volkel wonen jaarlijks onderzoeken op gehoorschade
#    ZAAK      2008Z01613  BRIEF_REGERING     Uitstel beantwoordingstermijn Saab en Lockheed Martin
#    ZAAK      2014Z10472  BRIEF_REGERING     Antwoorden op vragen van de commissie over het jaarlijkse voortgangsrapport van het Amerikaanse Government Accountability Office (GAO) over het F-35 programma
#    ZAAK      2011Z08332  BRIEF_REGERING     Lijst van vragen en antwoorden over de aanschaf van het tweede F-35 testtoestel
#    ZAAK      2008Z08502  BRIEF_REGERING     JSF Businesscase
#    ZAAK      2011Z08977  MOTIE              Motie-Jasper van Dijk c.s. over afzien van deelname aan de training
#    ZAAK      2009Z08023  MOTIE              Motie-Halsema c.s. over het niet aangaan van verplichtingen zonder dat in een nieuw contract een terugneemgarantie is opgenomen
#    ZAAK      2009Z06031  BRIEF_REGERING     Antwoorden op schriftelijke vragen over de vervanging van de F-16
#    ZAAK      2009Z07226  OVERIG             Verslag van een hoorzitting over de vervanging van de F-16
#    ZAAK      2008Z05593  MOTIE              Motie Van Velzen over het niet nemen van het besluit tot aanschaf van JSF-toestellen in februari 2009
#    ZAAK      2009Z04502  BRIEF_REGERING     Reactie op Motie Van Velzen c.s. inzake inlichtingen Raad van State m.b.t. vertrouwelijkheid inf. vervanging F-16
#    ZAAK      2009Z16675  OVERIG             Commercieel vertrouwelijke brief inzake de verkoop van F-16's aan Chili
#    ZAAK      2012Z06658  BRIEF_REGERING     Amerikaanse informatie over het F-35 programma
#    ZAAK      2010Z10185  BRIEF_REGERING     Commissieverzoek inzake contacten met de VS over het JSF-project
#    ZAAK      2010Z03567  BRIEF_REGERING     Lijst van vragen en antwoorden inzake de Amerikaanse besluitvorming over de tweede motor voor de F-35
#    ZAAK      2009Z22921  BRIEF_REGERING     Einde Arbitrage JSF Businesscase
#    ZAAK      2019Z19058  BRIEF_REGERING     Bestelling negen additionele F-35 jachtvliegtuigen
#    ZAAK      2011Z08976  MOTIE              Motie-Jasper van Dijk c.s. over afzien van de aanschaf
#    ZAAK      2014Z03841  BRIEF_REGERING     Antwoorden op vragen van de commissie over de informatie over de Bijzondere Vertegenwoordiger Industriële Inschakeling F-35
#    ZAAK      2024Z02388  BRIEF_REGERING     Programma doorontwikkeling F-35
#    ZAAK      2010Z08656  MOTIE              Motie Eijsink c.s. over het terugdraaien van investeringen in het eerste JSF-testtoestel
#    ZAAK      2011Z05560  BRIEF_REGERING     Rapportage van het project Vervanging F-16 over het jaar 2010
#    ZAAK      2008Z03969  BRIEF_REGERING     JSF en Israël, Italië en het Verenigd Koninkrijk
#    ZAAK      2017Z15917  BRIEF_REGERING     Bevestiging resterende zes F-35 toestellen in de Block Buy
#    ZAAK      2008Z02646  BRIEF_REGERING     Stand van zaken herberekening JSF Businesscase
#    ZAAK      2008Z03289  BRIEF_REGERING     Reactie verzoek Van Velzen over de kandidatenevaluatie 2002 en het verloop van JSF-orders
#    ZAAK      2014Z11383  BRIEF_REGERING     Reactie op de vraag van de vaste commissie voor Defensie over het F-35 Selected Acquisition Report 2013
#    ZAAK      2009Z17147  BRIEF_REGERING     Uitstelbericht arbitrage JSF Businesscase
#    ZAAK      2019Z07674  BRIEF_REGERING     Kabinetsreactie op het rapport van de Algemene Rekenkamer “Lessen van de JSF; Grip krijgen op grote projecten voor aanschaf defensiematerieel”
#    ZAAK      2008Z07742  BRIEF_REGERING     Diverse aspecten vervanging F-16
#    ZAAK      2015Z24286  BRIEF_REGERING     Provincie Noord-Brabant medefinancier motorenonderhoud te Woensdrecht
#    ZAAK      2015Z04495  MOTIE              Motie van het lid Knops over de door de Algemene Rekenkamer aangesneden problematiek bij een aantal van 37 F-35's
#    ZAAK      2007Z00072  BRIEF_REGERING     Nadere informatie over wijze van uitvoering van vergelijking JSF en alternatieve vliegtuigen (kandidatenvergelijking vervanging F-16)
#    ZAAK      2015Z04490  MOTIE              Motie van het lid Jasper Van Dijk over afzien van de aanschaf van acht JSF-toestellen
#    ZAAK      2016Z14477  MOTIE              Motie van het lid De Roon over niet over gaan tot een meerjarige bestelling van de JSF
#    ZAAK      2009Z12410  BRIEF_REGERING     Beantwoording aanvullende vragen van de commissie voor Defensie over de verkoop van jachtvliegtuigen aan Chili
#    ZAAK      2015Z14328  BRIEF_REGERING     Aanpassing afdrachtpercentage F-35 omzet van het Nederlandse bedrijfsleven aan de Staat
#    ZAAK      2007Z00075  BRIEF_REGERING     Toelichting op de herberekening van de businesscase, zoals deze op 1 juli 2008 aan de betrokken partijen is verstuurd
#    ZAAK      2016Z11015  BRIEF_REGERING     Reactie op keuze door de Deense regering voor de F-35
#    ZAAK      2017Z05605  BRIEF_REGERING     RAND-rapport over de Block Buy
#    ZAAK      2018Z18686  BRIEF_REGERING     Aanschaf beoogde resterende drie F-35 toestellen
#    ZAAK      2022Z20846  OVERIG             Mededeling
#    ZAAK      2022Z15822  BRIEF_REGERING     Reactie op verzoek commissie inzake nieuwsartikel F-35 over een mogelijke tekortkoming aan schietstoelen
#    ZAAK      2014Z22468  BRIEF_REGERING     Beantwoording vragen van de commissie voor Defensie over de Jaarrapportage van het project Vervanging F-16 (Kamerstuk 26 488, nr. 358)
#    ZAAK      2008Z09926  BRIEF_REGERING     Endlife update F-16
#    ZAAK      2009Z10947  BRIEF_REGERING     Ondertekening van het contract met Chili inzake verkoop jachtvliegtuigen aan Chili
#    ZAAK      2009Z01024  BRIEF_REGERING     Geluidsgegevens kandidaattoestellen Vervanging F-16
#    ZAAK      2009Z08021  MOTIE              Motie-Hamer c.s. over deelname aan de operationele testfase is geen definitieve keuze voor de JSF
https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6747286f-03eb-442f-834e-eb424a0ab6c8)/TK.DA.GGM.OData.Resource()
#    DOC #90   2007D00073 - 2008-07-01   - Het verschil tussen de kosten tussen deelname aan de ontwikkelingsfase en de JSF en het kopen van de plank van dit toestel - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b18278c0-04a8-4f2a-9cea-8b9536dc3089)/TK.DA.GGM.OData.Resource()
#    DOC #91   2007D00074 - 2008-07-02   - Reactie op vraag van Tweede Kamerlid Van Velzen om onderbouwing van berekende afdrachtpercentage     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fa66a53f-125c-41d7-b224-f8b852d4305c)/TK.DA.GGM.OData.Resource()
#    DOC #92   2007D00075 - 2008-07-03   - Toelichting op de herberekening van de businesscase, zoals deze op 1 juli 2008 aan de betrokken partijen is verstuurd - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d6d05fca-4cff-4047-9a64-043954937a7c)/TK.DA.GGM.OData.Resource()
#    DOC #96   2007D00071 - 2008-07-02   - Aanvullingen op zijn brief van 27 juni 2008 over de kandidatenvergelijking in het kader van de vervanging van de F-16 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1e0c3216-c92d-41ec-ae30-d024a6f7b8a8)/TK.DA.GGM.OData.Resource()
#    DOC #97   2008D00709 - 2008-07-08   - JSF: herberekening business case                                                                     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6eaa0bcc-3d79-4848-b5b3-a2395d2c35bc)/TK.DA.GGM.OData.Resource()
#    DOC #98   2008D00710 - 2008-07-10   - Studie van PricewaterhouseCoopers naar de spin-off, spill over en werkgelegenheidseffecten van een Nederlandse deelname aan het JSF-programma - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(38e596ee-3dd2-4792-b175-c1c2e3cc4e15)/TK.DA.GGM.OData.Resource()
#    DOC #99   2008D00711 - 2008-07-17   - Bezoek aan de fabrikanten van de Rafale en de Eurofighter                                            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(780cb975-7e22-45b3-ae03-365acb8870e0)/TK.DA.GGM.OData.Resource()
#    DOC #101  2008D02077 - 2008-09-02   - Uitstel beantwoordingstermijn Saab en Lockheed Martin                                                - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4bd68e11-c4f1-4332-b2bd-e7c0f9bd1008)/TK.DA.GGM.OData.Resource()
#    DOC #102  2008D04994 - 2008-09-17   - Stand van zaken herberekening JSF Businesscase                                                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e164ccc0-c425-4c69-a14b-34af41d46603)/TK.DA.GGM.OData.Resource()
#    DOC #103  2008D05276 - 2008-09-18   - Algemene Rekenkamer en project Vervanging F-16                                                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3c6c15c9-4086-46a7-a7c2-7675f9f435de)/TK.DA.GGM.OData.Resource()
#    DOC #104  2008D06832 - 2008-09-26   - Rafale en Eurofighter                                                                                - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b0d9e622-1b2a-4cd6-a46b-98c6d4009c7f)/TK.DA.GGM.OData.Resource()
#    DOC #105  2008D06796 - 2008-09-26   - Reactie verzoek Van Velzen over de kandidatenevaluatie 2002 en het verloop van JSF-orders            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(41981df4-6a05-4e12-b248-0cf784cac834)/TK.DA.GGM.OData.Resource()
#    DOC #106  2008D08444 - 2008-10-03   - Verzoek om reactie NRC-artikel                                                                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dabcc606-5740-4b2c-acd0-28b29f400262)/TK.DA.GGM.OData.Resource()
# ...
#    DOC #197  2022D57225 - 2022-12-30   - Reactie op de gewijzigde motie van het lid Omtzigt c.s. over een regeling waarin is vastgelegd wat een passende vergoeding is voor de stroomkosten in 2023 (Kamerstuk 36252-35) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f206aab7-99d3-486d-8921-9051f2beea3a)/TK.DA.GGM.OData.Resource()
#    DOC #198  2023D00623 - 2023-01-13   - Jaarverslag 2021 Beoordelingscommissie late zwangerschapsafbreking en levensbeëindiging bij pasgeborenen - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(63dc93fe-c094-4302-8074-7f6263cf43cd)/TK.DA.GGM.OData.Resource()
#    DOC #199  2023D01536 - 2023-01-19   - Reactie op verzoek commissie over de petitie “Meer onderzoek naar (onverklaarde) gezondheidsklachten van vrouwen” - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5e7d1213-b333-439b-a257-fcc01423b4f3)/TK.DA.GGM.OData.Resource()
#    DOC #200  2023D02466 - 2023-01-25   - Reactie op verzoek commissie over de planning van het ministerie van Volksgezondheid, Welzijn en Sport voor het jaar 2023 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1bfe85ac-4fc3-4c23-a594-d184453774b7)/TK.DA.GGM.OData.Resource()
#    DOC #201  2023D05489 - 2023-02-10   - Beleidsreactie evaluatie van het Centrum voor Ethiek en Gezondheid (2012-2021)                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(195e074b-6321-4566-80b5-77b224a5b77a)/TK.DA.GGM.OData.Resource()
#    DOC #202  2023D03987 - 2023-02-02   - Reactie op verzoek commissie over de gewijzigde motie van het lid Omtzigt c.s. over een regeling waarin is vastgelegd wat een passende vergoeding is voor de stroomkosten in 2023 (Kamerstuk 36252-35) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f22223cc-f81a-4ba6-bf5e-f0efaf14cb9a)/TK.DA.GGM.OData.Resource()
#    DOC #203  2023D08627 - 2023-03-02   - Reactie op de gewijzigde motie van het lid Omtzigt c.s. over een regeling waarin is vastgelegd wat een passende vergoeding is voor de stroomkosten in 2023 (Kamerstuk 36252-35) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5ddf2d73-4532-4de2-a14e-bc71d30a7027)/TK.DA.GGM.OData.Resource()
#    DOC #204  2023D09161 - 2023-03-07   - Integraal uitvoeringsplan Green Deal Duurzame Zorg                                                   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(630072a6-de0b-46ad-9e7b-e0db550e644c)/TK.DA.GGM.OData.Resource()
#    DOC #205  2023D11802 - 2023-03-22   - Motie van het lid Ellemeet c.s. over duurzaamheid meenemen in de toetsing van behandelingen voor het basispakket - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e1bd3e6f-f41d-4642-aff5-152c8397973e)/TK.DA.GGM.OData.Resource()
#    DOC #206  2023D11803 - 2023-03-22   - Motie van de leden Van Esch en Ellemeet over het verder uitbreiden van de pilot met heruitgifte van medicijnen - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f1e940b3-9d0a-4d25-8e14-63119d01b09e)/TK.DA.GGM.OData.Resource()
#    DOC #207  2023D11804 - 2023-03-22   - Motie van de leden Van Esch en Ellemeet over het schrappen van de speciale regels omtrent covidafval - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(01a209ac-11ad-4b52-b282-3e808b84cf16)/TK.DA.GGM.OData.Resource()
#    DOC #208  2023D11805 - 2023-03-22   - Motie van de leden Hijink en Van den Berg over wetgeving om de productie van medische hulpmiddelen te verduurzamen - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1be51cb3-7732-47f1-8832-bd83b234ebf9)/TK.DA.GGM.OData.Resource()
#    DOC #209  2023D11806 - 2023-03-22   - Motie van het lid Paulusma over onderzoek naar de opbrengsten van het tegengaan van verspilling van medische producten - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c9be031e-a6a2-47af-92ec-6584460f09d1)/TK.DA.GGM.OData.Resource()
#    DOC #210  2023D11807 - 2023-03-22   - Motie van het lid Den Haan over het opnemen van medische preventie in de green deal                  - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b840e717-98db-467e-9aee-3dcd2c63876d)/TK.DA.GGM.OData.Resource()
#    DOC #211  2023D11808 - 2023-03-22   - Motie van het lid Agema over de green deal Zorg schrappen voor een salarisverhoging voor zorgmedewerkers - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f7b4182b-5efd-493b-852a-39d4f1dc1145)/TK.DA.GGM.OData.Resource()
#    DOC #212  2023D11809 - 2023-03-22   - Motie van het lid Drost c.s. over ervoor zorgen dat bij de uitwerking van de green deal 3.0 ideeën van zorgpersoneel worden gestimuleerd - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5965f51e-0ef6-45e4-b074-97ac774c5567)/TK.DA.GGM.OData.Resource()
#    DOC #213  2023D10289 - 2023-03-27   - Verslag van een commissiedebat, gehouden op 9 maart 2023, over Verduurzaming van de zorg             - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e2d8fac6-970f-4a30-91e9-e8587e6559e3)/TK.DA.GGM.OData.Resource()
#    DOC #214  2023D13696 - 2023-04-03   - Verslag van een schriftelijk overleg over de reactie op de motie van de leden Paulusma en Bikker over de bekostiging van de tolkenvoorziening (Kamerstuk 35925-XVI-50) en het rapport ‘Tolken in de zorg: een overzicht van huidige inzet, financiering en knelpunten’ - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b43ca54f-8536-4310-b731-937d2dca5973)/TK.DA.GGM.OData.Resource()
#    DOC #215  2023D15170 - 2023-04-11   - Verzamelbrief Caribisch Nederland                                                                    - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(e8be6f8a-0b94-41df-b53d-79f48badcec3)/TK.DA.GGM.OData.Resource()
#    DOC #216  2023D15376 - 2023-04-12   - Voortgang financieel beheer ministerie van VWS                                                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b365d9b3-802a-41bb-b42e-1d6195c00cfd)/TK.DA.GGM.OData.Resource()
#    DOC #217  2023D17023 - 2023-04-19   - Schikkingen inzake vaccinatie Mexicaanse griep                                                       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(593930e3-c37b-49be-8b4a-0e114ee73fa6)/TK.DA.GGM.OData.Resource()
#    DOC #218  2023D16739 - 2023-04-19   - Reactie op verzoek commissie over de uitspraak van de Stichting Klachten en Geschillen Zorgverzekeringen inzake de vergoeding van stroomkosten - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bdda9e1c-7525-4ed4-9929-f9b8235d42dd)/TK.DA.GGM.OData.Resource()
#    DOC #219  2023D19354 - 2023-05-10   - Update energiemaatregelen langdurige zorg                                                            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(74de9186-468e-4675-b8c1-54f2e5abc2ea)/TK.DA.GGM.OData.Resource()
#    DOC #220  2023D20819 - 2023-05-17   - VWS-monitor mei 2023                                                                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d5009f6d-b523-4d9c-8c4c-8188c7be7aa9)/TK.DA.GGM.OData.Resource()
#    DOC #221  2023D20953 - 2023-05-17   - Inzet van Nederland tijdens de World Health Assembly                                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4af6dfb7-6068-45f7-80c5-e2e199983bed)/TK.DA.GGM.OData.Resource()
#    DOC #222  2023D21588 - 2023-05-23   - Reactie op verzoek commissie over het advies Raad van State inzake het ontwerp van een algemene maatregel van bestuur, houdende vaststelling van regels met betrekking tot de veiligheid van attractie- en speeltoestellen - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3ac43b67-a969-4bc7-8616-125a098ee556)/TK.DA.GGM.OData.Resource()
#    DOC #223  2023D23893 - 2023-06-02   - Reactie op verzoek commissie over de agenda’s en notulen van de vergaderingen van de Audit Committee VWS - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a352f23d-673a-4c4b-8d73-1993ce25d297)/TK.DA.GGM.OData.Resource()
#    DOC #224  2023D26169 - 2023-06-15   - Motie van het lid Paulusma c.s. over op korte termijn met een oplossing komen voor de problemen rond de inzet van tolken in de huisartsenzorg - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(613b41f2-a3aa-48ae-b75d-85cccee92986)/TK.DA.GGM.OData.Resource()
#    DOC #225  2023D26171 - 2023-06-15   - Motie van de leden Paulusma en Ceder over voor de langere termijn bezien of en, zo ja, hoe een algehele prestatie binnen de Zorgverzekeringswet voor de inzet van tolken mogelijk is - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7a148d3a-3097-4af4-a6e3-45b6d9261d84)/TK.DA.GGM.OData.Resource()
#    DOC #226  2023D26172 - 2023-06-15   - Motie van de leden Bushoff en Westerveld over met een landelijke oplossing komen voor een toegankelijke tolkenvoorziening in de Jeugdwet - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f11fda0e-abe2-443e-80c3-f4951cbd1e4d)/TK.DA.GGM.OData.Resource()
#    DOC #227  2023D26173 - 2023-06-15   - Motie van het lid Van der Plas over de invloed van het afschaffen van de subsidieregeling op de inzet van tolken in de zorg evalueren - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fb790a77-2aac-4edc-b63b-74e25f5cfa52)/TK.DA.GGM.OData.Resource()
#    DOC #228  2023D26174 - 2023-06-15   - Motie van het lid Ceder c.s. over in de contractering goede afspraken maken over de inzet van tolken in de jeugdzorg - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1612fdc0-6120-4115-832b-6de0b60a1925)/TK.DA.GGM.OData.Resource()
#    DOC #229  2023D26142 - 2023-06-15   - Financieel beheer ministerie van VWS; verbeteraanpak 2023                                            - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(2d64ed33-f912-43e5-8c86-10ea5fc21c86)/TK.DA.GGM.OData.Resource()
#    DOC #230  2023D26762 - 2023-06-20   - Gewijzigde motie van het lid Van der Plas over de resultaten van analyses inzake de inzet van tolken voor zorgverleners en zorgaanbieders afwachten voordat voorstellen naar de Kamer worden gezonden (t.v.v. 36200-XVI-227) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(47eff2f1-19c4-44a8-aae3-da50117c8183)/TK.DA.GGM.OData.Resource()
#    DOC #231  2023D27066 - 2023-06-20   - Appreciatie moties van 15 juni 2023 over ‘Bekostiging tolkenvoorzieningen en het rapport ‘Tolken in de zorg’’, ‘Stand van zaken gebruik Corona Opt-in’, en ‘Ontwikkelingen rondom het coronavirus/pandemische paraatheid’ - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a0d478e3-d5ba-4bb7-bb98-049a0ad70569)/TK.DA.GGM.OData.Resource()
#    DOC #232  2023D27188 - 2023-06-20   - Verslag World Health Assembly van 21 t/m 30 mei 2023                                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d865cf5c-ae69-4311-b3c5-c3e3dd1aa731)/TK.DA.GGM.OData.Resource()
#    DOC #233  2023D28812 - 2023-06-27   - Reactie op de motie van het lid Westerveld over het in kaart brengen van de voor- en nadelen van het RIVM als zelfstandig bestuursorgaan (Kamerstuk 25295-2008) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dfba7678-a208-42b6-9f59-5ba23f5e3301)/TK.DA.GGM.OData.Resource()
#    DOC #234  2023D28889 - 2023-06-29   - Verslag van een schriftelijk overleg over de reactie op verzoek commissie over het advies Raad van State inzake het ontwerp van een algemene maatregel van bestuur, houdende vaststelling van regels met betrekking tot de veiligheid van attractie- en speeltoestellen (Kamerstuk 36200-XVI-222) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c18ec521-8dee-4993-92b2-d8e4303bff16)/TK.DA.GGM.OData.Resource()
#    DOC #235  2023D29659 - 2023-06-30   - Appreciatie gewijzigde motie van het lid Van Houwelingen over ervoor zorgen dat uitgaven behorende bij nieuwe beleidsvoornemens rechtmatig worden vormgegeven (t.v.v. 36360-XVI-14) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bc8cae66-0f88-4dd7-9cb3-521233786d9a)/TK.DA.GGM.OData.Resource()
#    DOC #236  2023D29715 - 2023-06-30   - Stand van zaken moties en toezeggingen zomerreces 2023                                               - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(cc4740fc-6fe8-44b2-99f7-78dc8d1e9565)/TK.DA.GGM.OData.Resource()
#    DOC #237  2023D29778 - 2023-07-03   - Ontwikkelingen Caribisch Nederland                                                                   - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3d967b25-5218-4be4-8545-516cedd4578f)/TK.DA.GGM.OData.Resource()
#    DOC #238  2023D30337 - 2023-07-31   - Verslag van een commissiedebat, gehouden op 28 juni 2023, over Medische ethiek / orgaandonatie       - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(832b480c-1f43-418b-8a9a-be38d67df2a4)/TK.DA.GGM.OData.Resource()
#    DOC #239  2023D44495 - 2023-10-26   - Gewijzigde motie van het lid Van Esch over daadwerkelijk wettelijke eisen stellen voor verduurzaming van de zorg (t.v.v. 36200-XVI-80) - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(89c45eea-ce96-438f-9493-4c64cdcd72d0)/TK.DA.GGM.OData.Resource()
#
#
#
# == Dossier 36293 == Wijziging van de Aanvullingswet bodem Omgevingswet om een omissie in het overgangsrecht te herstellen ==
#    ZAAK      2023Z01276  WETGEVING          Wijziging van de Aanvullingswet bodem Omgevingswet om een omissie in het overgangsrecht te herstellen
#    ZAAK      2023Z05308  NOTA_NAV_HET_VERSLAG Nota naar aanleiding van het verslag
#    DOC #1    2023D02960 - 2023-01-26   - Koninklijke boodschap                                                                                - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a92401b4-cf76-4b6b-94b3-d34679fbca5e)/TK.DA.GGM.OData.Resource()
#    DOC #2    2023D02953 - 2023-01-26   - Voorstel van wet                                                                                     - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c01cfddc-60ec-45a9-863d-a015949d885d)/TK.DA.GGM.OData.Resource()
#    DOC #3    2023D02955 - 2023-01-26   - Memorie van toelichting                                                                              - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(af06345d-528e-4253-86cd-cbefafa79533)/TK.DA.GGM.OData.Resource()
#    DOC #4    2023D02957 - 2023-01-26   - Advies Afdeling advisering Raad van State en Nader rapport                                           - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(32bab2ca-fac4-41f6-9673-cc7eb242c985)/TK.DA.GGM.OData.Resource()
#    DOC #5    2023D07873 - 2023-02-23   - Verslag                                                                                              - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bc6bde20-7d1f-47e5-8014-822d09c9231f)/TK.DA.GGM.OData.Resource()
#    DOC #6    2023D12526 - 2023-03-27   - Nota naar aanleiding van het verslag                                                                 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(95c89244-b9a4-4018-a87b-b46f5adfa3cc)/TK.DA.GGM.OData.Resource()
#
#
#
# == Dossier 36466 == Verdrag betreffende de automatische erkenning van diploma’s in het hoger onderwijs; Brussel, 14 september 2021 ==
#    ZAAK      2023Z19363  VERDRAG            Verdrag betreffende de automatische erkenning van diploma’s in het hoger onderwijs; Brussel, 14 september 2021
#    DOC #1    2023D46852 - 2023-11-15   - Verdrag betreffende de automatische erkenning van diploma’s in het hoger onderwijs; Brussel, 14 september 2021 - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b821d2c6-c0bf-490b-92f0-f1cf9722754a)/TK.DA.GGM.OData.Resource()
#    DOC #2    2023D46855 - 2023-11-23   - Advies Afdeling advisering Raad van Staten en Nader rapport                                          - https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b457aed5-1e5a-4919-9c86-85c8c817f9db)/TK.DA.GGM.OData.Resource()

# %%
# Out of interest, and for a short example, look for larger dossiers.  Many of them will be more thematic.
# (the implied fetches should take 15 mins)
for dossier in sorted( all_dossiers, key=lambda d:d.nummer ): # sort to show the same-nummer-different-toevoeging cases together
    if len(dossier.documenten) > 100:
        toe_s = dossier.toevoeging is not None  and  '-%s'%dossier.toevoeging  or  '   ' # apologies for the syntax-fu
        print( "%5s%-5s  is a large dossier with %4d documents, titled:  %s" %(
                dossier.nummer, toe_s, len(dossier.documenten), dossier.titel))
# Out:
# 17050       is a large dossier with  253 documents, titled:  Misbruik en oneigenlijk gebruik op het gebied van belastingen, sociale zekerheid en subsidies
# 19637       is a large dossier with 2001 documents, titled:  Vreemdelingenbeleid
# 20454       is a large dossier with  112 documents, titled:  Voortgangsrapportage uitvoering wetten oorlogsgetroffenen
# 21501-08    is a large dossier with  655 documents, titled:  Milieuraad
# 21501-20    is a large dossier with 1649 documents, titled:  Europese Raad
# 21501-02    is a large dossier with 2024 documents, titled:  Raad Algemene Zaken en Raad Buitenlandse Zaken
# 21501-32    is a large dossier with 1341 documents, titled:  Landbouw- en Visserijraad
# 21501-33    is a large dossier with  887 documents, titled:  Raad voor Vervoer, Telecommunicatie en Energie
# 21501-34    is a large dossier with  313 documents, titled:  Raad voor Onderwijs, Jeugd, Cultuur en Sport
# 21501-31    is a large dossier with  590 documents, titled:  Raad voor de Werkgelegenheid, Sociaal Beleid, Volksgezondheid en Consumentenzaken
# 21501-07    is a large dossier with 1409 documents, titled:  Raad voor Economische en Financiële Zaken
# 21501-30    is a large dossier with  413 documents, titled:  Raad voor Concurrentievermogen
# 21501-28    is a large dossier with  221 documents, titled:  Defensieraad
# 21501-04    is a large dossier with  170 documents, titled:  Ontwikkelingsraad
# 21501-03    is a large dossier with  134 documents, titled:  Begrotingsraad
# 22026       is a large dossier with  242 documents, titled:  Nederlands deel van een hogesnelheidsspoorverbinding Amsterdam-Brussel-Parijs en Utrecht-Arnhem-Duitse grens
# 22054       is a large dossier with  274 documents, titled:  Wapenexportbeleid
# 22112       is a large dossier with 3265 documents, titled:  Nieuwe Commissievoorstellen en initiatieven van de lidstaten van de Europese Unie
# 22343       is a large dossier with  193 documents, titled:  Handhaving milieuwetgeving
# 22894       is a large dossier with  146 documents, titled:  Preventiebeleid voor de volksgezondheid
documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Justitie en Veiligheid (VI) voor het jaar 2023
# 36200       is a large dossier with  188 documents, titled:  Nota over de toestand van ’s Rijks Financiën
# 36200-VIII  is a large dossier with  265 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Onderwijs, Cultuur en Wetenschap (VIII) voor het jaar 2023
# 36200-IV    is a large dossier with  101 documents, titled:  Vaststelling van de begrotingsstaten van Koninkrijksrelaties (IV) en het BES-fonds (H) voor het jaar 2023
# 36200-XIII  is a large dossier with  133 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Economische Zaken en Klimaat (XIII) voor het jaar 2023
# 36200-XIV   is a large dossier with  127 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2023
# 36200-XVI   is a large dossier with  239 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Volksgezondheid, Welzijn en Sport (XVI) voor het jaar 2023
# 36200-XII   is a large dossier with  118 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Infrastructuur en Waterstaat (XII) voor het jaar 2023
# 36202       is a large dossier with  159 documents, titled:  Wijziging van enkele belastingwetten en enige andere wetten (Belastingplan 2023)
# 36410-VIII  is a large dossier with  118 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Onderwijs, Cultuur en Wetenschap (VIII) voor het jaar 2024
# 36410-XVI   is a large dossier with  138 documents, titled:  Vaststelling van de begrotingsstaten van het Ministerie van Volksgezondheid, Welzijn en Sport (XVI) voor het jaar 2024
# 36418       is a large dossier with  136 documents, titled:  Wijziging van enkele belastingwetten en enige andere wetten (Belastingplan 2024)

# %%
# Out of a different interest, let's get a count of the document types
#   (the implied fetching will take order of fifteen minutes)
soorten = collections.defaultdict(list)

for dossier in sorted( all_dossiers, key=lambda d:d.nummer ):
    for document in sorted( dossier.documenten, key=lambda doc:doc.volgnummer ):
        try:
            soorten[ str(document.soort).split(".",1)[1] ].append( document ) # takes the enum name (rather than value) and splits off the DocumentSoort.
        except Exception as e:
            print("SKIP invalid soort: %s"%(e))

# %%
# key a list of (soort,count), sort it by count, descending
soorten_by_count = sorted( list( soorten.items() ), key=lambda pair: len(pair[1]), reverse=True )

for soort, doclist in soorten_by_count:
    print( f'{len(doclist):7d}  {soort}')
# Out:
#   72448  BRIEF_REGERING
#   48694  MOTIE
#    8154  AMENDEMENT
#    5175  MOTIE_GEWIJZIGDNADER
#    5037  VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG
#    4570  AMENDEMENT_GEWIJZIGD_NADER_VERVANGEND
#    4118  VERSLAG_VAN_EEN_SCHRIFTELIJK_OVERLEG
#    3912  VOORSTEL_VAN_WET
#    3911  MEMORIE_VAN_TOELICHTING
#    3177  VERSLAG_INITIATIEFWETSVOORSTEL_NADER
#    2888  LIJST_VAN_VRAGEN_EN_ANTWOORDEN
#    2474  NOTA_NAV_HET_NADERTWEEDE_NADERENZ_VERSLAG
#    2370  NOTA_VAN_WIJZIGING
#    2278  KONINKLIJKE_BOODSCHAP
#    2130  ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT
#    1163  VERSLAG_HOUDENDE_EEN_LIJST_VAN_VRAGEN_EN_ANTWOORDEN
#     902  BRIEF_COMMISSIE
#     873  BRIEF_ALGEMENE_REKENKAMER
#     756  VERSLAG_VAN_EEN_COMMISSIEDEBAT
#     612  VERSLAG_VAN_EEN_WETGEVINGSOVERLEG
#     522  GELEIDENDE_BRIEF
#     437  BRIEF_LID__FRACTIE
#     416  MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL
#     391  VOORSTEL_VAN_WET_INITIATIEFVOORSTEL
#     379  VERSLAG_COMMISSIE_VERZOEKSCHRIFTEN_EN_DE_BURGERINITIATIEVEN
#     362  JAARVERSLAG
#     346  VERSLAG_VAN_EEN_BIJEENKOMST
#     321  VERSLAG_VAN_EEN_NOTAOVERLEG
#     295  BRIEF_KAMER
#     287  RAPPORT_ALGEMENE_REKENKAMER
#     273  BRIEF_PRESIDIUM
#     250  NOTA_VAN_VERBETERING
#     247  VERSLAG_VAN_EEN_HOORZITTING__RONDETAFELGESPREK
#     238  NOTA_VAN_WIJZIGING_INITIATIEFVOORSTEL
#     222  NADER_RAPPORT
#     211  INITIATIEFNOTA
#     182  ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#     169  MEDEDELING
#     142  VERSLAG_VAN_EEN_WERKBEZOEK
#     105  ADVIES_VAN_ANDERE_ADVIESORGANEN
#      68  OVERIG
#      59  BRIEF_INFORMATEUR
#      50  RAPPORT
#      49  VOORSTEL_TOT_WIJZIGING_REGLEMENT_VAN_ORDE
#      30  VOORLICHTING_AFDELING_ADVISERING_RAAD_VAN_STATE
#      30  VERSLAG_VAN_EEN_RAPPORTEUR
#      26  EU_VOORSTEL
#      26  BRIEF_EUROPESE_COMMISSIE
#      25  BRIEF_CTIVD
#      22  OORSPRONKELIJKE_TEKST
#      19  BRIEF_NATIONALE_OMBUDSMAN
#      18  BRIEF_PRESIDENT_HOGE_RAAD
#      13  ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#      12  VOORSTEL_VAN_WET_TWEEDE_LEZING
#      12  BRIEF_VERKENNER
#      10  NOTA
#       9  WIJZIGINGEN_VOORGESTELD_DOOR_DE_REGERING
#       8  VERSLAG_VAN_EEN_POLITIEKE_DIALOOG
#       6  BRIEF_FORMATEUR
#       5  BRIEF_AFDELING_ADVISERING_RAAD_VAN_STATE
#       4  INBRENG_VERSLAG_SCHRIFTELIJK_OVERLEG
#       4  VOORDRACHT
#       3  ONDERZOEKSVOORSTEL
#       3  BRIEF_VOORZITTER
#       2  ADVIES_COMMISSIE
#       2  BRIEF_COMMISSIE_AAN_BEWINDSPERSOON
#       2  BRIEF_EERSTE_KAMER
#       2  LIJST_VAN_VRAGEN
#       1  ADVIES_AAN_PRESIDIUM
#       1  RAMING_VAN_DE_UITGAVEN
#       1  BEGROTINGSTOELICHTING
#       1  BIJLAGE
#       1  REACTIE_INITIATIEFNEMERS

# %% [markdown]
# ## Example
#
# Let's say that our interest is more specific:
# finding what  Raad van State  has to say about  proposed laws (wetsvoorstellen).
#
# ...and, in the process also learn what the kinds of documents there are in each dossier.
#
# There is also the [advice on the raad van state site](https://www.raadvanstate.nl/adviezen/),
# (for a more data-like form, see also our [extras_datacollect_raadvanstate](extras_datacollect_raadvanstate.ipynb)),
# but there it is not placed in the context of the law it's referring to.
# This interface should at least gives us the law's name.

# %%
# We start by selecting dossiers where there already _is_ RvS advice.
#  - this is a decent filter for wetsvoorstellen
#  - and filters out wetsvoorstellen that don't need this advice (e.g. begroting)
# ...but we are about to find out
# - there are other things that RVS advises on, like finances (see e.g. 36200) 
# - there are law changes that RVS does not advise on (e.g. TODO)

sorted_dossiers = sorted(all_dossiers,  key=lambda d:d.nummer,  reverse=True )

count = 0
for i, dossier in enumerate( sorted_dossiers ):
    nummer_and_toevoeging = ('%s-%s'%(dossier.nummer, dossier.toevoeging or '')).rstrip('-')

    #if (dossier.nummer%100) == 0: # ignore a few specific special cases for now,   just because they're large to print
    #    continue

    ## In our stated interest:  first see if it has RvS advice
    sorted_docs      = sorted(dossier.documenten,  key=lambda d:d.volgnummer )
    has_raadvanstate = False
    for document in sorted_docs:
        try:
            # these come from an enum, try  list( tkapi.document.DocumentSoort )  to see a list
            if document.soort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                  #DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_NADER_RAPPORT, # seems to be begrotingstuff?  (TODO: check)
                                  DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS,
                                ):
                has_raadvanstate = True
        except ValueError: # there's some invalid / non-covered soort values in the data
            pass # ignore
        # we can filter on more, but we may not need to?

    if not has_raadvanstate:
        continue
    # if execution gets here, it's probably interesting to us.
    
    count += 1
    #if len(sorted_docs)>500:
    #    print( "\n\n== Dossier %s == %s =="%( dossier.nummer, dossier.titel) )
    #    print(' LARGE: %d documents'%len(sorted_docs))
    #    print(' %s ({{kamerdossier|%d}}'%(dossier.titel, dossier.nummer))
    #    continue

    print( "\n== %r == Dossier %s == %d docs == %s =="%( dossier.id, nummer_and_toevoeging, len(dossier.documenten), dossier.titel) )
    for document in sorted_docs:
        try:
            if 0: # just to make the summaries a little easier to read
                if document.soort in (DocumentSoort.MOTIE, DocumentSoort.AMENDEMENT, DocumentSoort.BRIEF_REGERING, DocumentSoort.VERSLAG_VAN_EEN_ALGEMEEN_OVERLEG,
                                    DocumentSoort.MEMORIE_VAN_TOELICHTING_INITIATIEFVOORSTEL,
                                    ):
                    continue
        except ValueError:
            print( "soort not known by tkapi")
            continue

        try:
            docsoort = document.soort
        except ValueError: # this seems to be internal inconsistency
            continue

        show_all_docs = False
        if show_all_docs or docsoort in (DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE, 
                                DocumentSoort.ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS):

            print( '#%s'%(document.volgnummer, ), document.soort.name)
            #print( 'soort', document.soort.name, '(%s)'%document.soort.value )
            print( '  onderwerp    ', document.onderwerp )     # for wetsvoorstel-dossiers, seems to often be the same as soort plus some detail (who a letter is from, who )
            print( '  citeertitel  ', document.titel_citeer ) # for wetsvoorstel-dossiers, this often seems to name the law. Or a related one, see e.g. 36195
            print( '  titel        ', document.titel )              # for wetsvoorstel-dossiers, this seems to often name the law, plus sometimes some reason
            #print( 'versies', document.versies )
            print( '  url          ', document.bestand_url )
            if 0:        # It may be interesting to know the document is part of multiple dossiers and/or multiple zaken
                print( '  zaken         ', document.zaken )
                #nums = document.dossier_nummers
                #nums.pop(dossier.nummer)
                #if len(nums)>0:
                #  print( "  also in dossiers: %s"%nums )

            print()

    #if i > 1000: # show only a bunch, not all
    #    print("break %d"%i)
    #    break
print( 'Interesting cases: %d'%count )
# Out:
# == '6abacd05-acdf-4938-ab33-36f88d8ea469' == Dossier 36468 == 6 docs == Voorstel van wet van het lid Dijk houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Dijk houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(87f1dfa6-1f5a-4d6a-96da-72e52ad0ae45)/TK.DA.GGM.OData.Resource()
#
#
# == '87a7ff74-bf81-4e71-a69e-2439ce536c2c' == Dossier 36346 == 7 docs == Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet raadplegend referendum Nederlands EU-lidmaatschap
#   titel         Voorstel van wet van het lid Van Houwelingen betreffende het houden van een raadplegend referendum over het Nederlandse lidmaatschap van de Europese Unie (Wet raadplegend referendum Nederlands EU-lidmaatschap)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bd0dbb7d-bbbe-4aa3-8e28-ba55df7756e3)/TK.DA.GGM.OData.Resource()
#
#
# == '189b20be-8f47-4785-90da-39f5d68b6861' == Dossier 36318 == 6 docs == Voorstel van wet van het lid Erkens houdende regels over het vergroten van de energieonafhankelijkheid (Wet energieonafhankelijkheid) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet energieonafhankelijkheid
#   titel         Voorstel van wet van het lid Erkens houdende regels over het vergroten van de energieonafhankelijkheid (Wet energieonafhankelijkheid)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bc70a52f-9cb3-4fef-897e-4eba92933162)/TK.DA.GGM.OData.Resource()
#
#
# == '49f64470-6e41-4115-9547-420f5e3b6a3e' == Dossier 36200 == 188 docs == Nota over de toestand van ’s Rijks Financiën ==
# #6 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Najaarsrapportage Afdeling advisering Raad van State en Kabinetsreactie
#   citeertitel   Miljoenennota 2023
#   titel         Nota over de toestand van ’s Rijks Financiën
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dd727f69-b617-4d27-89d8-0adb403e483c)/TK.DA.GGM.OData.Resource()
#
#
# == '759d319b-389a-494e-b69e-2ed3f5291b27' == Dossier 36195 == 33 docs == Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten (Wet vaste huurcontracten) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet vaste huurcontracten
#   titel         Voorstel van wet van de leden Nijboer en Grinwis tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Overgangswet nieuw Burgerlijk Wetboek in verband met het afschaffen van tijdelijke huurcontracten voor zelfstandige woonruimten (Wet vaste huurcontracten)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bf72af35-dbb5-49a3-87b0-b7c834cd6ec0)/TK.DA.GGM.OData.Resource()
#
#
# == 'bf967829-e330-46a1-989b-3b9e688dd411' == Dossier 36178 == 8 docs == Voorstel van wet van de leden Paulusma, Becker, Westerveld, Van Nispen en Kostic tot wijziging van het Wetboek van Strafrecht en enige andere wetten in verband met het strafbaar stellen van handelingen gericht op het veranderen of onderdrukken van de seksuele gerichtheid, genderidentiteit of genderexpressie (Wet strafbaarstelling conversiehandelingen) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet strafbaarstelling conversiehandelingen
#   titel         Voorstel van wet van de leden Van der Laan, Van der Woude, De Hoop, Westerveld, Kwint en Van Esch tot wijziging van het Wetboek van Strafrecht en enige andere wetten in verband met het strafbaar stellen van handelingen gericht op het veranderen of onderdrukken van de seksuele gerichtheid, genderidentiteit of genderexpressie (Wet strafbaarstelling conversiehandelingen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d5b82f36-b1cd-4872-bf4d-240b438387ce)/TK.DA.GGM.OData.Resource()
#
#
# == 'cc270778-4153-4d65-af77-fe3519a32b76' == Dossier 36161 == 7 docs == Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet raadgevend referendum naar Zwitsers model
#   titel         Voorstel van wet van de leden Baudet en Van Houwelingen houdende regels inzake een breed raadgevend referendum (Wet raadgevend referendum naar Zwitsers model)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(92f3980e-07d2-4e10-8b40-e7d5953961c4)/TK.DA.GGM.OData.Resource()
#
#
# == '06397d33-825c-47ec-ae31-6b186a4a06dd' == Dossier 36160 == 15 docs == Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Leijten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c4b73975-1fb0-4b46-ada1-4d39fdd365ad)/TK.DA.GGM.OData.Resource()
#
#
# == '992cfaeb-47f7-41d9-ae24-7905719cfca9' == Dossier 36128 == 10 docs == Voorstel van wet van de leden Maatoug en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Maatoug, Van der Lee en Nijboer houdende wijziging van de Wet inkomstenbelasting 2001 en enige andere fiscale wetten in verband met het doen vervallen van enkele fiscale regelingen en het vervangen van het box 2-tarief door een progressief tarief
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(21766f02-9869-4df9-a59f-94d2330f7a08)/TK.DA.GGM.OData.Resource()
#
#
# == '77900319-43c1-4121-8d58-883970285392' == Dossier 36125 == 6 docs == Voorstel van wet van het lid Sneller tot wijziging van de Wet op de rechterlijke organisatie in verband met het laten vervallen van de bijzondere aanwijzingsbevoegdheid van de minister met betrekking tot de uitoefening van de taken en bevoegdheden van het openbaar ministerie (Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie
#   titel         Voorstel van wet van het lid Sneller tot wijziging van de Wet op de rechterlijke organisatie in verband met het laten vervallen van de bijzondere aanwijzingsbevoegdheid van de minister met betrekking tot de uitoefening van de taken en bevoegdheden van het openbaar ministerie (Wet verval bijzondere aanwijzingsbevoegdheid openbaar ministerie)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9cebfb50-4e51-451e-9d8e-c728ead4b003)/TK.DA.GGM.OData.Resource()
#
#
# == 'ad0b6d7d-4132-4f09-84ac-1cbb6927994c' == Dossier 36052 == 8 docs == Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Houwelingen houdende splitsing van de gemeente Groningen en instelling van de gemeente Haren
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(28e4b35d-51b4-4db6-abd3-353e58e219e7)/TK.DA.GGM.OData.Resource()
#
#
# == 'bebb0654-c0c7-49a3-838a-d3346c0cc7fc' == Dossier 36047 == 11 docs == Voorstel van wet van de leden Sneller en Bushoff tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet vervroegd stemmen in het stemlokaal
#   titel         Voorstel van wet van de leden Sneller en Kathmann tot wijziging van de Kieswet in verband met de permanente invoering van de mogelijkheid voor kiezers om gedurende twee dagen voorafgaand aan de dag van de stemming vervroegd te stemmen in het stemlokaal (Wet vervroegd stemmen in het stemlokaal)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5af5cab2-077c-4f7b-86c7-f03799cd2d4d)/TK.DA.GGM.OData.Resource()
#
#
# == '5d249bfc-57df-4090-8a3d-697345122d44' == Dossier 36041 == 5 docs == Voorstel van wet van de leden Kops en Edgar Mulder tot wijziging van de Wet op de omzetbelasting 1968 en de Belastingwet BES inzake het tijdelijk onder het nultarief plaatsen van energie en tot wijziging van de begrotingsstaat van het gemeentefonds voor het jaar 2022 inzake het extra compenseren van huishoudens (Tijdelijke noodwet betaalbare energie) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Tijdelijke noodwet betaalbare energie
#   titel         Voorstel van wet van de leden Kops en Edgar Mulder tot wijziging van de Wet op de omzetbelasting 1968 en de Belastingwet BES inzake het tijdelijk onder het nultarief plaatsen van energie en tot wijziging van de begrotingsstaat van het gemeentefonds voor het jaar 2022 inzake het extra compenseren van huishoudens (Tijdelijke noodwet betaalbare energie)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9a4bcf7a-3b0e-416d-b91e-a03d7063cfcc)/TK.DA.GGM.OData.Resource()
#
#
# == 'bff0de26-0e61-433a-a06a-f479d1ad87ca' == Dossier 36028 == 6 docs == Wijziging van het Wetboek van Burgerlijke Rechtsvordering en het Wetboek van Burgerlijke Rechtsvordering BES in verband met het op 2 december 2004 te New York tot stand gekomen Verdrag van de Verenigde Naties inzake de immuniteit van rechtsmacht van staten en hun eigendommen (Uitvoeringswet VN-Verdrag staatsimmuniteit) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Afdeling advisering Raad van State
#   citeertitel
#   titel         Wijziging van het Wetboek van Burgerlijke Rechtsvordering en het Wetboek van Burgerlijke Rechtsvordering BES in verband met het op 2 december 2004 te New York tot stand gekomen Verdrag van de Verenigde Naties inzake de immuniteit van rechtsmacht van staten en hun eigendommen (Uitvoeringswet VN-Verdrag staatsimmuniteit)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b966124c-359e-45cb-bf62-6f944e0089d6)/TK.DA.GGM.OData.Resource()
#
#
# == '3e2a9c16-63a4-44f5-9e83-3e1e5660f3d1' == Dossier 35999 == 17 docs == Voorstel van wet van de leden Koerhuis, Van der Plas, Grinwis en Westerveld tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Woningwet in verband met het bieden van huurbescherming aan weeskinderen (Wet huurbescherming weeskinderen) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet huurbescherming weeskinderen
#   titel         Voorstel van wet van de leden Koerhuis, Van der Plas, Grinwis en Westerveld tot wijziging van Boek 7 van het Burgerlijk Wetboek en de Woningwet in verband met het bieden van huurbescherming aan weeskinderen (Wet huurbescherming weeskinderen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(85277fa6-d27e-48eb-b888-ef773d15e16d)/TK.DA.GGM.OData.Resource()
#
#
# == '53e35856-bb9b-453a-b797-05e4f5f2dbd8' == Dossier 35953 == 8 docs == Voorstel van wet van het lid Van Raan houdende wijziging van de Klimaatwet om te bewerkstelligen dat Nederland zo spoedig mogelijk een zo groot mogelijke bijdrage gaat leveren aan het voorkomen van een verdere opwarming van de Aarde (Klimaatwet 1.5) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Raan houdende wijziging van de Klimaatwet om te bewerkstelligen dat Nederland zo spoedig mogelijk een zo groot mogelijke bijdrage gaat leveren aan het voorkomen van een verdere opwarming van de Aarde (Klimaatwet 1.5)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(79f92ea9-a2ac-47a4-adac-e43687e9d965)/TK.DA.GGM.OData.Resource()
#
#
# == '8baa7ea2-fc92-4043-9e00-48a91cbdf8bf' == Dossier 35925-XIV == 162 docs == Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022 ==
# #3 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Afdeling advisering Raad van State en Nader rapport
#   citeertitel
#   titel         Vaststelling van de begrotingsstaten van het Ministerie van Landbouw, Natuur en Voedselkwaliteit (XIV) en het Diergezondheidsfonds (F) voor het jaar 2022
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(81f48e48-8189-4335-a543-81b6a64cc813)/TK.DA.GGM.OData.Resource()
#
#
# == 'cb5510e3-80c1-4cbf-9531-9cc7430e90cb' == Dossier 35914 == 15 docs == Voorstel van wet van het lid Kops tot wijziging van de Huisvestingswet 2014 in verband met het uitzonderen van het verlenen van voorrang aan vergunninghouders bij huisvesting op grond van het feit dat zij vergunninghouder zijn (Wet uitzonderen voorrang vergunninghouders) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet uitzonderen voorrang vergunninghouders
#   titel         Voorstel van wet van het lid Kops tot wijziging van de Huisvestingswet 2014 in verband met het uitzonderen van het verlenen van voorrang aan vergunninghouders bij huisvesting op grond van het feit dat zij vergunninghouder zijn (Wet uitzonderen voorrang vergunninghouders)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(88979d43-f591-4ca3-8a5b-73524f86c000)/TK.DA.GGM.OData.Resource()
#
#
# == 'c6222530-7f6d-49ee-bc6c-364fb4a85b85' == Dossier 35761 == 21 docs == Voorstel van wet van de leden Ceder, Dobbe, Hirsch, Koekkoek en Bamenga houdende regels voor gepaste zorgvuldigheid in waardeketens om schending van mensenrechten en het milieu tegen te gaan bij het bedrijven van buitenlandse handel (Wet verantwoord en duurzaam internationaal ondernemen) ==
# #8 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet verantwoord en duurzaam internationaal ondernemen
#   titel         Voorstel van wet van de leden Van der Graaf, Jasper van Dijk, Thijssen, Van der Lee, Koekkoek en Hammelburg houdende regels voor gepaste zorgvuldigheid in productieketens om schending van mensenrechten, arbeidsrechten en het milieu tegen te gaan bij het bedrijven van buitenlandse handel (Wet verantwoord en duurzaam internationaal ondernemen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(fe675c97-22f9-46f4-8110-10a73d6fc5a4)/TK.DA.GGM.OData.Resource()
#
#
# == '5cb39db5-7a01-49b9-909b-c0154aa0e796' == Dossier 35754 == 12 docs == Voorstel van wet van de leden Bikker, Westerveld, Krul, Diederik van Dijk, Dobbe, Kostic en Van der Plas tot wijziging van de Wet publieke gezondheid ter bevordering en verankering van integrale suïcidepreventie (Wet integrale suïcidepreventie) ==
# #7 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Bikker, Mohandis, Kuik, Westerveld, Van der Staaij, Dijk, Van Esch en Van der Plas tot wijziging van de Wet publieke gezondheid ter bevordering en verankering van integrale suïcidepreventie (Wet integrale suïcidepreventie)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f515ebad-cec3-4cc2-87b8-e45983818ec3)/TK.DA.GGM.OData.Resource()
#
#
# == '17e6671a-e68b-4084-ac90-a9ac4a63d5c2' == Dossier 35741 == 8 docs == Voorstel van wet van de leden Hammelburg, Bromet en De Hoop houdende verandering in de Grondwet, strekkende tot toevoeging van handicap en seksuele gerichtheid als non-discriminatiegrond ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de afdeling advisering van de Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Bergkamp, Özütok en Van den Hul houdende verandering in de Grondwet, strekkende tot toevoeging van handicap en seksuele gerichtheid als non-discriminatiegrond
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7bfca2d9-fe7c-4060-820a-0625b03bff8b)/TK.DA.GGM.OData.Resource()
#
#
# == '71f7a199-ece7-4aca-abf1-a00385746296' == Dossier 35737 == 29 docs == Voorstel van wet van de leden Paternotte, Kuiken, Ellemeet en Tellegen tot wijziging van Wet afbreking zwangerschap in verband met het afschaffen van de verplichte minimale beraadtermijn voor de afbreking van zwangerschappen ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Jetten tot wijziging van Wet afbreking zwangerschap in verband met het afschaffen van de verplichte minimale beraadtermijn voor de afbreking van zwangerschappen
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(18f1e108-8068-421f-bb05-2739125d0f7d)/TK.DA.GGM.OData.Resource()
#
#
# == 'a4827a89-332c-4667-b49d-d7fa1ec53873' == Dossier 35729 == 16 docs == Voorstel van wet van het lid Leijten houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     35729 Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer inzake het voorstel van wet van het lid Van Raak houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   citeertitel
#   titel         Voorstel van wet van het lid Van Raak houdende verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5102166a-a7d2-4677-90dc-6877eee40fcb)/TK.DA.GGM.OData.Resource()
#
#
# == '2c61a29f-1d53-4cba-8347-347d348342e8' == Dossier 35714 == 17 docs == Voorstel van wet van de leden Van Weyenberg en Maatoug tot wijziging van de Wet flexibel werken in verband met het bevorderen van flexibel werken naar arbeidsplaats (Wet werken waar je wilt) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet werken waar je wilt
#   titel         Voorstel van wet van de leden Van Weyenberg en Smeulders tot wijziging van de Wet flexibel werken in verband met het bevorderen van flexibel werken naar arbeidsplaats (Wet werken waar je wilt)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(63941ab0-d4f5-47ee-89b8-00d5166e3d05)/TK.DA.GGM.OData.Resource()
#
#
# == '0d382dd6-6e86-459e-ac4d-fd2770bde129' == Dossier 35709 == 11 docs == Voorstel van wet van de leden Ellemeet en Bikker tot wijziging van het Wetboek van Strafrecht in verband met de invoering van het discriminatoir oogmerk als strafverzwaringsgrond ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Ellemeet en Segers tot wijziging van het Wetboek van Strafrecht in verband met de invoering van het discriminatoir oogmerk als strafverzwaringsgrond
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9004be05-c82c-4317-994f-0d83be5d0e7b)/TK.DA.GGM.OData.Resource()
#
#
# == 'ae3373f1-cc16-4e98-af57-ad19d21cb9b8' == Dossier 35681 == 10 docs == Voorstel van wet van het lid Van Kent tot tijdelijke wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het invoeren van een maatregel tot onder meer aanpassing van de disconteringsvoet waartegen pensioenfondsen hun pensioenverplichtingen moeten berekenen ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Brenk tot tijdelijke wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het invoeren van een maatregel tot onder meer aanpassing van de disconteringsvoet waartegen pensioenfondsen hun pensioenverplichtingen moeten berekenen
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(d02e3f0a-8896-4a18-94e5-0a15d1373ad9)/TK.DA.GGM.OData.Resource()
#
#
# == '9d878b43-e8d3-4d22-8e6c-e259eb0e4eec' == Dossier 35660 == 16 docs == Voorstel van wet van de leden Ellemeet en Tielen houdende wijziging van de Wet kwaliteit, klachten en geschillen zorg in verband met de invloed van zorgverleners ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Ellemeet en Aukje de Vries houdende wijziging van de Wet kwaliteit, klachten en geschillen zorg in verband met de invloed van zorgverleners
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(14c4df0f-2034-4113-9a3e-ce30db81ef3b)/TK.DA.GGM.OData.Resource()
#
#
# == 'bd9e437c-6e9b-45e0-89c6-75a2919dccb7' == Dossier 35636 == 8 docs == Voorstel van wet van het lid Van Kent tot wijziging van de Wet minimumloon en minimumvakantiebijslag in verband met het achterblijven van de loonontwikkeling (Wet eerlijker inkomen) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van initiatiefnemers
#   citeertitel   Wet eerlijker inkomen
#   titel         Voorstel van wet van het lid Van Kent tot wijziging van de Wet minimumloon en minimumvakantiebijslag in verband met het achterblijven van de loonontwikkeling (Wet eerlijker inkomen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9035be73-fb52-44fa-b748-474515d9a950)/TK.DA.GGM.OData.Resource()
#
#
# == 'f73f058a-30bf-49a9-8844-c60b51e67326' == Dossier 35608 == 19 docs == Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Bromet en Tjeerd de Groot tot wijziging van de Waterschapswet en de Kieswet in verband met het volledig democratiseren van de waterschapsbesturen
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(505fed20-e14e-4e96-a56e-f568d539e7cd)/TK.DA.GGM.OData.Resource()
#
#
# == '6a2f93f7-75a7-40a9-9327-5ea8e4216d94' == Dossier 35592 == 22 docs == Voorstel van wet van het lid Maatoug tot wijziging van de Arbeidsomstandighedenwet in verband met het verplicht stellen van een vertrouwenspersoon ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Maatoug tot wijziging van de Arbeidsomstandighedenwet in verband met het verplicht stellen van een vertrouwenspersoon
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3946d523-5332-41fb-a634-620d7d410876)/TK.DA.GGM.OData.Resource()
#
#
# == '69c79bee-4219-4bcb-905f-fb622a151feb' == Dossier 35536 == 11 docs == Voorstel van wet van het lid Kathmann tot wijziging van de Arbeidsomstandighedenwet in verband met het aangaan van een gesprek tussen werkgever en werknemers over bereikbaarheid buiten werktijd ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet op het recht op onbereikbaarheid
#   titel         Voorstel van wet van het lid Gijs van Dijk tot wijziging van de Arbeidsomstandighedenwet in verband met het aangaan van een gesprek tussen werkgever en werknemers over bereikbaarheid buiten werktijd (Wet op het recht op onbereikbaarheid)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(491229cc-6706-45f5-b8f6-12b1375f7c9d)/TK.DA.GGM.OData.Resource()
#
#
# == 'c1c1adfb-1f15-4796-afbf-e10f972eee03' == Dossier 35534 == 9 docs == Voorstel van wet van het lid Podt houdende toetsing van levenseindebegeleiding van ouderen op verzoek en tot wijziging van het Wetboek van Strafrecht, de Wet op de beroepen in de individuele gezondheidszorg en enkele andere wetten (Wet toetsing levenseindebegeleiding van ouderen op verzoek) ==
# #6 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet toetsing levenseindebegeleiding van ouderen op verzoek
#   titel         Voorstel van wet van het lid Podt houdende toetsing van levenseindebegeleiding van ouderen op verzoek en tot wijziging van het Wetboek van Strafrecht, de Wet op de beroepen in de individuele gezondheidszorg en enkele andere wetten (Wet toetsing levenseindebegeleiding van ouderen op verzoek)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(18fda2bb-78ac-492e-9b29-2f76019ca030)/TK.DA.GGM.OData.Resource()
#
#
# == '887f7acc-1e76-4677-9cb7-b80ae79ebe3c' == Dossier 35523 == 20 docs == Voorstel van wet van het lid Van der Lee tot wijziging van de Wet op de dividendbelasting 1965 en enige andere belastingwetten in verband met de invoering van een conditionele eindafrekening (Spoedwet conditionele eindafrekening dividendbelasting) ==
# #6 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Spoedwet conditionele eindafrekening dividendbelasting
#   titel         Voorstel van wet van het lid Snels tot wijziging van de Wet op de dividendbelasting 1965 en enige andere belastingwetten in verband met de invoering van een conditionele eindafrekening (Spoedwet conditionele eindafrekening dividendbelasting)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5739c7d0-b254-4b99-866a-340a7df81eb1)/TK.DA.GGM.OData.Resource()
#
# #7 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer inzake de nota van wijziging
#   citeertitel   Spoedwet conditionele eindafrekening dividendbelasting
#   titel         Voorstel van wet van het lid Snels tot wijziging van de Wet op de dividendbelasting 1965 en enige andere belastingwetten in verband met de invoering van een conditionele eindafrekening (Spoedwet conditionele eindafrekening dividendbelasting)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(57673193-df16-4611-b910-d6123b92c22a)/TK.DA.GGM.OData.Resource()
#
#
# == '987c2d57-c829-47e7-88f8-e84c5c7db5f1' == Dossier 35444 == 9 docs == Voorstel van wet van het lid Bromet tot wijziging van de Wet natuurbescherming en enige andere wetten in verband met het treffen van maatregelen betreffende stikstofemissie en het opnemen van een grondslag voor subsidieverlening voor veestapelreductie en natuurversterking (Wet duurzame aanpak stikstof) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet duurzame aanpak stikstof
#   titel         Voorstel van wet van de leden Klaver en Bromet tot wijziging van de Wet natuurbescherming in verband met het treffen van maatregelen betreffende stikstofemissie en het opnemen van een grondslag voor subsidieverlening voor veestapelreductie en natuurversterking (Wet duurzame aanpak stikstof)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(6f381d17-8b99-461a-b5f8-09d7b9612f1a)/TK.DA.GGM.OData.Resource()
#
#
# == 'f41ce961-b8f4-4ec1-8538-701d5b673783' == Dossier 35410 == 9 docs == Voorstel van wet van het lid Kuiken houdende wijziging van de Geneesmiddelenwet, de Wet medische hulpmiddelen en de Wet op de beroepen in de individuele gezondheidszorg, tot oprichting van een openbaar register over de financiële betrekkingen tussen vergunninghouders en fabrikanten van geneesmiddelen en leveranciers van medische hulpmiddelen enerzijds en beroepsbeoefenaren, maatschappen, zorginstellingen, derden en patiënten-consumentenorganisaties anderzijds (Wet transparantieregister zorg) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de Afdeling advisering van de Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet transparantieregister zorg
#   titel         Voorstel van wet van het lid Ploumen houdende wijziging van de Geneesmiddelenwet, de Wet medische hulpmiddelen en de Wet op de beroepen in de individuele gezondheidszorg, tot oprichting van een openbaar register over de financiële betrekkingen tussen vergunninghouders en fabrikanten van geneesmiddelen en leveranciers van medische hulpmiddelen enerzijds en beroepsbeoefenaren, maatschappen, zorginstellingen, derden en patiënten-consumentenorganisaties anderzijds (Wet transparantieregister zorg)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(64bbfe4a-a72b-438a-b0a0-d29870566647)/TK.DA.GGM.OData.Resource()
#
#
# == 'e81db02a-5326-4bd1-a216-5cffdede639e' == Dossier 35406 == 10 docs == Voorstel van wet van de leden Markuszower en De Graaf tot wijziging van de Vreemdelingenwet in verband met afschaffing van de dwangsomregeling bij asielaanvragen (Noodwet afschaffing dwangsomregeling ter voorkoming van misbruik door asielzoekers) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Noodwet afschaffing dwangsomregeling ter voorkoming van misbruik door asielzoekers
#   titel         Voorstel van wet van de leden Wilders en Emiel van Dijk tot wijziging van de Vreemdelingenwet in verband met afschaffing van de dwangsomregeling bij asielaanvragen (Noodwet afschaffing dwangsomregeling ter voorkoming van misbruik door asielzoekers)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9d97ee0c-d228-4b92-a760-c4576ee8a64f)/TK.DA.GGM.OData.Resource()
#
#
# == '5c069fb5-bc99-44ce-9a05-22f3397c2dbf' == Dossier 35397 == 9 docs == Voorstel van wet van de leden Chris Simons en Inge van Dijk tot wijziging van de Gemeentewet, de Provinciewet en de Wet openbare lichamen Bonaire, Sint Eustatius en Saba in verband met het laten vervallen van het verplicht voorzitterschap door raadsleden, statenleden en eilandsraadsleden van raads-, staten- en eilandsraadscommissies ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Van den Bosch en Van der Molen tot wijziging van de Gemeentewet, de Provinciewet en de Wet openbare lichamen Bonaire, Sint Eustatius en Saba in verband met het laten vervallen van het verplicht voorzitterschap door raadsleden, statenleden en eilandsraadsleden van raads-, staten- en eilandsraadscommissies
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(11e0fb10-fd86-4ca2-b807-ba57501b87a0)/TK.DA.GGM.OData.Resource()
#
#
# == 'db70f6e0-cb2f-4721-b456-9e9a1859f0b4' == Dossier 35386 == 11 docs == Voorstel van wet van de leden Klaver en Ouwehand tot wijziging van de Wet milieubeheer en de Wet op de economische delicten in verband met de invoering van een vuurwerkverbod voor consumenten ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Klaver en Ouwehand tot wijziging van de Wet milieubeheer en de Wet op de economische delicten in verband met de invoering van een vuurwerkverbod voor consumenten
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(bfdc17af-3d66-47ab-afe6-8515f1b42443)/TK.DA.GGM.OData.Resource()
#
#
# == '2638ab4b-8577-49be-8e04-b8c708f38716' == Dossier 35335 == 23 docs == Voorstel van wet van de leden Kathmann en Maatoug houdende wijziging van de Wet minimumloon en minimumvakantiebijslag en enige andere wetten in verband met de invoering van een uniform wettelijk minimumuurloon en enige andere wijzigingen (Wet invoering minimumuurloon) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet invoering minimumuurloon
#   titel         Voorstel van wet van het lid Gijs van Dijk houdende wijziging van de Wet minimumloon en minimumvakantiebijslag en enige andere wetten in verband met de invoering van een uniform wettelijk minimumuurloon en enige andere wijzigingen (Wet invoering minimumuurloon)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ed0af36d-6860-4cf7-9c2a-94b054f146fa)/TK.DA.GGM.OData.Resource()
#
#
# == '9c8835d2-9fb2-43e6-8f86-946354a0b419' == Dossier 35333 == 9 docs == Voorstel van wet van de leden Kops, Graus en Van Aalst houdende een noodregeling over stikstof (Tijdelijke noodwet stikstof) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Tijdelijke noodwet stikstof
#   titel         Voorstel van wet van de leden Kops, Graus en Van Aalst houdende een noodregeling over stikstof (Tijdelijke noodwet stikstof)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(54f1ea8f-ca87-4770-8a61-522e00ce4812)/TK.DA.GGM.OData.Resource()
#
#
# == '4edfde49-dc95-4a38-9b85-89db323edc18' == Dossier 35298 == 22 docs == Wijziging van de Gemeentewet, de Provinciewet en de Comptabiliteitswet 2016 in verband met het afschaffen van de decentrale rekenkamerfunctie en het uitbreiden van de bevoegdheden van de rekenkamers (Wet versterking decentrale rekenkamers) ==
# #14 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE
#   onderwerp     Advies Afdeling advisering Raad van State en Nader rapport
#   citeertitel   Wet versterking decentrale rekenkamers
#   titel         Wijziging van de Gemeentewet, de Provinciewet en de Comptabiliteitswet 2016 in verband met het afschaffen van de decentrale rekenkamerfunctie en het uitbreiden van de bevoegdheden van de rekenkamers (Wet versterking decentrale rekenkamers)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(f31479ec-4f15-4f0e-b3b6-a342a5eebafc)/TK.DA.GGM.OData.Resource()
#
#
# == 'da54d573-1296-4fee-b096-645c663e0fb7' == Dossier 35296 == 18 docs == Voorstel van wet van de leden Koerhuis en Van Toorenburg tot wijziging van het Wetboek van Strafvordering in verband met het wijzigen van de rechterlijke procedure voor de beoordeling van de rechtmatige binnentreding van een woning of lokaal met als doel het verwijderen van personen alsmede voorwerpen die daar worden aangetroffen (Wet handhaving kraakverbod) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer(s)
#   citeertitel   Wet handhaving kraakverbod
#   titel         Voorstel van wet van de leden Koerhuis en Van Toorenburg tot wijziging van het Wetboek van Strafvordering in verband met het wijzigen van de rechterlijke procedure voor de beoordeling van de rechtmatige binnentreding van een woning of lokaal met als doel het verwijderen van personen alsmede voorwerpen die daar worden aangetroffen (Wet handhaving kraakverbod)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(dcde8c11-5bcb-4ad1-8941-de523f32eb67)/TK.DA.GGM.OData.Resource()
#
#
# == 'c79b1c77-e0b1-462b-98b0-56d13959a9df' == Dossier 35257 == 14 docs == Voorstel van wet van het lid Verhoeven houdende een regeling voor een afwegingsproces voor het gebruik van kwetsbaarheden in geautomatiseerde werken door de overheid (Wet Zerodays Afwegingsproces) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer inzake het voorstel van wet van het lid Verhoeven houdende een regeling voor een afwegingsproces voor het gebruik van kwetsbaarheden in geautomatiseerde werken door de overheid (Wet Zerodays Afwegingsproces)
#   citeertitel   Wet Zerodays Afwegingsproces
#   titel         Voorstel van wet van het lid Verhoeven houdende een regeling voor een afwegingsproces voor het gebruik van kwetsbaarheden in geautomatiseerde werken door de overheid (Wet Zerodays Afwegingsproces)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(71adafdd-c96b-4e40-bdce-90125bf21f15)/TK.DA.GGM.OData.Resource()
#
#
# == 'd70ddedc-ab67-4e36-810a-c8298ff2c482' == Dossier 35202-(R2126) == 10 docs == Voorstel van rijkswet van de leden Verhoeven en Jetten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot toevoeging van bepalingen inzake het lidmaatschap van de Europese Unie ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State van het Koninkrijk en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van rijkswet van de leden Verhoeven en Jetten houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot toevoeging van bepalingen inzake het lidmaatschap van de Europese Unie
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(9b2fb066-f1ac-4974-a8ed-d47d3efc866e)/TK.DA.GGM.OData.Resource()
#
#
# == 'c75a0799-2199-4522-bbd0-6d9b006a39fc' == Dossier 35157 == 8 docs == Voorstel van wet van de leden Ploumen, Özütok, Jasper van Dijk en Van Brenk tot wijziging van de Wet gelijke behandeling mannen en vrouwen in verband met de invoering van een certificaat als bewijs dat vrouwen en mannen gelijk loon ontvangen voor arbeid van gelijke waarde (Wet gelijke beloning van vrouwen en mannen) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet gelijke beloning van vrouwen en mannen
#   titel         Voorstel van wet van de leden Ploumen, Özütok, Jasper van Dijk en Van Brenk tot wijziging van de Wet gelijke behandeling mannen en vrouwen in verband met de invoering van een certificaat als bewijs dat vrouwen en mannen gelijk loon ontvangen voor arbeid van gelijke waarde (Wet gelijke beloning van vrouwen en mannen)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(eddad807-9a2d-4a8f-a883-b55a1806f83d)/TK.DA.GGM.OData.Resource()
#
#
# == '2bc77341-f6e4-46cb-84f5-fed70a79707b' == Dossier 35130-(R2119) == 18 docs == Voorstel van Rijkswet van de leden Sjoerdsma, Asscher, Van Otterloo, Van Wijngaarden en Van Ojik houdende regels inzake het creëren van tijdelijke uitzonderingen op de Rijkswet op het Nederlanderschap (Rijkswet inperking gevolgen Brexit) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State van het Koninkrijk en Reactie van de initiatiefnemers
#   citeertitel   Rijkswet inperking gevolgen Brexit
#   titel         Voorstel van Rijkswet van de leden Sjoerdsma, Asscher en Van Rooijen houdende regels inzake het creëren van tijdelijke uitzonderingen op de Rijkswet op het Nederlanderschap (Rijkswet inperking gevolgen Brexit)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(86019a2b-b8c3-4f38-8678-2eac9220a2ed)/TK.DA.GGM.OData.Resource()
#
#
# == '9c85134d-c871-4844-9e18-73695f9c7b0a' == Dossier 35129 == 16 docs == Voorstel van wet van het lid Van Raak houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Raak houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(a713b831-7bb0-4ca1-a675-d277bd86ff3f)/TK.DA.GGM.OData.Resource()
#
#
# == 'bfd7ec3b-73c5-4b1b-826c-e850dd63467e' == Dossier 35101 == 13 docs == Voorstel van wet van het lid Warmerdam tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het toekennen van een adviesrecht aan het verantwoordingsorgaan en belanghebbendenorgaan voor het maatschappelijk verantwoord beleggingsbeleid (Wet eigen strategie pensioenfonds) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Beukering-Huijbregts tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het toekennen van een adviesrecht aan het verantwoordingsorgaan en belanghebbendenorgaan voor het maatschappelijk verantwoord beleggingsbeleid en een goedkeuringsrecht voor het uitsluitingenbeleid
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(1d9e5222-df81-48f7-8f55-790fcfbcb80c)/TK.DA.GGM.OData.Resource()
#
#
# == 'c34e6e0c-e82d-4fef-8426-249b3da53959' == Dossier 35096 == 9 docs == Voorstel van wet van de leden Smeulders en Van Rooijen tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het voorkomen van pensioenkortingen op de korte termijn ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de Afdeling advisering van de Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Smeulders en Van Rooijen tot wijziging van de Pensioenwet en de Wet verplichte beroepspensioenregeling in verband met het voorkomen van pensioenkortingen op de korte termijn
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(7ba34ddd-5807-425e-b344-b61446b33adf)/TK.DA.GGM.OData.Resource()
#
#
# == 'f7be3cd0-4483-4bde-bc7e-752508c65e87' == Dossier 35079 == 29 docs == Voorstel van wet van de leden Kuiken, Kuik, Van Wijngaarden, Van der Graaf en Van der Staaij houdende regels over het bestuursrechtelijk verbieden van organisaties die een cultuur van wetteloosheid creëren, bevorderen of in stand houden (Wet bestuurlijk verbod ondermijnende organisaties) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet bestuurlijk verbod ondermijnende organisaties
#   titel         Voorstel van wet van de leden Kuiken, Van Toorenburg, Van Wijngaarden, Drost en Van der Staaij houdende regels over het bestuursrechtelijk verbieden van organisaties die een cultuur van wetteloosheid creëren, bevorderen of in stand houden (Wet bestuurlijk verbod ondermijnende organisaties)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8cf08a2a-afe8-473c-9ece-bb48a5507a5d)/TK.DA.GGM.OData.Resource()
#
#
# == '2baa2d0d-2940-4614-a55b-c38cf712a1ce' == Dossier 35063 == 18 docs == Voorstel van wet van de leden Kwint en Westerveld tot wijziging van diverse onderwijswetten teneinde te verbieden dat leerlingen van ouders die geen vrijwillige geldelijke bijdrage hebben voldaan worden buitengesloten van activiteiten ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies van de Afdeling advisering van de Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Kwint en Westerveld tot wijziging van diverse onderwijswetten teneinde te verbieden dat leerlingen van ouders die geen vrijwillige geldelijke bijdrage hebben voldaan worden buitengesloten van activiteiten
# ...
#
#
# == '7d5a36fb-c01b-4b19-bda1-eac31afb22d6' == Dossier 30564 == 6 docs == Voorstel van wet van het lid Arib houdende wijziging van de Wet op de lijkbezorging en de Wet op de beroepen in de individuele gezondheidszorg ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Arib houdende wijziging van de Wet op de lijkbezorging en de Wet op de beroepen in de individuele gezondheidszorg
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(01912134-30c8-4567-8e5d-74a49294356b)/TK.DA.GGM.OData.Resource()
#
#
# == '4eee6469-8483-462c-92d5-e71320e8c3a4' == Dossier 30538 == 18 docs == Voorstel van wet van de leden Recourt, Oskam en Segers tot wijziging van het Wetboek van Strafrecht en het Wetboek van Strafvordering in verband met het opheffen van de strafrechtelijke immuniteiten van publiekrechtelijke rechtspersonen en hun leidinggevers ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Heerts, Van de Camp en Anker tot wijziging van het Wetboek van Strafrecht en het Wetboek van Strafvordering in verband met het opheffen van de strafrechtelijke immuniteiten van publiekrechtelijke rechtspersonen en hun leidinggevers
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8d096c69-8cb3-4d1f-978d-fe010e5dc8b3)/TK.DA.GGM.OData.Resource()
#
#
# == '86ef7afe-2c25-4e9e-a465-b7ef5edd1709' == Dossier 30520 == 21 docs == Voorstel van wet van het lid Van Dam houdende wijziging van Boek 2 en Boek 6 van het Burgerlijk Wetboek (stilzwijgende verlenging en opzegtermijn bij lidmaatschappen, abonnementen en overige overeenkomsten) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Crone en Van Dam houdende wijziging van Boek 2 en Boek 6 van het Burgerlijk Wetboek (stilzwijgende verlenging en opzegtermijn bij lidmaatschappen, abonnementen en overige overeenkomsten)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0f2d9b10-01d1-436f-838b-158e26ec9304)/TK.DA.GGM.OData.Resource()
#
#
# == '25cd1dca-abf9-4c67-902c-d93738ecf373' == Dossier 30519 == 12 docs == Voorstel van wet van het lid  Oskam tot wijziging van Boek 6 van het Burgerlijk Wetboek in verband met de verruiming van de aansprakelijkheid van ouders voor gedragingen van minderjarigen vanaf de leeftijd van veertien jaar ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid  Çörüz tot wijziging van Boek 6 van het Burgerlijk Wetboek in verband met verruiming van de aansprakelijkheid voor gedragingen van minderjarigen in de leeftijd van veertien tot achttien jaar
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4543670e-b0e4-42ae-bdf3-e6e13affad33)/TK.DA.GGM.OData.Resource()
#
#
# == 'e027169f-b133-4416-9349-18d35a1dd3c2' == Dossier 30511 == 37 docs == Voorstel van wet van de leden Ormel en Van Dekken tot wijziging van het Wetboek van Strafrecht in verband met het verhogen van de maximale proeftijd voor misdrijven die de gezondheid of het welzijn van dieren benadelen, en in verband met het verhogen van het strafmaximum voor onder meer het doden van andermans dieren ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Waalkens en Ormel tot wijziging van het Wetboek van Strafrecht in verband met het verhogen van de maximale proeftijd voor misdrijven die de gezondheid of het welzijn van dieren benadelen, en in verband met het verhogen van het strafmaximum voor onder meer het doden van andermans dieren
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(552f7668-b9e6-4d5c-b41b-54f431830ce8)/TK.DA.GGM.OData.Resource()
#
#
# == '909b9b8d-bcba-4a94-9f96-863ca2b68a1a' == Dossier 30491 == 9 docs == Voorstel van wet van het lid Vermeij tot wijziging van het Wetboek van Strafrecht met betrekking tot rechtsmacht en strafmaat ter zake van internationale kinderontvoering ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van het lid Wolfsen tot wijziging van het Wetboek van Strafrecht met betrekking tot rechtsmacht en strafmaat ter zake van internationale kinderontvoering
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(26433dca-776d-4efc-8373-cb0968048086)/TK.DA.GGM.OData.Resource()
#
#
# == '90489650-2453-4b21-a619-643093d8bc9b' == Dossier 30479 == 9 docs == Voorstel van wet van het lid Hamer houdende regels met betrekking tot een tegemoetkoming in de kosten van kinderopvang en waarborging van de kwaliteit van kinderopvang (Wet basisvoorziening kinderopvang en ontwikkelingsstimulering) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet basisvoorziening kinderopvang en ontwikkelingsstimulering
#   titel         Voorstel van wet van het lid Hamer houdende regels met betrekking tot een tegemoetkoming in de kosten van kinderopvang en waarborging van de kwaliteit van kinderopvang (Wet basisvoorziening kinderopvang en ontwikkelingsstimulering)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0532dfd8-8414-48c7-ad70-058385511f05)/TK.DA.GGM.OData.Resource()
#
#
# == '9d9eed69-249f-4c67-b32e-ffa892d4c012' == Dossier 30417 == 10 docs == Voorstel van wet van de leden Ypma, Jasper van Dijk, Klaver en Van Meenen houdende wijziging van de Wet op het primair onderwijs, de Wet op de expertisecentra, de Wet op het voortgezet onderwijs, de Wet educatie en beroepsonderwijs en de Algemene wet gelijke behandeling inzake toelating tot onderwijsinstellingen van leerlingen of deelnemers (regeling toelatingsrecht onderwijs) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van de leden Hamer, Jasper van Dijk, Dibi en Pechtold houdende wijziging van de Wet op het primair onderwijs, de Wet op de expertisecentra, de Wet op het voortgezet onderwijs, de Wet educatie en beroepsonderwijs en de Algemene wet gelijke behandeling inzake toelating tot onderwijsinstellingen van leerlingen of deelnemers (regeling toelatingsrecht onderwijs)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3def7a41-7e70-404c-958d-4923f74eb7f8)/TK.DA.GGM.OData.Resource()
#
#
# == '47680d17-1794-4fe9-ad6b-8b6c6b957d70' == Dossier 30372 == 47 docs == Voorstel van wet van de leden Heijnen, Voortman en Schouw houdende regels inzake het raadgevend referendum (Wet raadgevend referendum) ==
# #7 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet raadgevend referendum
#   titel         Voorstel van wet van de leden Kalma, Duyvendak en Van der Ham, houdende regels inzake het raadgevend referendum (Wet raadgevend referendum)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(4bde8077-1f33-4718-88a5-72f3ef655909)/TK.DA.GGM.OData.Resource()
#
#
# == '90b0851c-6fe1-4815-975b-ba1a6c35dbb7' == Dossier 30309 == 7 docs == Voorstel van wet van het lid Wilders betreffende het houden van een raadplegend referendum over de toetreding van Turkije tot de Europese Unie (Wet raadplegend referendum toetreding Turkije) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet raadplegend referendum toetreding Turkije
#   titel         Voorstel van wet van het lid Wilders betreffende het houden van een raadplegend referendum over de toetreding van Turkije tot de Europese Unie (Wet raadplegend referendum toetreding Turkije)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(038c66f7-cff5-4cda-a722-2aad07447f86)/TK.DA.GGM.OData.Resource()
#
#
# == 'b9525c48-0ba0-4e25-8f90-61246f190204' == Dossier 30174 == 28 docs == Voorstel van wet van de leden Heijnen, Voortman en Schouw houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van de leden Duyvendak, Kalma en Van der Ham houdende verklaring dat er grond bestaat een voorstel in overweging te nemen tot verandering in de Grondwet, strekkende tot opneming van bepalingen inzake het correctief referendum
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(5d24c5ff-51f8-4d53-8053-88875e01dc2d)/TK.DA.GGM.OData.Resource()
#
#
# == 'a41c1827-b88e-4a77-8d58-278c0d8c66d3' == Dossier 29688 == 13 docs == Voorstel van wet van het lid Crone houdende regels inzake de toegankelijkheid, veiligheid, bereikbaarheid en redelijke prijsstelling van basisbetaaldiensten (Wet toegankelijkheid en bereikbaarheid basisbetaaldiensten) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet toegankelijkheid en bereikbaarheid basisbetaaldiensten
#   titel         Voorstel van wet van het lid Crone houdende regels inzake de toegankelijkheid, veiligheid, bereikbaarheid en redelijke prijsstelling van basisbetaaldiensten (Wet toegankelijkheid en bereikbaarheid basisbetaaldiensten)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(0a09865a-ab93-4dc6-af84-685c8911d56c)/TK.DA.GGM.OData.Resource()
#
#
# == '6965a393-e229-48d9-8105-ab0fd90b0fff' == Dossier 29680 == 12 docs == Voorstel van wet van het lid Van Wijngaarden tot wijziging van de Mediawet en de Auteurswet 1912 (regeling verstrekking programmagegevens) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van de leden Weekers en Van der Ham tot wijziging van de Mediawet en de Auteurswet 1912 (regeling verstrekking programmagegevens)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(3200ce09-c180-499b-aeca-be36f3a1b66e)/TK.DA.GGM.OData.Resource()
#
#
# == '7d146ebe-7ab2-4b5d-80db-4c7749610fa5' == Dossier 29535 == 10 docs == Voorstel van wet van het lid Duyvendak tot wijziging van enkele wetten in verband met de invoering van een belasting ter regulering van het verkeer (Wet regulerende heffing wegverkeer) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel   Wet regulerende heffing wegverkeer
#   titel         Voorstel van wet van het lid Duyvendak tot wijziging van enkele wetten in verband met de invoering van een belasting ter regulering van het verkeer (Wet regulerende heffing wegverkeer)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b3c8e4bc-3eed-47de-87ee-f65c1429ab82)/TK.DA.GGM.OData.Resource()
#
#
# == '60c335ed-09be-4d24-97d5-5badf6e4bbe2' == Dossier 29275 == 8 docs == Voorstel van wet van de leden Vos en Stuurman betreffende het wijzigen van de wet Stimulering evenredige arbeidsdeelname minderheden ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet verlenging Wet SAMEN
#   titel         Voorstel van wet van de leden Vos en Stuurman betreffende het wijzigen van de Wet stimulering arbeidsdeelname minderheden (Wet verlenging Wet SAMEN)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(b0efa574-7abf-4ec5-b8ed-e5f5b0058742)/TK.DA.GGM.OData.Resource()
#
#
# == 'af1b0a8a-ab84-45c2-a2d2-c26bdd2b79ec' == Dossier 29003 == 8 docs == Voorstel van wet van het lid Van Gent tot wijziging van de Huursubsidiewet (huursubsidie voor jongeren en studenten) ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Gent tot wijziging van de Huursubsidiewet (huursubsidie voor jongeren en studenten)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(8392d9a4-8c21-4836-8bcb-45f84693d9c5)/TK.DA.GGM.OData.Resource()
#
#
# == 'cf2420c5-6417-41e3-aae0-a81523ad1139' == Dossier 28996 == 13 docs == Voorstel van wet van het lid Van Raak houdende regels met betrekking tot de bevordering van de aanleg en het behoud van buitenspeelruimte voor kinderen (Wet buitenspeelruimte) ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel   Wet buitenspeelruimte
#   titel         Voorstel van wet van de leden Kant en Langkamp houdende regels met betrekking tot de bevordering van de aanleg en het behoud van buitenspeelruimte voor kinderen (Wet buitenspeelruimte)
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(c7644776-9a49-4605-a5c0-3a4d1b29020a)/TK.DA.GGM.OData.Resource()
#
#
# == '993e70df-60a3-461c-8189-7c25f86879f1' == Dossier 28990 == 8 docs == Voorstel van wet van het lid Van Gent tot wijziging van het Burgerlijk Wetboek in verband met een regeling van de vrijheid van meningsuiting van werknemers ter bescherming van klokkenluiders ==
# #4 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemer
#   citeertitel
#   titel         Voorstel van wet van het lid Van Gent tot wijziging van het Burgerlijk Wetboek in verband met een regeling van de vrijheid van meningsuiting van werknemers ter bescherming van klokkenluiders
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(961ff2ab-fddf-4390-883c-6b9f014e9f4b)/TK.DA.GGM.OData.Resource()
#
#
# == 'c919447a-e191-42ef-b33d-ccba98cf1007' == Dossier 28102 == 6 docs == Voorstel van wet van het lid Arib tot instelling van een Kinderombudsman ==
# #5 ADVIES_AFDELING_ADVISERING_RAAD_VAN_STATE_EN_REACTIE_VAN_DE_INITIATIEFNEMERS
#   onderwerp     Advies Afdeling advisering Raad van State en Reactie van de initiatiefnemers
#   citeertitel
#   titel         Voorstel van wet van het lid Arib tot instelling van een Kinderombudsman
#   url           https://gegevensmagazijn.tweedekamer.nl/OData/v4/2.0/Document(ab85c7ac-4691-4627-83e3-43feb94b9c0c)/TK.DA.GGM.OData.Resource()
#
# Interesting cases: 191
